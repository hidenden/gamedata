# %%
from gamedata import hard_sales as hs
from typing import Optional, List
import pandas as pd
from datetime import datetime, timedelta

# %%
hard_sales_df = hs.load_hard_sales()
hs.get_hw_names(hard_sales_df)


hard_sales_df = hard_sales_df[hard_sales_df['hw'].isin(['NSW', 'NS2', 'PS5', 'PS4', "XSX"])]
# hard_sales_dfの最後から20行程度を表示する
hard_sales_df[hard_sales_df['hw'] == "NS2"]
# Out:
#            weekly_id begin_date   end_date report_date  period_date   hw  \
# 8404  2025-06-08_NS2 2025-06-02 2025-06-08  2025-06-08            7  NS2
# 8409  2025-06-15_NS2 2025-06-09 2025-06-15  2025-06-15            7  NS2
# 8414  2025-06-22_NS2 2025-06-16 2025-06-22  2025-06-22            7  NS2
# 8419  2025-06-29_NS2 2025-06-23 2025-06-29  2025-06-29            7  NS2
# 8424  2025-07-06_NS2 2025-06-30 2025-07-06  2025-07-06            7  NS2
# 8429  2025-07-13_NS2 2025-07-07 2025-07-13  2025-07-13            7  NS2
# 8434  2025-07-20_NS2 2025-07-14 2025-07-20  2025-07-20            7  NS2
# 8439  2025-07-27_NS2 2025-07-21 2025-07-27  2025-07-27            7  NS2
# 8444  2025-08-03_NS2 2025-07-28 2025-08-03  2025-08-03            7  NS2
#
#        units  year  month  mday  week  delta_day  delta_week  delta_month  \
# 8404  715432  2025      6     8    23          3           0            0
# 8409  153205  2025      6    15    24         10           1            0
# ...

# %%
latest_df = hs.extract_latest(hard_sales_df)
latest_df
# Out:
#            weekly_id begin_date   end_date report_date  period_date   hw  \
# 8444  2025-08-03_NS2 2025-07-28 2025-08-03  2025-08-03            7  NS2
# 8445  2025-08-03_NSW 2025-07-28 2025-08-03  2025-08-03            7  NSW
# 8446  2025-08-03_PS4 2025-07-28 2025-08-03  2025-08-03            7  PS4
# 8447  2025-08-03_PS5 2025-07-28 2025-08-03  2025-08-03            7  PS5
# 8448  2025-08-03_XSX 2025-07-28 2025-08-03  2025-08-03            7  XSX
#
#       units  year  month  mday  week  delta_day  delta_week  delta_month  \
# 8444  62733  2025      8     3    31         59           8            2
# 8445  18637  2025      8     3    31       3075         439          101
# 8446     19  2025      8     3    31       4180         597          138
# 8447   7141  2025      8     3    31       1725         246           57
# 8448    271  2025      8     3    31       1727         246           57
#
#       delta_year  avg_units  sum_units launch_date maker_name  \
# ...

# %%
filtered_df = hs.extract_by_date(hard_sales_df, '2025-06-05')
filtered_df
# Out:
#            weekly_id begin_date   end_date report_date  period_date   hw  \
# 8404  2025-06-08_NS2 2025-06-02 2025-06-08  2025-06-08            7  NS2
# 8405  2025-06-08_NSW 2025-06-02 2025-06-08  2025-06-08            7  NSW
# 8406  2025-06-08_PS4 2025-06-02 2025-06-08  2025-06-08            7  PS4
# 8407  2025-06-08_PS5 2025-06-02 2025-06-08  2025-06-08            7  PS5
# 8408  2025-06-08_XSX 2025-06-02 2025-06-08  2025-06-08            7  XSX
#
#        units  year  month  mday  week  delta_day  delta_week  delta_month  \
# 8404  715432  2025      6     8    23          3           0            0
# 8405   16611  2025      6     8    23       3019         431           99
# 8406      24  2025      6     8    23       4124         589          136
# 8407   20782  2025      6     8    23       1669         238           55
# 8408     333  2025      6     8    23       1671         238           55
#
#       delta_year  avg_units  sum_units launch_date maker_name  \
# ...

# %%
df1M = hs.extract_week_reached_units(hard_sales_df, 1500000)
df1M
# Out:
#            weekly_id begin_date   end_date report_date  period_date   hw  \
# 8434  2025-07-20_NS2 2025-07-14 2025-07-20  2025-07-20            7  NS2
# 6455  2017-08-27_NSW 2017-08-21 2017-08-27  2017-08-27            7  NSW
# 5871  2015-08-02_PS4 2015-07-27 2015-08-02  2015-08-02            7  PS4
# 7638  2022-04-03_PS5 2022-03-28 2022-04-03  2022-04-03            7  PS5
#
#        units  year  month  mday  week  delta_day  delta_week  delta_month  \
# 8434  152165  2025      7    20    29         45           6            1
# 6455   85503  2017      8    27    34        177          25            5
# 5871   13192  2015      8     2    31        526          75           18
# 7638   30666  2022      4     3    13        507          72           17
#
#       delta_year  avg_units  sum_units launch_date maker_name  \
# 8434           0      21737    1522377  2025-06-05   Nintendo
# 6455           0      12214    1565273  2017-03-03   Nintendo
# ...

# %%
# 昨年のデータ
last_year_df = hard_sales_df[hard_sales_df["year"] == 2024]
last_year_df
# Out:
#            weekly_id begin_date   end_date report_date  period_date   hw  \
# 8096  2024-01-07_NSW 2024-01-01 2024-01-07  2024-01-07            7  NSW
# 8097  2024-01-07_PS4 2024-01-01 2024-01-07  2024-01-07            7  PS4
# 8098  2024-01-07_PS5 2024-01-01 2024-01-07  2024-01-07            7  PS5
# 8099  2024-01-07_XSX 2024-01-01 2024-01-07  2024-01-07            7  XSX
# 8101  2024-01-14_NSW 2024-01-08 2024-01-14  2024-01-14            7  NSW
# ...              ...        ...        ...         ...          ...  ...
# 8311  2024-12-22_XSX 2024-12-16 2024-12-22  2024-12-22            7  XSX
# 8312  2024-12-29_NSW 2024-12-23 2024-12-29  2024-12-29            7  NSW
# 8313  2024-12-29_PS4 2024-12-23 2024-12-29  2024-12-29            7  PS4
# 8314  2024-12-29_PS5 2024-12-23 2024-12-29  2024-12-29            7  PS5
# 8315  2024-12-29_XSX 2024-12-23 2024-12-29  2024-12-29            7  XSX
#
#        units  year  month  mday  week  delta_day  delta_week  delta_month  \
# ...

# %%
nintendo_df = hard_sales_df[hard_sales_df["maker_name"].isin(['Nintendo'])]
nintendo_df.tail(20)
# Out:
#            weekly_id begin_date   end_date report_date  period_date   hw  \
# 8396  2025-05-25_NSW 2025-05-19 2025-05-25  2025-05-25            7  NSW
# 8400  2025-06-01_NSW 2025-05-26 2025-06-01  2025-06-01            7  NSW
# 8404  2025-06-08_NS2 2025-06-02 2025-06-08  2025-06-08            7  NS2
# 8405  2025-06-08_NSW 2025-06-02 2025-06-08  2025-06-08            7  NSW
# 8409  2025-06-15_NS2 2025-06-09 2025-06-15  2025-06-15            7  NS2
# 8410  2025-06-15_NSW 2025-06-09 2025-06-15  2025-06-15            7  NSW
# 8414  2025-06-22_NS2 2025-06-16 2025-06-22  2025-06-22            7  NS2
# 8415  2025-06-22_NSW 2025-06-16 2025-06-22  2025-06-22            7  NSW
# 8419  2025-06-29_NS2 2025-06-23 2025-06-29  2025-06-29            7  NS2
# 8420  2025-06-29_NSW 2025-06-23 2025-06-29  2025-06-29            7  NSW
# 8424  2025-07-06_NS2 2025-06-30 2025-07-06  2025-07-06            7  NS2
# 8425  2025-07-06_NSW 2025-06-30 2025-07-06  2025-07-06            7  NSW
# ...

# %%
# switch_dfを月毎に集計する
switch_monthly_sales = hs.monthly_sales(switch_df)
# 月毎のNintendo Switch*の販売台数を表示する
switch_monthly_sales.tail(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # switch_dfを月毎に集計する
# ----> 2 switch_monthly_sales = hs.aggregate_monthly_sales(switch_df)
#       3 # 月毎のNintendo Switch*の販売台数を表示する
#       4 switch_monthly_sales.tail(20)
#
# NameError: name 'switch_df' is not defined
