# %%
### 週販レポート2025年版
# %matplotlib widget

# 標準ライブラリ
from datetime import datetime, timedelta

# サードパーティライブラリ
import pandas as pd
from pandas import Timedelta
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
from IPython.display import Markdown, display

# プロジェクト内モジュール
from gamedata import hard_sales as hs
from gamedata import plot_hard as ph
from gamedata import hard_info as hi
from gamedata import hard_event as he

plt.show()

# %%
(fig, df) = ph.plot_monthly_bar_by_hard(hw=['PS5', 'PS4', 'NSW'], year=2023, stacked=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
(fig, df) = ph.plot_monthly_bar_by_hard(hw=['PS5', 'PS4', 'NSW'], year=2023)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
(fig, df) = ph.plot_yearly_bar_by_hard(hw=['PS5', 'PS4', 'NSW'], begin=datetime(2019,1,1), end=datetime(2024,12,31), stacked=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# If the function expects a year comparison, ensure you pass the correct type
(fig, df) = ph.plot_delta_yearly_bar(hw=['NSW', 'PS4', 'PS5', 'NS2'], delta_end=5)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
df
# Out:
# hw                NSW        PS4        PS5
# delta_year
# 0           3407158.0   925570.0   255150.0
# 1           3482388.0  1190336.0   968185.0
# 2           4493903.0  1790883.0  1154054.0
# 3           5956943.0  1935247.0  2587468.0
# 4           5579127.0  1695227.0  1454149.0
# 5           4804546.0  1196153.0   590931.0
# 6           4062609.0   542647.0        0.0
# 7           3109103.0   104054.0        0.0
# 8           1073896.0    22823.0        0.0
# 9                 0.0    73292.0        0.0
# 10                0.0    13728.0        0.0
# 11                0.0      822.0        0.0

# %%
(fig, df) = ph.plot_sales(hw=['NS2', 'NSW', 'PS5', 'PS4'], begin=datetime(2017,1,1), mode='year')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
(fig, df) = ph.plot_sales(hw=[], xgrid=1, begin=datetime(2016,1,1), mode='year', area=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
(fig, df) = ph.plot_area_sales(hw=[], begin=datetime(2015,1,1), mode="year")

# %%
ph.plot_sales(begin=datetime(2025,1,1))
# Out:
# (<Figure size 1000x500 with 1 Axes>,
#  hw                NS2       NSW   PS4       PS5     XSX
#  report_date
#  2025-01-05        NaN  109729.0  35.0   46680.0  1113.0
#  2025-01-12        NaN   57831.0  31.0   11828.0   876.0
#  2025-01-19        NaN   47560.0  29.0   10738.0   785.0
#  2025-01-26        NaN   45327.0  31.0   12341.0  1087.0
#  2025-02-02        NaN   44341.0  19.0   12873.0  3070.0
#  2025-02-09        NaN   43672.0  21.0   14408.0  2320.0
#  2025-02-16        NaN   40003.0  23.0   16049.0  2826.0
#  2025-02-23        NaN   39172.0  22.0   13556.0  1535.0
#  2025-03-02        NaN   45189.0  20.0  108978.0   721.0
#  2025-03-09        NaN   37841.0  22.0   52520.0   559.0
#  2025-03-16        NaN   27898.0  19.0   27863.0   333.0
#  2025-03-23        NaN   30504.0  18.0   15212.0   252.0
#  2025-03-30        NaN   30489.0  33.0   13727.0   216.0
#  2025-04-06        NaN   35041.0  21.0   12518.0   148.0
#  2025-04-13        NaN   25035.0  17.0    8866.0   196.0
# ...

# %%
ph.plot_cumulative_sales_by_delta(hw=['PS5', 'PS4'])
# Out:
# (<Figure size 1000x500 with 1 Axes>,
#  hw                PS4       PS5
#  delta_week
#  0            322083.0  118085.0
#  1            374780.0  160976.0
#  2            405546.0  201435.0
#  3            434410.0  213328.0
#  4            467751.0  224384.0
#  ...               ...       ...
#  597         9490707.0       NaN
#  598         9490723.0       NaN
#  599         9490739.0       NaN
#  600         9490752.0       NaN
#  601         9490768.0       NaN
#
#  [602 rows x 2 columns])

# %%
ph.plot_sales_by_delta(hw=['NS2', 'NSW'], end=15, ymax=300000, event_priority=3.5)
# Out:
# (<Figure size 1000x500 with 1 Axes>,
#  hw               NS2       NSW
#  delta_week
#  0           715432.0  330637.0
#  1           153205.0   63420.0
#  2           140026.0   50821.0
#  3           161021.0   79493.0
#  4           128643.0   32262.0
#  5            71885.0   45271.0
#  6           152165.0   42700.0
#  7            92013.0   40367.0
#  8            62733.0   74217.0
#  9            89820.0   47353.0
#  10           89821.0   25257.0
#  11           35359.0   27264.0
#  12           41957.0   27440.0
#  13               NaN   25274.0
#  14               NaN   28293.0
#  15               NaN   49440.0)

# %%
ph.plot_cumulative_sales(hw=['PS5', 'PS4', 'NSW', 'NS2'], event_priority=1)
# Out:
# (<Figure size 1000x500 with 1 Axes>,
#  hw                 NS2         NSW        PS4        PS5
#  report_date
#  2014-02-23         NaN         NaN   322083.0        NaN
#  2014-03-02         NaN         NaN   374780.0        NaN
#  2014-03-09         NaN         NaN   405546.0        NaN
#  2014-03-16         NaN         NaN   434410.0        NaN
#  2014-03-23         NaN         NaN   467751.0        NaN
#  ...                ...         ...        ...        ...
#  2025-08-03   1677123.0  35869618.0  9490707.0  6946379.0
#  2025-08-10   1766943.0  35888291.0  9490723.0  6954944.0
#  2025-08-17   1856764.0  35906964.0  9490739.0  6963510.0
#  2025-08-24   1892123.0  35924909.0  9490752.0  6969938.0
#  2025-08-31   1934080.0  35945498.0  9490768.0  6978242.0
#
#  [602 rows x 4 columns])

# %%
ph.plot_monthly_histogram_by_year('PS5', begin=datetime(2023,1,1))
# Out:
# (<Figure size 1000x500 with 1 Axes>,
#  year       2023      2024      2025
#  month
#  1      234329.0  185480.0   81587.0
#  2      366982.0  146945.0   56886.0
#  3      222656.0  162281.0  218300.0
#  4      219646.0   91981.0   38983.0
#  5      166660.0   87218.0   32001.0
#  6      215521.0  117592.0   63516.0
#  7      243383.0  123087.0   28959.0
#  8      181361.0  104178.0   39004.0
#  9      181056.0   74523.0       0.0
#  10     112186.0   47615.0       0.0
#  11     231317.0  151370.0       0.0
#  12     212371.0  161879.0       0.0)

# %%
ph.plot_yearly_histogram_by_hard(['PS5', 'NSW', 'NS2'], begin=datetime(2020,1,1))
# Out:
# (<Figure size 1000x500 with 1 Axes>,
#  hw          NS2        NSW        PS5
#  year
#  2020        0.0  5956943.0   255150.0
#  2021        0.0  5579127.0   968185.0
#  2022        0.0  4804546.0  1154054.0
#  2023        0.0  4062609.0  2587468.0
#  2024        0.0  3109103.0  1454149.0
#  2025  1934080.0  1049721.0   559236.0)

# %%
ph.plot_delta_yearly_histogram(['PS5', 'NSW', 'NS2'])
# Out:
# (<Figure size 1000x500 with 1 Axes>,
#  hw                NS2        NSW        PS5
#  delta_year
#  0           1934080.0  3407158.0   255150.0
#  1                 0.0  3482388.0   968185.0
#  2                 0.0  4493903.0  1154054.0
#  3                 0.0  5956943.0  2587468.0
#  4                 0.0  5579127.0  1454149.0
#  5                 0.0  4804546.0   559236.0
#  6                 0.0  4062609.0        0.0
#  7                 0.0  3109103.0        0.0
#  8                 0.0  1049721.0        0.0)
