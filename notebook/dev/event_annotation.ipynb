# %%
# 標準ライブラリ
from datetime import datetime, timedelta
from typing import Optional


# サードパーティライブラリ
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
from matplotlib.figure import Figure

# プロジェクト内モジュール
from gamedata import hard_sales as hs
from gamedata import plot_hard as ph
from gamedata import hard_event as he
from gamedata import hard_info as hi

# %%
info_df = hi.load_hard_info()
event_df = he.load_hard_event()
delta_event_df = he.delta_event(event_df, info_df)

delta_event_df
# Out:
#             event_date   hw hw2        event_name  priority  delta_week
# report_date
# 2016-09-11  2016-09-07  PS4               PS4Slim         1         133
# 2016-11-13  2016-11-10  PS4                PS4Pro         1         142
# 2016-12-04  2016-11-29  PS4                  FF15         1         145
# 2017-07-23  2017-07-21  NSW                  スプラ2         2          20
# 2017-07-30  2017-07-29  PS4                  DQ11         2         179
# 2017-10-29  2017-10-27  NSW                  マリオデ         1          34
# 2018-01-28  2018-01-26  PS4                   MHW         1         205
# 2018-12-09  2018-12-06  PS4              PS4大バンバン         1         250
# 2019-09-22  2019-09-20  NSW            SwitchLite         1         133
# 2019-12-22  2019-12-19  PS4            PS4数量限定セール         2         304
# 2020-03-22  2020-03-20  NSW                   あつ森         2         159
# 2021-08-01  2021-08-01  PS5           PS5 CFI1100         3          37
# 2021-10-10  2021-10-08  NSW            SwitchOLED         1         240
# 2022-09-11  2022-09-09  NSW                  スプラ3         2         288
# 2022-10-02  2022-10-01  PS5           PS5 CFI1200         3          98
# 2023-05-14  2023-05-12  NSW                  ToTK         2         323
# 2023-06-25  2023-06-22  PS5                  FF16         1         136
# 2023-08-06  2023-08-01  PS5                PS5値上げ         1         142
# 2023-10-22  2023-10-20  NSW               マリオワンダー         3         346
# 2023-11-12  2023-11-10  PS5               PS5Slim         1         156
# 2024-09-01  2024-08-27  PS5                PS5値上げ         1         198
# 2024-09-15  2024-09-11  PS5              PS5Pro発表         3         200
# 2024-09-29  2024-09-26  PS5       PS5サイインインキャンペーン         2         202
# 2024-11-10  2024-11-07  PS5                PS5Pro         1         208
# 2024-12-22  2024-12-19  PS5            PS5年末年始セール         2         214
# 2025-01-19  2025-01-16  NSW            Switch2初公開         2         411
# 2025-03-02  2025-02-28  PS5                  MHWs         1         224
# 2025-03-02  2025-02-28  PS5             PS5新生活セール         2         224
# 2025-03-30  2025-03-27  NSW       Nintendo Direct         3         421
# 2025-04-06  2025-04-02  NSW        Switch2 Direct         1         422
# 2025-06-01  2025-05-28  PS5      Days of Play2025         2         237
# 2025-06-08  2025-06-05  NSW             Switch2発売         1         431
# 2025-07-20  2025-07-17  NS2                DKバナンザ         2           6
# 2025-09-07  2025-09-04  PS5         PS5オータムキャンペーン         2         251
# 2025-09-14  2025-09-13  PS5             PS5DE容量削減         1         252
# 2025-10-19  2025-10-16  NS2                ポケモンZA         1          19
# 2025-11-23  2025-11-20  NS2                エアライダー         2          24

# %%
hard_sales_df = hs.load_hard_sales()
pv_c_df = hs.pivot_cumulative_sales_by_delta(hard_sales_df)

pv_c_df
# Out:
# hw               3DS        DC         DS         GB        GBA        GC  \
# delta_week
# 0           371326.0  101490.0   441485.0        NaN   611504.0  133719.0
# 1           577413.0  133066.0   622716.0        NaN   935190.0  162928.0
# 2           681825.0  161061.0   843011.0        NaN  1132611.0  184265.0
# 3           746767.0  203085.0  1056428.0        NaN  1272110.0  198567.0
# 4           801423.0  270095.0  1269845.0        NaN  1367434.0  207105.0
# ...              ...       ...        ...        ...        ...       ...
# 726              NaN       NaN        NaN  6388541.0        NaN       NaN
# 727              NaN       NaN        NaN  6388947.0        NaN       NaN
# 728              NaN       NaN        NaN  6389105.0        NaN       NaN
# 729              NaN       NaN        NaN  6389273.0        NaN       NaN
# 730              NaN       NaN        NaN  6389694.0        NaN       NaN
#
# hw          N64        NS2       NSW  NeoGeoP  ...       PSP  SATURN  \
# delta_week                                     ...
# 0           NaN   715432.0  330637.0  21471.0  ...  166074.0     NaN
# 1           NaN   868637.0  394057.0  26159.0  ...  247429.0     NaN
# 2           NaN  1008663.0  444878.0  29324.0  ...  349283.0     NaN
# 3           NaN  1169684.0  524371.0  31041.0  ...  451138.0     NaN
# 4           NaN  1298327.0  556633.0  32963.0  ...  506496.0     NaN
# ...         ...        ...       ...      ...  ...       ...     ...
# 726         NaN        NaN       NaN      NaN  ...       NaN     NaN
# 727         NaN        NaN       NaN      NaN  ...       NaN     NaN
# 728         NaN        NaN       NaN      NaN  ...       NaN     NaN
# 729         NaN        NaN       NaN      NaN  ...       NaN     NaN
# 730         NaN        NaN       NaN      NaN  ...       NaN     NaN
#
# hw              Vita        WS       Wii      WiiU     XB360    XBOne  \
# delta_week
# 0           321407.0  102655.0  371936.0  308570.0   62135.0  23562.0
# 1           402794.0  154012.0  481004.0  439223.0   74455.0  27136.0
# 2           442900.0  177204.0  582960.0  561579.0   84490.0  28672.0
# 3           483007.0  209072.0  786039.0  635290.0   94525.0  30411.0
# 4           498744.0  233936.0  989118.0  709001.0  103180.0  31855.0
# ...              ...       ...       ...       ...       ...      ...
# 726              NaN       NaN       NaN       NaN       NaN      NaN
# 727              NaN       NaN       NaN       NaN       NaN      NaN
# 728              NaN       NaN       NaN       NaN       NaN      NaN
# 729              NaN       NaN       NaN       NaN       NaN      NaN
# 730              NaN       NaN       NaN       NaN       NaN      NaN
#
# hw              XSX      Xbox
# delta_week
# 0           20534.0  123929.0
# 1           24218.0  161076.0
# 2           27811.0  172006.0
# 3           29433.0  179930.0
# 4           30844.0  184935.0
# ...             ...       ...
# 726             NaN       NaN
# 727             NaN       NaN
# 728             NaN       NaN
# 729             NaN       NaN
# 730             NaN       NaN
#
# [731 rows x 26 columns]

# %%
pv_s_df = hs.pivot_sales_by_delta(hard_sales_df)
pv_s_df
# Out:
# hw               3DS        DC        DS     GB       GBA        GC  N64  \
# delta_week
# 0           371326.0  101490.0  441485.0    NaN  611504.0  133719.0  NaN
# 1           206087.0   31576.0  181231.0    NaN  323686.0   29209.0  NaN
# 2           104412.0   27995.0  220295.0    NaN  197421.0   21337.0  NaN
# 3            64942.0   42024.0  213417.0    NaN  139499.0   14302.0  NaN
# 4            54656.0   67010.0  213417.0    NaN   95324.0    8538.0  NaN
# ...              ...       ...       ...    ...       ...       ...  ...
# 726              NaN       NaN       NaN  442.0       NaN       NaN  NaN
# 727              NaN       NaN       NaN  406.0       NaN       NaN  NaN
# 728              NaN       NaN       NaN  158.0       NaN       NaN  NaN
# 729              NaN       NaN       NaN  168.0       NaN       NaN  NaN
# 730              NaN       NaN       NaN  421.0       NaN       NaN  NaN
#
# hw               NS2       NSW  NeoGeoP  ...       PSP  SATURN      Vita  \
# delta_week                               ...
# 0           715432.0  330637.0  21471.0  ...  166074.0     NaN  321407.0
# 1           153205.0   63420.0   4688.0  ...   81355.0     NaN   81387.0
# 2           140026.0   50821.0   3165.0  ...  101854.0     NaN   40106.0
# 3           161021.0   79493.0   1717.0  ...  101855.0     NaN   40107.0
# 4           128643.0   32262.0   1922.0  ...   55358.0     NaN   15737.0
# ...              ...       ...      ...  ...       ...     ...       ...
# 726              NaN       NaN      NaN  ...       NaN     NaN       NaN
# 727              NaN       NaN      NaN  ...       NaN     NaN       NaN
# 728              NaN       NaN      NaN  ...       NaN     NaN       NaN
# 729              NaN       NaN      NaN  ...       NaN     NaN       NaN
# 730              NaN       NaN      NaN  ...       NaN     NaN       NaN
#
# hw                WS       Wii      WiiU    XB360    XBOne      XSX      Xbox
# delta_week
# 0           102655.0  371936.0  308570.0  62135.0  23562.0  20534.0  123929.0
# 1            51357.0  109068.0  130653.0  12320.0   3574.0   3684.0   37147.0
# 2            23192.0  101956.0  122356.0  10035.0   1536.0   3593.0   10930.0
# 3            31868.0  203079.0   73711.0  10035.0   1739.0   1622.0    7924.0
# 4            24864.0  203079.0   73711.0   8655.0   1444.0   1411.0    5005.0
# ...              ...       ...       ...      ...      ...      ...       ...
# 726              NaN       NaN       NaN      NaN      NaN      NaN       NaN
# 727              NaN       NaN       NaN      NaN      NaN      NaN       NaN
# 728              NaN       NaN       NaN      NaN      NaN      NaN       NaN
# 729              NaN       NaN       NaN      NaN      NaN      NaN       NaN
# 730              NaN       NaN       NaN      NaN      NaN      NaN       NaN
#
# [731 rows x 26 columns]

# %%
def add_event_positions_delta(event_df: pd.DataFrame, pivot_delta_df: pd.DataFrame, priority: int = 3) -> pd.DataFrame:
    """
    event_dfにx_pos（event_date）とy_pos（該当ハードの販売数）を追加し、条件に合わない行は除外した新しいDataFrameを返す。

    Args:
        event_df (pd.DataFrame): ゲームイベントデータ
        pivot_delta_df (pd.DataFrame): 累積週次販売データのピボット
        priority (int): この値以下のpriorityのイベントのみ残す

    Returns:
        pd.DataFrame: x_pos, y_posを追加したイベントデータ（条件に合わない行は除外）
    """
    # priorityでフィルタ（指定値以下のみ残す）
    filtered_events = event_df[event_df['priority'] <= priority].copy()
    x_pos_list = []
    y_pos_list = []
    drop_indices = []
    
    for idx, event_row in filtered_events.iterrows():
        delta_week = event_row['delta_week']
        hw = event_row['hw']
        hw2 = event_row['hw2']
        y_pos = None

        # delta_weekがpivot_delta_dfのindexに存在しない場合は除外
        if delta_week not in pivot_delta_df.index:
            drop_indices.append(idx)
            continue

        pivot_row = pivot_delta_df.loc[delta_week]

        # hwの値がNAでなく、pivot_rowに存在する場合
        if pd.notna(hw) and hw in pivot_row and not pd.isna(pivot_row[hw]):
            y_pos = pivot_row[hw]
        # hw2の値がNAでなく、pivot_rowに存在する場合
        elif pd.notna(hw2) and hw2 in pivot_row and not pd.isna(pivot_row[hw2]):
            y_pos = pivot_row[hw2]
        else:
            drop_indices.append(idx)
            continue

        x_pos_list.append(delta_week)
        y_pos_list.append(y_pos)

    # drop_indicesで行を除外
    filtered_events = filtered_events.drop(index=drop_indices)
    filtered_events = filtered_events.assign(x_pos=x_pos_list, y_pos=y_pos_list)
    return filtered_events



f2 = add_event_positions_delta(delta_event_df, pv_c_df, priority=3)

# %%
f2 = he.add_event_positions_delta(delta_event_df, pv_c_df, priority=3)
f2
# Out:
#             event_date   hw hw2        event_name  priority  delta_week  \
# report_date
# 2016-09-11  2016-09-07  PS4               PS4Slim         1         133
# 2016-11-13  2016-11-10  PS4                PS4Pro         1         142
# 2016-12-04  2016-11-29  PS4                  FF15         1         145
# 2017-07-23  2017-07-21  NSW                  スプラ2         2          20
# 2017-07-30  2017-07-29  PS4                  DQ11         2         179
# 2017-10-29  2017-10-27  NSW                  マリオデ         1          34
# 2018-01-28  2018-01-26  PS4                   MHW         1         205
# 2018-12-09  2018-12-06  PS4              PS4大バンバン         1         250
# 2019-09-22  2019-09-20  NSW            SwitchLite         1         133
# 2019-12-22  2019-12-19  PS4            PS4数量限定セール         2         304
# 2020-03-22  2020-03-20  NSW                   あつ森         2         159
# 2021-08-01  2021-08-01  PS5           PS5 CFI1100         3          37
# 2021-10-10  2021-10-08  NSW            SwitchOLED         1         240
# 2022-09-11  2022-09-09  NSW                  スプラ3         2         288
# 2022-10-02  2022-10-01  PS5           PS5 CFI1200         3          98
# 2023-05-14  2023-05-12  NSW                  ToTK         2         323
# 2023-06-25  2023-06-22  PS5                  FF16         1         136
# 2023-08-06  2023-08-01  PS5                PS5値上げ         1         142
# 2023-10-22  2023-10-20  NSW               マリオワンダー         3         346
# 2023-11-12  2023-11-10  PS5               PS5Slim         1         156
# 2024-09-01  2024-08-27  PS5                PS5値上げ         1         198
# 2024-09-15  2024-09-11  PS5              PS5Pro発表         3         200
# 2024-09-29  2024-09-26  PS5       PS5サイインインキャンペーン         2         202
# 2024-11-10  2024-11-07  PS5                PS5Pro         1         208
# 2024-12-22  2024-12-19  PS5            PS5年末年始セール         2         214
# 2025-01-19  2025-01-16  NSW            Switch2初公開         2         411
# 2025-03-02  2025-02-28  PS5                  MHWs         1         224
# 2025-03-02  2025-02-28  PS5             PS5新生活セール         2         224
# 2025-03-30  2025-03-27  NSW       Nintendo Direct         3         421
# 2025-04-06  2025-04-02  NSW        Switch2 Direct         1         422
# 2025-06-01  2025-05-28  PS5      Days of Play2025         2         237
# 2025-06-08  2025-06-05  NSW             Switch2発売         1         431
# 2025-07-20  2025-07-17  NS2                DKバナンザ         2           6
#
#              x_pos       y_pos
# report_date
# 2016-09-11     133   3001234.0
# 2016-11-13     142   3431163.0
# 2016-12-04     145   3625775.0
# 2017-07-23      20   1205087.0
# 2017-07-30     179   4991752.0
# 2017-10-29      34   2041221.0
# 2018-01-28     205   6172173.0
# 2018-12-09     250   7303856.0
# 2019-09-22     133   9211699.0
# 2019-12-22     304   8652067.0
# 2020-03-22     159  12801240.0
# 2021-08-01      37    940203.0
# 2021-10-10     240  21425357.0
# 2022-09-11     288  26078981.0
# 2022-10-02      98   1973279.0
# 2023-05-14     323  29113102.0
# 2023-06-25     136   3803183.0
# 2023-08-06     142   4096924.0
# 2023-10-22     346  30988899.0
# 2023-11-12     156   4630339.0
# 2024-09-01     198   6017484.0
# 2024-09-15     200   6038586.0
# 2024-09-29     202   6058142.0
# 2024-11-10     208   6207882.0
# 2024-12-22     214   6391876.0
# 2025-01-19     411  35110897.0
# 2025-03-02     224   6666457.0
# 2025-03-02     224   6666457.0
# 2025-03-30     421  35495333.0
# 2025-04-06     422  35530374.0
# 2025-06-01     237   6862029.0
# 2025-06-08     431  35752038.0
# 2025-07-20       6   1522377.0

# %%
he.filter_event(delta_event_df, hw=['NSW', 'PS4'])
# Out:
#             event_date   hw hw2       event_name  priority  delta_week
# report_date
# 2016-09-11  2016-09-07  PS4              PS4Slim         1         133
# 2016-11-13  2016-11-10  PS4               PS4Pro         1         142
# 2016-12-04  2016-11-29  PS4                 FF15         1         145
# 2017-07-23  2017-07-21  NSW                 スプラ2         2          20
# 2017-07-30  2017-07-29  PS4                 DQ11         2         179
# 2017-10-29  2017-10-27  NSW                 マリオデ         1          34
# 2018-01-28  2018-01-26  PS4                  MHW         1         205
# 2018-12-09  2018-12-06  PS4             PS4大バンバン         1         250
# 2019-09-22  2019-09-20  NSW           SwitchLite         1         133
# 2019-12-22  2019-12-19  PS4           PS4数量限定セール         2         304
# 2020-03-22  2020-03-20  NSW                  あつ森         2         159
# 2021-10-10  2021-10-08  NSW           SwitchOLED         1         240
# 2022-09-11  2022-09-09  NSW                 スプラ3         2         288
# 2023-05-14  2023-05-12  NSW                 ToTK         2         323
# 2023-10-22  2023-10-20  NSW              マリオワンダー         3         346
# 2025-01-19  2025-01-16  NSW           Switch2初公開         2         411
# 2025-03-30  2025-03-27  NSW      Nintendo Direct         3         421
# 2025-04-06  2025-04-02  NSW       Switch2 Direct         1         422
# 2025-06-08  2025-06-05  NSW            Switch2発売         1         431

# %%
import sqlite3

DB_PATH = '/Users/hide/Documents/sqlite3/gamehard.db'

def load_hard_info() -> pd.DataFrame:
    """ハード情報の読み込み

    Returns:
        pd.DataFrame: ハード情報
    """
    # SQLite3データベースに接続
    conn = sqlite3.connect(DB_PATH)
    # SQLクエリを実行してデータをDataFrameに読み込む
    query = "SELECT * FROM gamehard_info;"
    df = pd.read_sql_query(query, conn)
    df['launch_date'] = pd.to_datetime(df['launch_date'])
    
    # 接続を閉じる
    conn.close()

    return df

# %%
df_hard_info = load_hard_info()

# %%
df_hard_event = he.load_hard_event()
df_hard_event = df_hard_event.reset_index()
df_event_merged = df_hard_event.merge(how='left', right=df_hard_info, left_on='hw', right_on="id")

# %%
df_event_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37 entries, 0 to 36
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   report_date  37 non-null     datetime64[ns]
#  1   event_date   37 non-null     datetime64[ns]
#  2   hw           37 non-null     object
#  3   hw2          37 non-null     object
#  4   event_name   37 non-null     object
#  5   priority     37 non-null     int64
#  6   id           37 non-null     object
#  7   launch_date  37 non-null     datetime64[ns]
#  8   maker_name   37 non-null     object
#  9   full_name    37 non-null     object
# dtypes: datetime64[ns](3), int64(1), object(6)
# memory usage: 3.2+ KB

# %%
# launch_dateとreport_dateの差を計算して新カラム　delta_weekを設定
df_event_merged['delta_week'] = (df_event_merged['report_date'] - df_event_merged['launch_date']).dt.days // 7

# %%
df_event_merged
# Out:
#    report_date event_date   hw hw2        event_name  priority   id  \
# 0   2016-09-11 2016-09-07  PS4               PS4Slim         1  PS4
# 1   2016-11-13 2016-11-10  PS4                PS4Pro         1  PS4
# 2   2016-12-04 2016-11-29  PS4                  FF15         1  PS4
# 3   2017-07-23 2017-07-21  NSW                  スプラ2         2  NSW
# 4   2017-07-30 2017-07-29  PS4                  DQ11         2  PS4
# 5   2017-10-29 2017-10-27  NSW                  マリオデ         1  NSW
# 6   2018-01-28 2018-01-26  PS4                   MHW         1  PS4
# 7   2018-12-09 2018-12-06  PS4              PS4大バンバン         1  PS4
# 8   2019-09-22 2019-09-20  NSW            SwitchLite         1  NSW
# 9   2019-12-22 2019-12-19  PS4            PS4数量限定セール         2  PS4
# 10  2020-03-22 2020-03-20  NSW                   あつ森         2  NSW
# 11  2021-08-01 2021-08-01  PS5           PS5 CFI1100         3  PS5
# 12  2021-10-10 2021-10-08  NSW            SwitchOLED         1  NSW
# 13  2022-09-11 2022-09-09  NSW                  スプラ3         2  NSW
# 14  2022-10-02 2022-10-01  PS5           PS5 CFI1200         3  PS5
# 15  2023-05-14 2023-05-12  NSW                  ToTK         2  NSW
# 16  2023-06-25 2023-06-22  PS5                  FF16         1  PS5
# 17  2023-08-06 2023-08-01  PS5                PS5値上げ         1  PS5
# 18  2023-10-22 2023-10-20  NSW               マリオワンダー         3  NSW
# 19  2023-11-12 2023-11-10  PS5               PS5Slim         1  PS5
# 20  2024-09-01 2024-08-27  PS5                PS5値上げ         1  PS5
# 21  2024-09-15 2024-09-11  PS5              PS5Pro発表         3  PS5
# 22  2024-09-29 2024-09-26  PS5       PS5サイインインキャンペーン         2  PS5
# 23  2024-11-10 2024-11-07  PS5                PS5Pro         1  PS5
# 24  2024-12-22 2024-12-19  PS5            PS5年末年始セール         2  PS5
# 25  2025-01-19 2025-01-16  NSW            Switch2初公開         2  NSW
# 26  2025-03-02 2025-02-28  PS5                  MHWs         1  PS5
# 27  2025-03-02 2025-02-28  PS5             PS5新生活セール         2  PS5
# 28  2025-03-30 2025-03-27  NSW       Nintendo Direct         3  NSW
# 29  2025-04-06 2025-04-02  NSW        Switch2 Direct         1  NSW
# 30  2025-06-01 2025-05-28  PS5      Days of Play2025         2  PS5
# 31  2025-06-08 2025-06-05  NSW             Switch2発売         1  NSW
# 2022-10-02        SONY      PlayStation5          98
# 2023-05-14    Nintendo   Nintendo Switch         323
# 2023-06-25        SONY      PlayStation5         136
# 2023-08-06        SONY      PlayStation5         142
# 2023-10-22    Nintendo   Nintendo Switch         346
# 2023-11-12        SONY      PlayStation5         156
# 2024-09-01        SONY      PlayStation5         198
# 2024-09-15        SONY      PlayStation5         200
# 2024-09-29        SONY      PlayStation5         202
# 2024-11-10        SONY      PlayStation5         208
# 2024-12-22        SONY      PlayStation5         214
# 2025-01-19    Nintendo   Nintendo Switch         411
# 2025-03-02        SONY      PlayStation5         224
# 2025-03-02        SONY      PlayStation5         224
# 2025-03-30    Nintendo   Nintendo Switch         421
# 2025-04-06    Nintendo   Nintendo Switch         422
# 2025-06-01        SONY      PlayStation5         237
# 2025-06-08    Nintendo   Nintendo Switch         431
# 2025-07-20    Nintendo  Nintendo Switch2           6
# 2025-09-07        SONY      PlayStation5         251
# 2025-09-14        SONY      PlayStation5         252
# 2025-10-19    Nintendo  Nintendo Switch2          19
# 2025-11-23    Nintendo  Nintendo Switch2          24

# %%
df_hard_info
# Out:
#          id launch_date maker_name             full_name
# 0       PS5  2020-11-12       SONY          PlayStation5
# 1       XSX  2020-11-10  Microsoft       Xbox Series X|S
# 2       NSW  2017-03-03   Nintendo       Nintendo Switch
# 3       NS2  2025-06-05   Nintendo      Nintendo Switch2
# 4     XBOne  2014-09-04  Microsoft               XboxOne
# 5       PS4  2014-02-22       SONY          PlayStation4
# 6      WiiU  2012-12-08   Nintendo                  WiiU
# 7      Vita  2011-12-17       SONY      PlayStation Vita
# 8       3DS  2011-02-26   Nintendo          Nintendo 3DS
# 9       Wii  2006-12-02   Nintendo                   Wii
# 10      PS3  2006-11-11       SONY          PlayStation3
# 11    XB360  2005-12-10  Microsoft               Xbox360
# 12       DS  2004-12-02   Nintendo           Nintendo DS
# 13      PSP  2004-12-12       SONY  PlayStation Portable
# 14     Xbox  2002-02-22  Microsoft                  Xbox
# 15       GC  2001-09-14   Nintendo     Nintendo GAMECUBE
# 16      GBA  2001-03-21   Nintendo      GAME BOY ADVANCE
# 17      PS2  2000-03-04       SONY          PlayStation2
# 18       WS  1999-03-04     BANDAI            WonderSwan
# 19      PKS  1999-01-23       SONY         PocketStation
# 20       DC  1998-11-27       SEGA             DreamCast
# 21  NeoGeoP  1998-10-28        SNK         NeoGeo Pocket
# 22       GB  1989-04-21   Nintendo              GAME BOY
# 23      N64  1996-06-23   Nintendo            NINTENDO64
# 24       PS  1994-12-03       SONY           PlayStation
# 25   SATURN  1994-11-22       SEGA           SEGA SATURN

# %%
(fig, df) = ph.plot_cumulative_sales_by_delta(hw=['PS4', 'PS5'], end=270, event_priority=1, event_flag=True)

# %%
(fig, df) = ph.plot_cumulative_sales_by_delta(hw=['PS4', 'PS5'], begin=195, end=255,
                                              event_priority=1, event_flag=True)

# %%
(fig, df) = ph.plot_sales_by_delta(hw=["NSW", "NS2"], end=22, ymax=180000, xgrid=2, ygrid=20000, mode="week", event_flag=True)
