# %%
# %load_ext autoreload
# %autoreload 2

# %%
### 週販レポート2025年版

# 標準ライブラリ
from datetime import datetime, timedelta

# サードパーティライブラリ
import pandas as pd
from pandas import Timedelta
import matplotlib.pyplot as plt
import japanize_matplotlib
from matplotlib.ticker import ScalarFormatter
from IPython.display import Markdown, display

# プロジェクト内モジュール
import gamedata as g

# %% [markdown]
# ## plot_cumulative_sales_by_delta

# %%
(pcsd_fig, pcsd_df) = g.plot_cumulative_sales_by_delta(hw=['PS5', 'NS2', 'NSW'], 
                                                        mode='week',
                                                        end=100,
                                                        event_mask=g.EVENT_MASK_MIDDLE)

# %%
pcsd_df.head(10)
# Out:
# ┌────────────┬─────────┬───────────┬─────────┐
# │ delta_week ┆ NSW     ┆ NS2       ┆ PS5     │
# ╞════════════╪═════════╪═══════════╪═════════╡
# │ 0          ┆ 330,637 ┆ 715,432   ┆ 118,085 │
# │ 1          ┆ 394,057 ┆ 868,637   ┆ 160,976 │
# │ 2          ┆ 444,878 ┆ 1,008,663 ┆ 201,435 │
# │ 3          ┆ 524,371 ┆ 1,169,684 ┆ 213,328 │
# │ 4          ┆ 556,633 ┆ 1,298,327 ┆ 224,384 │
# │ 5          ┆ 601,904 ┆ 1,370,212 ┆ 241,962 │
# │ 6          ┆ 644,604 ┆ 1,522,377 ┆ 255,150 │
# │ 7          ┆ 684,971 ┆ 1,614,390 ┆ 265,782 │
# │ 8          ┆ 759,188 ┆ 1,677,123 ┆ 276,946 │
# │ 9          ┆ 806,541 ┆ 1,766,943 ┆ 284,274 │
# └────────────┴─────────┴───────────┴─────────┘

# %% [markdown]
# ## plot_sales

# %%
(ps_fig, ps_df) = g.plot_sales(hw=['PS5', 'NSW', 'PS4', 'XSX'],
                                begin=datetime(2024, 1, 1),
                                end=datetime(2024,12,31),
                                event_mask=g.EVENT_MASK_MIDDLE)

# %%
(psm_fig, psm_df) = g.plot_sales(hw=['PS5', 'NSW', 'PS4', 'XSX'],
                                begin=datetime(2024, 1, 1),
                                end=datetime(2024,12,31),
                                mode='month')

# %%
psm_df.head(10)
# Out:
# ┌───────┬───────┬─────────┬─────────┬────────┬───────┐
# │ year  ┆ month ┆ NSW     ┆ PS5     ┆ XSX    ┆ PS4   │
# ╞═══════╪═══════╪═════════╪═════════╪════════╪═══════╡
# │ 2,024 ┆ 1     ┆ 241,282 ┆ 185,480 ┆ 8,281  ┆ 2,574 │
# │ 2,024 ┆ 2     ┆ 190,786 ┆ 146,945 ┆ 11,030 ┆ 2,374 │
# │ 2,024 ┆ 3     ┆ 289,673 ┆ 162,281 ┆ 10,329 ┆ 5,055 │
# │ 2,024 ┆ 4     ┆ 257,515 ┆ 91,981  ┆ 10,185 ┆ 341   │
# │ 2,024 ┆ 5     ┆ 185,821 ┆ 87,218  ┆ 11,783 ┆ 365   │
# │ 2,024 ┆ 6     ┆ 225,316 ┆ 117,592 ┆ 9,357  ┆ 1,215 │
# │ 2,024 ┆ 7     ┆ 229,316 ┆ 123,087 ┆ 13,176 ┆ 874   │
# │ 2,024 ┆ 8     ┆ 227,913 ┆ 104,178 ┆ 9,023  ┆ 153   │
# │ 2,024 ┆ 9     ┆ 308,404 ┆ 74,523  ┆ 4,091  ┆ 221   │
# │ 2,024 ┆ 10    ┆ 245,466 ┆ 47,615  ┆ 6,419  ┆ 148   │
# └───────┴───────┴─────────┴─────────┴────────┴───────┘

# %%
(psmq_fig, psmq_df) = g.plot_sales(hw=['PS5', 'NSW', 'PS4', 'XSX', 'NS2'],
                                begin=datetime(2017, 1, 1),
                                end=datetime(2025,12,31),
                                mode='quarter',
                                event_mask=g.EVENT_MASK_LONG)

# %%
psmq_df.tail(10)
# Out:
# ┌─────────┬────────┬───────────┬─────────┬────────┬───────────┐
# │ quarter ┆ PS4    ┆ NSW       ┆ PS5     ┆ XSX    ┆ NS2       │
# ╞═════════╪════════╪═══════════╪═════════╪════════╪═══════════╡
# │ 2023Q3  ┆ 18,078 ┆ 1,048,979 ┆ 605,800 ┆ 37,164 ┆ 0         │
# │ 2023Q4  ┆ 17,883 ┆ 1,071,264 ┆ 555,874 ┆ 33,195 ┆ 0         │
# │ 2024Q1  ┆ 10,003 ┆ 721,741   ┆ 494,706 ┆ 29,640 ┆ 0         │
# │ 2024Q2  ┆ 1,921  ┆ 668,652   ┆ 296,791 ┆ 31,325 ┆ 0         │
# │ 2024Q3  ┆ 1,248  ┆ 765,633   ┆ 301,788 ┆ 26,290 ┆ 0         │
# │ 2024Q4  ┆ 556    ┆ 953,077   ┆ 360,864 ┆ 30,966 ┆ 0         │
# │ 2025Q1  ┆ 323    ┆ 599,556   ┆ 356,773 ┆ 15,693 ┆ 0         │
# │ 2025Q2  ┆ 314    ┆ 298,116   ┆ 134,500 ┆ 6,577  ┆ 1,169,684 │
# │ 2025Q3  ┆ 237    ┆ 234,995   ┆ 146,656 ┆ 3,917  ┆ 939,938   │
# │ 2025Q4  ┆ 213    ┆ 387,717   ┆ 241,275 ┆ 5,039  ┆ 1,674,445 │
# └─────────┴────────┴───────────┴─────────┴────────┴───────────┘

# %% [markdown]
# ## plot_sales_by_delta

# %%
(psd_fig, psd_df) = g.plot_sales_by_delta(hw=['NSW', 'NS2'], begin=0, end=50)
psd_df.head(10)
# Out:
# hw               NS2       NSW
# delta_week
# 0           715432.0  330637.0
# 1           153205.0   63420.0
# 2           140026.0   50821.0
# 3           161021.0   79493.0
# 4           128643.0   32262.0
# 5            71885.0   45271.0
# 6           152165.0   42700.0
# 7            92013.0   40367.0
# 8            62733.0   74217.0
# 9            89820.0   47353.0

# %%
(pso_fig, pso_df) = g.plot_sales_with_offset(
                              hw_periods=[
                              {'hw': 'NSW', 'begin': datetime(2017,12,30)},
                              {'hw': 'NS2', 'begin': datetime(2025,12,30)},
                              ],
                          end = 15)

pso_df
# Out:
# label        NS2:2025.12.30〜  NSW:2017.12.30〜
# offset_week
# 0                   156919.0         115255.0
# 1                   156919.0         159636.0
# 2                    67509.0          31189.0
# 3                        NaN          38749.0
# 4                        NaN          39473.0
# 5                        NaN          46517.0
# 6                        NaN          43522.0
# 7                        NaN          40655.0
# 8                        NaN          41294.0
# 9                        NaN          43801.0
# 10                       NaN          45746.0
# 11                       NaN          47841.0
# 12                       NaN          51563.0
# 13                       NaN          41402.0
# 14                       NaN          36341.0

# %%
(psps5_fig, psps5_df) = g.plot_sales_with_offset(
                              hw_periods=[
                              {'hw': 'PS5', 'begin': datetime(2023,12,1)},
                              {'hw': 'PS5', 'begin': datetime(2024,12,1)},
                              {'hw': 'PS5', 'begin': datetime(2025,12,1)},
                              ],
                          end = 15)

psps5_df
# Out:
# label        PS5:2023.12.01〜  PS5:2024.12.01〜  PS5:2025.12.01〜
# offset_week
# 0                    43946.0          38160.0          25240.0
# 1                    44166.0          50365.0          18912.0
# 2                    42316.0          21574.0          19307.0
# 3                    40971.0          24650.0          19232.0
# 4                    40972.0          27130.0          23376.0
# 5                    41126.0          46680.0          23377.0
# 6                    36506.0          11828.0           9983.0
# 7                    57903.0          10738.0              NaN
# 8                    49945.0          12341.0              NaN
# 9                    34484.0          12873.0              NaN
# 10                   40745.0          14408.0              NaN
# 11                   38212.0          16049.0              NaN
# 12                   33504.0          13556.0              NaN
# 13                   48067.0         108978.0              NaN
# 14                   39064.0          52520.0              NaN

# %% [markdown]
# ## plot_cumulative_sales

# %%
(pcs_fig, pcs_df) = g.plot_cumulative_sales(hw=['PS5', 'NSW', 'NS2'], mode='month')
pcs_df.tail(10)
# Out:
# hw                 NS2         NSW        PS5
# report_date
# 2025-04-30         NaN  35608846.0  6814762.0
# 2025-05-31         NaN  35715352.0  6846763.0
# 2025-06-30   1169684.0  35793449.0  6910279.0
# 2025-07-31   1614390.0  35850981.0  6939238.0
# 2025-08-31   1934080.0  35945498.0  6978242.0
# 2025-09-30   2109622.0  36028444.0  7056935.0
# 2025-10-31   2468021.0  36124524.0  7121667.0
# 2025-11-30   2968435.0  36262542.0  7215519.0
# 2025-12-31   3784067.0  36416161.0  7298210.0
# 2026-01-31   4165414.0  36489755.0  7354946.0

# %% [markdown]
# ## plot_cumsum_diffs

# %%
(pcd_fig, pcd_df) = g.plot_cumsum_diffs([('NSW', 'PS4'), ('NS2', 'PS5')])
pcd_df.head(10)
# Out:
# hw   PS4_NSW差   PS5_NS2差
# 0   4359277.0  6862029.0
# 1   4065277.0  6167379.0
# 2   4036422.0  6028303.0
# 3   4018033.0  5894283.0
# 4   3969019.0  5740595.0
# 5   3965065.0  5620581.0
# 6   3941870.0  5555958.0
# 7   3921237.0  5409941.0
# 8   3899716.0  5324848.0
# 9   3850255.0  5269256.0

# %% [markdown]
# ## plot_sales_pase_diff

# %%
(pspd_fig, pspd_df) = g.plot_sales_pase_diff(base_hw='PS4', compare_hw='PS5')
pspd_df.tail(80)
# Out:
#      PS5累計_PS4累計差 ps4_report_date ps5_report_date
# 191      433415.0      2017-10-22      2024-07-14
# 192      445547.0      2017-10-29      2024-07-21
# 193      439379.0      2017-11-05      2024-07-28
# 194      435531.0      2017-11-12      2024-08-04
# 195      427115.0      2017-11-19      2024-08-11
# ..            ...             ...             ...
# 266     -702772.0      2019-03-31      2025-12-21
# 267     -697394.0      2019-04-07      2025-12-28
# 268     -685811.0      2019-04-14      2026-01-04
# 269     -673797.0      2019-04-21      2026-01-11
# 270     -677981.0      2019-04-28      2026-01-18
#
# [80 rows x 3 columns]
