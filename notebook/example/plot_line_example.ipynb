# %%
# %load_ext autoreload
# %autoreload 2

# %%
### 週販レポート2025年版

# 標準ライブラリ
from datetime import datetime, timedelta

# サードパーティライブラリ
import pandas as pd
from pandas import Timedelta
import matplotlib.pyplot as plt
import japanize_matplotlib
from matplotlib.ticker import ScalarFormatter
from IPython.display import Markdown, display

# プロジェクト内モジュール
import gamedata as g

# %% [markdown]
# ## plot_cumulative_sales_by_delta

# %%
(pcsd_fig, pcsd_df) = g.plot_cumulative_sales_by_delta(hw=['PS5', 'NS2', 'NSW'], 
                                                        mode='week',
                                                        end=100,
                                                        event_mask=g.EVENT_MASK_MIDDLE)

# %%
pcsd_df.head(10)
# Out:
# hw                NS2       NSW       PS5
# delta_week
# 0            715432.0  330637.0  118085.0
# 1            868637.0  394057.0  160976.0
# 2           1008663.0  444878.0  201435.0
# 3           1169684.0  524371.0  213328.0
# 4           1298327.0  556633.0  224384.0
# 5           1370212.0  601904.0  241962.0
# 6           1522377.0  644604.0  255150.0
# 7           1614390.0  684971.0  265782.0
# 8           1677123.0  759188.0  276946.0
# 9           1766943.0  806541.0  284274.0

# %% [markdown]
# ## plot_sales

# %%
(ps_fig, ps_df) = g.plot_sales(hw=['PS5', 'NSW', 'PS4', 'XSX'],
                                begin=datetime(2024, 1, 1),
                                end=datetime(2024,12,31),
                                event_mask=g.EVENT_MASK_MIDDLE)

# %%
(psm_fig, psm_df) = g.plot_sales(hw=['PS5', 'NSW', 'PS4', 'XSX'],
                                begin=datetime(2024, 1, 1),
                                end=datetime(2024,12,31),
                                mode='month')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'report_date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 (psm_fig, psm_df) = g.plot_sales(hw=['PS5', 'NSW', 'PS4', 'XSX'],
#       2                                 begin=datetime(2024, 1, 1),
#       3                                 end=datetime(2024,12,31),
#       4                                 mode='month')
#
# File ~/Documents/Development/gamedata/src/gamedata/plot_line.py:313, in plot_sales(hw, mode, begin, end, ymax, xgrid, ygrid, event_mask, area, ticklabelsize)
#     310 if ticklabelsize is not None:
#     311     tick_params_fn = lambda: pu.TickParams(labelsize=ticklabelsize)
# --> 313 return _plot_sales(
#     314     data_source=data_source,
#     315     labeler=labeler,
#     316     tick_params_fn=tick_params_fn,
#     317     annotation_positioner=annotation_positioner,
#     318     ymax=ymax,
#     319     ybottom=0,
#     320     xgrid=xgrid,
#     321     ygrid=ygrid,
#     322     area=area,
#     323 )
#
# File ~/Documents/Development/gamedata/src/gamedata/plot_line.py:76, in _plot_sales(data_source, labeler, tick_params_fn, annotation_positioner, ymax, ybottom, xgrid, ygrid, plot_style, area)
#      49 def _plot_sales(
#      50     data_source,
#      51     labeler=None,
#    (...)     59     area: bool = False,
#      60 ) -> tuple[Figure, pd.DataFrame]:
#      61     """
#      62     各ハードウェアの販売台数をプロット共通関数
#      63
#    (...)     74         pd.DataFrame: プロットに使用したデータのDataFrame
#      75     """
# ---> 76     (df, title_key) = data_source()
#      78     plt.ioff()
#      79     fig, ax = plt.subplots(figsize=pu.get_figsize())
#
# File ~/Documents/Development/gamedata/src/gamedata/plot_line.py:292, in plot_sales.<locals>.data_source()
#     290     title_key = '年'
#     291 else:
# --> 292     df = pv.pivot_sales(df, hw=hw, begin=begin, end=end)
#     293     title_key = '週'
#     294 return (df, title_key)
#
# File ~/Documents/Development/gamedata/src/gamedata/hard_sales_pivot.py:31, in pivot_sales(src_df, hw, begin, end)
#      29 # begin/endでフィルタリング
#      30 if begin is not None and end is not None:
# ---> 31     df = src_df.loc[(src_df['report_date'] >= begin) & (src_df['report_date'] <= end)]
#      32 elif begin is not None:
#      33     df = src_df.loc[src_df['report_date'] >= begin]
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'report_date'

# %%
(psm_fig, psm_df) = g.plot_sales(hw=['PS5', 'NSW', 'PS4', 'XSX', 'NS2'],
                                begin=datetime(2017, 1, 1),
                                end=datetime(2025,12,31),
                                mode='quarter',
                                event_mask=g.EVENT_MASK_LONG)

# %%
psm_df.tail(10)
# Out:
# hw             NSW   PS4     PS5    XSX
# year month
# 2024 3      289673  5055  162281  10329
#      4      257515   341   91981  10185
#      5      185821   365   87218  11783
#      6      225316  1215  117592   9357
#      7      229316   874  123087  13176
#      8      227913   153  104178   9023
#      9      308404   221   74523   4091
#      10     245466   148   47615   6419
#      11     255401   171  151370  10742
#      12     452210   237  161879  13805

# %% [markdown]
# ## plot_sales_by_delta

# %%
(psd_fig, psd_df) = g.plot_sales_by_delta(hw=['NSW', 'NS2'], begin=0, end=50)
psd_df.head(10)
# Out:
# hw               NS2       NSW
# delta_week
# 0           715432.0  330637.0
# 1           153205.0   63420.0
# 2           140026.0   50821.0
# 3           161021.0   79493.0
# 4           128643.0   32262.0
# 5            71885.0   45271.0
# 6           152165.0   42700.0
# 7            92013.0   40367.0
# 8            62733.0   74217.0
# 9            89820.0   47353.0

# %% [markdown]
# ## plot_cumulative_sales

# %%
(pcs_fig, pcs_df) = g.plot_cumulative_sales(hw=['PS5', 'NSW', 'NS2'], mode='month')
pcs_df.tail(10)
# Out:
# hw                 NS2         NSW        PS5
# report_date
# 2025-04-30         NaN  35608846.0  6814762.0
# 2025-05-31         NaN  35715352.0  6846763.0
# 2025-06-30   1169684.0  35793449.0  6910279.0
# 2025-07-31   1614390.0  35850981.0  6939238.0
# 2025-08-31   1934080.0  35945498.0  6978242.0
# 2025-09-30   2109622.0  36028444.0  7056935.0
# 2025-10-31   2468021.0  36124524.0  7121667.0
# 2025-11-30   2968435.0  36262542.0  7215519.0
# 2025-12-31   3784067.0  36416161.0  7298210.0
# 2026-01-31   4165414.0  36489755.0  7354946.0

# %% [markdown]
# ## plot_cumsum_diffs

# %%
(pcd_fig, pcd_df) = g.plot_cumsum_diffs([('NSW', 'PS4'), ('NS2', 'PS5')])
pcd_df.head(10)
# Out:
# hw   PS4_NSW差   PS5_NS2差
# 0   4359277.0  6862029.0
# 1   4065277.0  6167379.0
# 2   4036422.0  6028303.0
# 3   4018033.0  5894283.0
# 4   3969019.0  5740595.0
# 5   3965065.0  5620581.0
# 6   3941870.0  5555958.0
# 7   3921237.0  5409941.0
# 8   3899716.0  5324848.0
# 9   3850255.0  5269256.0

# %% [markdown]
# ## plot_sales_pase_diff

# %%
(pspd_fig, pspd_df) = g.plot_sales_pase_diff(base_hw='PS4', compare_hw='PS5')
pspd_df.tail(80)
# Out:
#      PS5累計_PS4累計差 ps4_report_date ps5_report_date
# 191      433415.0      2017-10-22      2024-07-14
# 192      445547.0      2017-10-29      2024-07-21
# 193      439379.0      2017-11-05      2024-07-28
# 194      435531.0      2017-11-12      2024-08-04
# 195      427115.0      2017-11-19      2024-08-11
# ..            ...             ...             ...
# 266     -702772.0      2019-03-31      2025-12-21
# 267     -697394.0      2019-04-07      2025-12-28
# 268     -685811.0      2019-04-14      2026-01-04
# 269     -673797.0      2019-04-21      2026-01-11
# 270     -677981.0      2019-04-28      2026-01-18
#
# [80 rows x 3 columns]
