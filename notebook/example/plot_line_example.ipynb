# %%
# %load_ext autoreload
# %autoreload 2

# %%
### 週販レポート2025年版

# 標準ライブラリ
from datetime import datetime, timedelta

# サードパーティライブラリ
import polars as pl
import matplotlib.pyplot as plt
import japanize_matplotlib
from matplotlib.ticker import ScalarFormatter
from IPython.display import Markdown, display

# プロジェクト内モジュール
import gamedata as g

# %% [markdown]
# ## plot_cumulative_sales_by_delta

# %%
(pcsd_fig, pcsd_df) = g.plot_cumulative_sales_by_delta(hw=['PS5', 'NS2', 'NSW'], 
                                                        mode='week',
                                                        end=100,
                                                        event_mask=g.EVENT_MASK_MIDDLE)

# %%
pcsd_df.head(10)
# Out:
# ┌────────────┬─────────┬─────────┬───────────┐
# │ delta_week ┆ PS5     ┆ NSW     ┆ NS2       │
# │ ---        ┆ ---     ┆ ---     ┆ ---       │
# │ i32        ┆ i64     ┆ i64     ┆ i64       │
# ╞════════════╪═════════╪═════════╪═══════════╡
# │ 0          ┆ 118,085 ┆ 330,637 ┆ 715,432   │
# │ 1          ┆ 160,976 ┆ 394,057 ┆ 868,637   │
# │ 2          ┆ 201,435 ┆ 444,878 ┆ 1,008,663 │
# │ 3          ┆ 213,328 ┆ 524,371 ┆ 1,169,684 │
# │ 4          ┆ 224,384 ┆ 556,633 ┆ 1,298,327 │
# │ 5          ┆ 241,962 ┆ 601,904 ┆ 1,370,212 │
# │ 6          ┆ 255,150 ┆ 644,604 ┆ 1,522,377 │
# │ 7          ┆ 265,782 ┆ 684,971 ┆ 1,614,390 │
# │ 8          ┆ 276,946 ┆ 759,188 ┆ 1,677,123 │
# │ 9          ┆ 284,274 ┆ 806,541 ┆ 1,766,943 │
# └────────────┴─────────┴─────────┴───────────┘

# %% [markdown]
# ## plot_sales

# %%
(ps_fig, ps_df) = g.plot_sales(hw=['PS5', 'NSW', 'PS4', 'XSX'],
                                begin=datetime(2025, 1, 1),
                                end=datetime(2025,12,31),
                                event_mask=g.EVENT_MASK_SHORT)

# %%
ps_df.head(10)
# Out:
# ┌─────────────┬─────────┬─────┬─────────┬───────┐
# │ report_date ┆ NSW     ┆ PS4 ┆ PS5     ┆ XSX   │
# │ ---         ┆ ---     ┆ --- ┆ ---     ┆ ---   │
# │ date        ┆ i64     ┆ i64 ┆ i64     ┆ i64   │
# ╞═════════════╪═════════╪═════╪═════════╪═══════╡
# │ 2025-01-05  ┆ 109,729 ┆ 35  ┆ 46,680  ┆ 1,113 │
# │ 2025-01-12  ┆ 57,831  ┆ 31  ┆ 11,828  ┆ 876   │
# │ 2025-01-19  ┆ 47,560  ┆ 29  ┆ 10,738  ┆ 785   │
# │ 2025-01-26  ┆ 45,327  ┆ 31  ┆ 12,341  ┆ 1,087 │
# │ 2025-02-02  ┆ 44,341  ┆ 19  ┆ 12,873  ┆ 3,070 │
# │ 2025-02-09  ┆ 43,672  ┆ 21  ┆ 14,408  ┆ 2,320 │
# │ 2025-02-16  ┆ 40,003  ┆ 23  ┆ 16,049  ┆ 2,826 │
# │ 2025-02-23  ┆ 39,172  ┆ 22  ┆ 13,556  ┆ 1,535 │
# │ 2025-03-02  ┆ 45,189  ┆ 20  ┆ 108,978 ┆ 721   │
# │ 2025-03-09  ┆ 37,841  ┆ 22  ┆ 52,520  ┆ 559   │
# └─────────────┴─────────┴─────┴─────────┴───────┘

# %%
(psm_fig, psm_df) = g.plot_sales(hw=['PS5', 'NSW', 'PS4', 'XSX'],
                                begin=datetime(2023, 10, 1),
                                end=datetime(2024,12,31),
                                mode='month')

# %%
psm_df.head(10)
# Out:
# ┌────────────┬─────────┬─────────┬────────┬───────┐
# │ month      ┆ NSW     ┆ PS5     ┆ XSX    ┆ PS4   │
# │ ---        ┆ ---     ┆ ---     ┆ ---    ┆ ---   │
# │ date       ┆ i64     ┆ i64     ┆ i64    ┆ i64   │
# ╞════════════╪═════════╪═════════╪════════╪═══════╡
# │ 2023-10-31 ┆ 339,650 ┆ 112,186 ┆ 12,658 ┆ 5,940 │
# │ 2023-11-30 ┆ 296,274 ┆ 231,317 ┆ 12,574 ┆ 5,362 │
# │ 2023-12-31 ┆ 435,340 ┆ 212,371 ┆ 7,963  ┆ 6,581 │
# │ 2024-01-31 ┆ 241,282 ┆ 185,480 ┆ 8,281  ┆ 2,574 │
# │ 2024-02-29 ┆ 190,786 ┆ 146,945 ┆ 11,030 ┆ 2,374 │
# │ 2024-03-31 ┆ 289,673 ┆ 162,281 ┆ 10,329 ┆ 5,055 │
# │ 2024-04-30 ┆ 257,515 ┆ 91,981  ┆ 10,185 ┆ 341   │
# │ 2024-05-31 ┆ 185,821 ┆ 87,218  ┆ 11,783 ┆ 365   │
# │ 2024-06-30 ┆ 225,316 ┆ 117,592 ┆ 9,357  ┆ 1,215 │
# │ 2024-07-31 ┆ 229,316 ┆ 123,087 ┆ 13,176 ┆ 874   │
# └────────────┴─────────┴─────────┴────────┴───────┘

# %%
(psmq_fig, psmq_df) = g.plot_sales(hw=['PS5', 'NSW', 'PS4', 'XSX', 'NS2'],
                                begin=datetime(2017, 1, 1),
                                end=datetime(2025,12,31),
                                mode='quarter',
                                event_mask=g.EVENT_MASK_LONG)
# Out:
# Warning: event_mask is ignored when mode is not 'week'.

# %%
psmq_df.tail(10)
# Out:
# ┌─────────┬────────┬───────────┬─────────┬────────┬───────────┐
# │ quarter ┆ PS4    ┆ NSW       ┆ PS5     ┆ XSX    ┆ NS2       │
# │ ---     ┆ ---    ┆ ---       ┆ ---     ┆ ---    ┆ ---       │
# │ str     ┆ i64    ┆ i64       ┆ i64     ┆ i64    ┆ i64       │
# ╞═════════╪════════╪═══════════╪═════════╪════════╪═══════════╡
# │ 2023Q3  ┆ 18,078 ┆ 1,048,979 ┆ 605,800 ┆ 37,164 ┆ null      │
# │ 2023Q4  ┆ 17,883 ┆ 1,071,264 ┆ 555,874 ┆ 33,195 ┆ null      │
# │ 2024Q1  ┆ 10,003 ┆ 721,741   ┆ 494,706 ┆ 29,640 ┆ null      │
# │ 2024Q2  ┆ 1,921  ┆ 668,652   ┆ 296,791 ┆ 31,325 ┆ null      │
# │ 2024Q3  ┆ 1,248  ┆ 765,633   ┆ 301,788 ┆ 26,290 ┆ null      │
# │ 2024Q4  ┆ 556    ┆ 953,077   ┆ 360,864 ┆ 30,966 ┆ null      │
# │ 2025Q1  ┆ 323    ┆ 599,556   ┆ 356,773 ┆ 15,693 ┆ null      │
# │ 2025Q2  ┆ 314    ┆ 298,116   ┆ 134,500 ┆ 6,577  ┆ 1,169,684 │
# │ 2025Q3  ┆ 237    ┆ 234,995   ┆ 146,656 ┆ 3,917  ┆ 939,938   │
# │ 2025Q4  ┆ 213    ┆ 387,717   ┆ 241,275 ┆ 5,039  ┆ 1,674,445 │
# └─────────┴────────┴───────────┴─────────┴────────┴───────────┘

# %% [markdown]
# ## plot_sales_by_delta

# %%
(psd_fig, psd_df) = g.plot_sales_by_delta(hw=['NSW', 'NS2'], begin=0, end=50, mode='week',
                                          event_mask=g.EVENT_MASK_MIDDLE)
psd_df.head(5)
# Out:
# ┌────────────┬─────────┬─────────┐
# │ delta_week ┆ NSW     ┆ NS2     │
# │ ---        ┆ ---     ┆ ---     │
# │ i32        ┆ i64     ┆ i64     │
# ╞════════════╪═════════╪═════════╡
# │ 0          ┆ 330,637 ┆ 715,432 │
# │ 1          ┆ 63,420  ┆ 153,205 │
# │ 2          ┆ 50,821  ┆ 140,026 │
# │ 3          ┆ 79,493  ┆ 161,021 │
# │ 4          ┆ 32,262  ┆ 128,643 │
# └────────────┴─────────┴─────────┘

# %%
(pso_fig, pso_df) = g.plot_sales_with_offset(
                              hw_periods=[
                              {'hw': 'NSW', 'begin': datetime(2017,12,30)},
                              {'hw': 'NS2', 'begin': datetime(2025,12,30)},
                              ],
                          end = 15)

pso_df
# Out:
# ┌─────────────┬──────────────────┬──────────────────┐
# │ offset_week ┆ NSW:2017.12.30〜 ┆ NS2:2025.12.30〜 │
# │ ---         ┆ ---              ┆ ---              │
# │ i32         ┆ i64              ┆ i64              │
# ╞═════════════╪══════════════════╪══════════════════╡
# │ 0           ┆ 115,255          ┆ 156,919          │
# │ 1           ┆ 159,636          ┆ 156,919          │
# │ 2           ┆ 31,189           ┆ 67,509           │
# │ 3           ┆ 38,749           ┆ 72,086           │
# │ 4           ┆ 39,473           ┆ 69,586           │
# │ 5           ┆ 46,517           ┆ null             │
# │ 6           ┆ 43,522           ┆ null             │
# │ 7           ┆ 40,655           ┆ null             │
# │ 8           ┆ 41,294           ┆ null             │
# │ 9           ┆ 43,801           ┆ null             │
# │ 10          ┆ 45,746           ┆ null             │
# │ 11          ┆ 47,841           ┆ null             │
# │ 12          ┆ 51,563           ┆ null             │
# │ 13          ┆ 41,402           ┆ null             │
# │ 14          ┆ 36,341           ┆ null             │
# └─────────────┴──────────────────┴──────────────────┘

# %%
(psps5_fig, psps5_df) = g.plot_sales_with_offset(
                              hw_periods=[
                              {'hw': 'PS5', 'begin': datetime(2023,12,1)},
                              {'hw': 'PS5', 'begin': datetime(2024,12,1)},
                              {'hw': 'PS5', 'begin': datetime(2025,12,1)},
                              ],
                          end = 15)

psps5_df
# Out:
# ┌─────────────┬──────────────────┬──────────────────┬──────────────────┐
# │ offset_week ┆ PS5:2023.12.01〜 ┆ PS5:2024.12.01〜 ┆ PS5:2025.12.01〜 │
# │ ---         ┆ ---              ┆ ---              ┆ ---              │
# │ i32         ┆ i64              ┆ i64              ┆ i64              │
# ╞═════════════╪══════════════════╪══════════════════╪══════════════════╡
# │ 0           ┆ 43,946           ┆ 38,160           ┆ 25,240           │
# │ 1           ┆ 44,166           ┆ 50,365           ┆ 18,912           │
# │ 2           ┆ 42,316           ┆ 21,574           ┆ 19,307           │
# │ 3           ┆ 40,971           ┆ 24,650           ┆ 19,232           │
# │ 4           ┆ 40,972           ┆ 27,130           ┆ 23,376           │
# │ 5           ┆ 41,126           ┆ 46,680           ┆ 23,377           │
# │ 6           ┆ 36,506           ┆ 11,828           ┆ 9,983            │
# │ 7           ┆ 57,903           ┆ 10,738           ┆ 9,766            │
# │ 8           ┆ 49,945           ┆ 12,341           ┆ 10,949           │
# │ 9           ┆ 34,484           ┆ 12,873           ┆ 11,130           │
# │ 10          ┆ 40,745           ┆ 14,408           ┆ 11,588           │
# │ 11          ┆ 38,212           ┆ 16,049           ┆ null             │
# │ 12          ┆ 33,504           ┆ 13,556           ┆ null             │
# │ 13          ┆ 48,067           ┆ 108,978          ┆ null             │
# │ 14          ┆ 39,064           ┆ 52,520           ┆ null             │
# └─────────────┴──────────────────┴──────────────────┴──────────────────┘

# %% [markdown]
# ## plot_cumulative_sales

# %%
(pcs_fig, pcs_df) = g.plot_cumulative_sales(hw=['PS5', 'NSW', 'NS2'], mode='week', event_mask=g.EVENT_MASK_LONG)
pcs_df.tail(10)
# Out:
# ┌─────────────┬────────────┬───────────┬───────────┐
# │ report_date ┆ NSW        ┆ PS5       ┆ NS2       │
# │ ---         ┆ ---        ┆ ---       ┆ ---       │
# │ date        ┆ i64        ┆ i64       ┆ i64       │
# ╞═════════════╪════════════╪═══════════╪═══════════╡
# │ 2025-12-14  ┆ 36,345,202 ┆ 7,259,671 ┆ 3,362,777 │
# │ 2025-12-21  ┆ 36,383,386 ┆ 7,278,978 ┆ 3,583,810 │
# │ 2025-12-28  ┆ 36,416,161 ┆ 7,298,210 ┆ 3,784,067 │
# │ 2026-01-04  ┆ 36,439,341 ┆ 7,321,586 ┆ 3,940,986 │
# │ 2026-01-11  ┆ 36,462,521 ┆ 7,344,963 ┆ 4,097,905 │
# │ 2026-01-18  ┆ 36,489,755 ┆ 7,354,946 ┆ 4,165,414 │
# │ 2026-01-25  ┆ 36,507,270 ┆ 7,364,712 ┆ 4,237,500 │
# │ 2026-02-01  ┆ 36,517,948 ┆ 7,375,661 ┆ 4,307,086 │
# │ 2026-02-08  ┆ 36,526,840 ┆ 7,386,791 ┆ 4,372,893 │
# │ 2026-02-15  ┆ 36,553,321 ┆ 7,398,379 ┆ 4,430,672 │
# └─────────────┴────────────┴───────────┴───────────┘

# %% [markdown]
# ## plot_cumsum_diffs

# %%
(pcd_fig, pcd_df) = g.plot_cumsum_diffs([('NSW', 'PS4'), ('NS2', 'PS5')])
# Out:
# ---------------------------------------------------------------------------
# ColumnNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 (pcd_fig, pcd_df) = g.plot_cumsum_diffs([('NSW', 'PS4'), ('NS2', 'PS5')])
#
# File ~/Documents/Development/gamedata/src/gamedata/plot_line.py:547, in plot_cumsum_diffs(cmplist, ymax, xgrid, ygrid)
#     539 def labeler(title_key: str) -> pu.AxisLabels:
#     540     return pu.AxisLabels(
#     541         title=f'累計販売台数差',
#     542         xlabel='販売開始からの週数',
#     543         ylabel='累計販売台数の差',
#     544         legend='販売台数差分'
#     545     )
# --> 547 return _plot_sales(
#     548     data_source=data_source,
#     549     labeler=labeler,
#     550
#     551     ymax=ymax,
#     552     ybottom=0,
#     553     xgrid=xgrid,
#     554     ygrid=ygrid,
#     555     plot_style={'marker': None}
#     556 )
#
# File ~/Documents/Development/gamedata/src/gamedata/plot_line.py:77, in _plot_sales(data_source, labeler, tick_params_fn, annotation_positioner, ymax, ybottom, xgrid, ygrid, plot_style, area)
#      50 def _plot_sales(
#      51     data_source,
#      52     labeler=None,
#    (...)     60     area: bool = False,
#      61 ) -> tuple[Figure, pl.DataFrame]:
#      62     """
#      63     各ハードウェアの販売台数をプロット共通関数
#      64
#    (...)     75         pl.DataFrame: プロットに使用したデータのDataFrame
#      76     """
# ---> 77     (df, title_key) = data_source()
#      78     pd_df = df.to_pandas()
#      79     pd_df = pd_df.set_index(pd_df.columns[0])
#
# File ~/Documents/Development/gamedata/src/gamedata/plot_line.py:535, in plot_cumsum_diffs.<locals>.data_source()
#     533 def data_source() -> tuple[pl.DataFrame, str]:
#     534     df = hs.load_hard_sales()
# --> 535     df = pv.cumsum_diffs(df, cmplist)
#     536     title_key = '週'
#     537     return (df, title_key)
#
# File ~/Documents/Development/gamedata/src/gamedata/hard_sales_pivot.py:500, in cumsum_diffs(df, cmplist)
#     498 diff_dfs = []
#     499 for base_hw, cmp_hw in cmplist:
# --> 500     diff_df = cumsum_diff_frame(df, base_hw, cmp_hw)
#     501     diff_dfs.append(diff_df)
#     503 # 最初のDataFrameをベースに、他のDataFrameをrow_nrで結合
#
# File ~/Documents/Development/gamedata/src/gamedata/hard_sales_pivot.py:489, in cumsum_diffs.<locals>.cumsum_diff_frame(df, base_hw, cmp_hw)
#     481 # base_hwがnullでない行を抽出し、差分を計算
#     482 diff_col_name = f"{cmp_hw}_{base_hw}差"
#     483 pivot_df = (
#     484     pivot_df
#     485     .filter(pl.col(base_hw).is_not_null())
#     486     .with_columns(
#     487         diff_col_name = pl.col(cmp_hw) - pl.col(base_hw)
#     488     )
# --> 489     .filter(pl.col(diff_col_name) >= -10000)
#     490     .select(['row_nr', diff_col_name])
#     491 )
#     493 # 行番号を0から振り直す
#     494 pivot_df = pivot_df.with_row_index('new_row_nr').drop('row_nr').rename({'new_row_nr': 'row_nr'})
#
# File /opt/homebrew/lib/python3.11/site-packages/polars/dataframe/frame.py:5345, in DataFrame.filter(self, *predicates, **constraints)
#    5185 """
#    5186 Filter rows, retaining those that match the given predicate expression(s).
#    5187
#    (...)   5338 └──────┴──────┴─────┘
#    5339 """
#    5340 from polars.lazyframe.opt_flags import QueryOptFlags
#    5342 return (
#    5343     self.lazy()
#    5344     .filter(*predicates, **constraints)
# -> 5345     .collect(optimizations=QueryOptFlags._eager())
#    5346 )
#
# File /opt/homebrew/lib/python3.11/site-packages/polars/_utils/deprecation.py:97, in deprecate_streaming_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      93         kwargs["engine"] = "in-memory"
#      95     del kwargs["streaming"]
# ---> 97 return function(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/polars/lazyframe/opt_flags.py:324, in forward_old_opt_flags.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     321         optflags = cb(optflags, kwargs.pop(key))  # type: ignore[no-untyped-call,unused-ignore]
#     323 kwargs["optimizations"] = optflags
# --> 324 return function(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/polars/lazyframe/frame.py:2429, in LazyFrame.collect(self, type_coercion, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, cluster_with_columns, collapse_joins, no_optimization, engine, background, optimizations, **_kwargs)
#    2427 # Only for testing purposes
#    2428 callback = _kwargs.get("post_opt_callback", callback)
# -> 2429 return wrap_df(ldf.collect(engine, callback))
#
# ColumnNotFoundError: unable to find column "PS4_NSW差"; valid columns: ["row_nr", "report_date", "PS4", "NSW", "diff_col_name"]

# %%
pcd_df.filter(pl.col('weeks') >= 30).head(10)
# Out:
# ┌───────┬───────────┬───────────┐
# │ weeks ┆ PS4_NSW差 ┆ PS5_NS2差 │
# │ ---   ┆ ---       ┆ ---       │
# │ u32   ┆ i64       ┆ i64       │
# ╞═══════╪═══════════╪═══════════╡
# │ 30    ┆ 3,529,438 ┆ 3,514,143 │
# │ 31    ┆ 3,489,502 ┆ 3,380,600 │
# │ 32    ┆ 3,476,475 ┆ 3,247,058 │
# │ 33    ┆ 3,465,734 ┆ 3,189,532 │
# │ 34    ┆ 3,473,849 ┆ 3,127,212 │
# │ 35    ┆ 3,366,878 ┆ 3,068,575 │
# │ 36    ┆ 3,334,864 ┆ null      │
# │ 37    ┆ 3,279,912 ┆ null      │
# │ 38    ┆ 3,221,471 ┆ null      │
# │ 39    ┆ 3,115,531 ┆ null      │
# └───────┴───────────┴───────────┘

# %% [markdown]
# ## plot_sales_pase_diff

# %%
(pspd_fig, pspd_df) = g.plot_sales_pase_diff(base_hw='PS4', compare_hw='PS5')
pspd_df.tail(80)
# Out:
# ┌────────────┬───────────────────┬─────────────────┬─────────────────┐
# │ delta_week ┆ PS5累計_PS4累計差 ┆ ps4_report_date ┆ ps5_report_date │
# │ ---        ┆ ---               ┆ ---             ┆ ---             │
# │ i32        ┆ i64               ┆ date            ┆ date            │
# ╞════════════╪═══════════════════╪═════════════════╪═════════════════╡
# │ 193        ┆ 439,379           ┆ 2017-11-05      ┆ 2024-07-28      │
# │ 194        ┆ 435,531           ┆ 2017-11-12      ┆ 2024-08-04      │
# │ 195        ┆ 427,115           ┆ 2017-11-19      ┆ 2024-08-11      │
# │ 196        ┆ 422,755           ┆ 2017-11-26      ┆ 2024-08-18      │
# │ 197        ┆ 422,730           ┆ 2017-12-03      ┆ 2024-08-25      │
# │ 198        ┆ 377,353           ┆ 2017-12-10      ┆ 2024-09-01      │
# │ 199        ┆ 315,218           ┆ 2017-12-17      ┆ 2024-09-08      │
# │ 200        ┆ 254,732           ┆ 2017-12-24      ┆ 2024-09-15      │
# │ 201        ┆ 205,307           ┆ 2017-12-31      ┆ 2024-09-22      │
# │ 202        ┆ 112,499           ┆ 2018-01-07      ┆ 2024-09-29      │
# │ 203        ┆ 83,862            ┆ 2018-01-14      ┆ 2024-10-06      │
# │ 204        ┆ 50,756            ┆ 2018-01-21      ┆ 2024-10-13      │
# │ 205        ┆ -78,361           ┆ 2018-01-28      ┆ 2024-10-20      │
# │ 206        ┆ -175,702          ┆ 2018-02-04      ┆ 2024-10-27      │
# │ 207        ┆ -231,909          ┆ 2018-02-11      ┆ 2024-11-03      │
# │ …          ┆ …                 ┆ …               ┆ …               │
# │ 258        ┆ -664,251          ┆ 2019-02-03      ┆ 2025-10-26      │
# │ 259        ┆ -676,695          ┆ 2019-02-10      ┆ 2025-11-02      │
# │ 260        ┆ -690,575          ┆ 2019-02-17      ┆ 2025-11-09      │
# │ 261        ┆ -703,092          ┆ 2019-02-24      ┆ 2025-11-16      │
# │ 262        ┆ -688,511          ┆ 2019-03-03      ┆ 2025-11-23      │
# │ 263        ┆ -682,674          ┆ 2019-03-10      ┆ 2025-11-30      │
# │ 264        ┆ -687,382          ┆ 2019-03-17      ┆ 2025-12-07      │
# │ 265        ┆ -698,216          ┆ 2019-03-24      ┆ 2025-12-14      │
# │ 266        ┆ -702,772          ┆ 2019-03-31      ┆ 2025-12-21      │
# │ 267        ┆ -697,394          ┆ 2019-04-07      ┆ 2025-12-28      │
# │ 268        ┆ -685,811          ┆ 2019-04-14      ┆ 2026-01-04      │
# │ 269        ┆ -673,797          ┆ 2019-04-21      ┆ 2026-01-11      │
# │ 270        ┆ -677,981          ┆ 2019-04-28      ┆ 2026-01-18      │
# │ 271        ┆ -683,216          ┆ 2019-05-05      ┆ 2026-01-25      │
# │ 272        ┆ -687,269          ┆ 2019-05-12      ┆ 2026-02-01      │
# └────────────┴───────────────────┴─────────────────┴─────────────────┘
