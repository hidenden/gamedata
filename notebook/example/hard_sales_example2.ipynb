# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib widget

### 累計レポート
# 標準ライブラリ
import os
from datetime import datetime, timedelta
from typing import List, Dict, Tuple, Optional, Callable

# サードパーティライブラリ
import polars as pl
import matplotlib.pyplot as plt
import japanize_matplotlib
from matplotlib.ticker import ScalarFormatter
from IPython.display import Markdown, display

# プロジェクト内モジュール
import gamedata as g

# %%
df_all = g.load_hard_sales()

ex1 = g.extract_latest(df_all)
ex1
# Out:
# ┌─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┐
# │ wee ┆ beg ┆ end ┆ rep ┆ per ┆ hw  ┆ uni ┆ adj ┆ yea ┆ mon ┆ mda ┆ wee ┆ del ┆ del ┆ del ┆ del ┆ avg ┆ sum ┆ lau ┆ mak ┆ ful ┆ qua │
# │ kly ┆ in_ ┆ _da ┆ ort ┆ iod ┆ --- ┆ ts  ┆ ust ┆ r   ┆ th  ┆ y   ┆ k   ┆ ta_ ┆ ta_ ┆ ta_ ┆ ta_ ┆ _un ┆ _un ┆ nch ┆ er_ ┆ l_n ┆ rte │
# │ _id ┆ dat ┆ te  ┆ _da ┆ _da ┆ str ┆ --- ┆ _un ┆ --- ┆ --- ┆ --- ┆ --- ┆ day ┆ wee ┆ mon ┆ yea ┆ its ┆ its ┆ _da ┆ nam ┆ ame ┆ r   │
# │ --- ┆ e   ┆ --- ┆ te  ┆ te  ┆     ┆ i64 ┆ its ┆ i16 ┆ i16 ┆ i16 ┆ i16 ┆ --- ┆ k   ┆ th  ┆ r   ┆ --- ┆ --- ┆ te  ┆ e   ┆ --- ┆ --- │
# │ str ┆ --- ┆ dat ┆ --- ┆ --- ┆     ┆     ┆ --- ┆     ┆     ┆     ┆     ┆ i32 ┆ --- ┆ --- ┆ --- ┆ i64 ┆ i64 ┆ --- ┆ --- ┆ str ┆ str │
# │     ┆ dat ┆ e   ┆ dat ┆ i16 ┆     ┆     ┆ i64 ┆     ┆     ┆     ┆     ┆     ┆ i32 ┆ i16 ┆ i16 ┆     ┆     ┆ dat ┆ str ┆     ┆     │
# ...

# %%
hw_summary_df = df_all.sort("hw", "delta_week").unique(subset="hw", keep="last")
ps4_summary_df = hw_summary_df.filter((pl.col("hw") == "PS4") | (pl.col("hw") == "PS3"))
ps4_summary_df.transpose(include_header=True, column_names=ps4_summary_df["hw"].to_list())
# Out:
# ┌──────────────┬────────────────┬────────────────┐
# │ column       ┆ PS3            ┆ PS4            │
# │ ---          ┆ ---            ┆ ---            │
# │ str          ┆ str            ┆ str            │
# ╞══════════════╪════════════════╪════════════════╡
# │ weekly_id    ┆ 2015-12-13_PS3 ┆ 2026-03-29_PS4 │
# │ begin_date   ┆ 2015-12-07     ┆ 2026-03-23     │
# │ end_date     ┆ 2015-12-13     ┆ 2026-03-29     │
# │ report_date  ┆ 2015-12-13     ┆ 2026-03-29     │
# │ period_date  ┆ 7              ┆ 7              │
# │ hw           ┆ PS3            ┆ PS4            │
# │ units        ┆ 1903           ┆ 16             │
# │ adjust_units ┆ 0              ┆ 0              │
# │ year         ┆ 2015           ┆ 2026           │
# │ month        ┆ 12             ┆ 3              │
# │ mday         ┆ 13             ┆ 29             │
# │ week         ┆ 2              ┆ 5              │
# │ delta_day    ┆ 3319           ┆ 4418           │
# ...

# %%
ps3_summary_df = hw_summary_df.filter(pl.col("hw") == "PS3")
ps3_summary_df.transpose(include_header=True)
# Out:
# ┌──────────────┬────────────────┐
# │ column       ┆ column_0       │
# │ ---          ┆ ---            │
# │ str          ┆ str            │
# ╞══════════════╪════════════════╡
# │ weekly_id    ┆ 2015-12-13_PS3 │
# │ begin_date   ┆ 2015-12-07     │
# │ end_date     ┆ 2015-12-13     │
# │ report_date  ┆ 2015-12-13     │
# │ period_date  ┆ 7              │
# │ hw           ┆ PS3            │
# │ units        ┆ 1903           │
# │ adjust_units ┆ 0              │
# │ year         ┆ 2015           │
# │ month        ┆ 12             │
# │ mday         ┆ 13             │
# │ week         ┆ 2              │
# │ delta_day    ┆ 3319           │
# │ delta_week   ┆ 474            │
# │ delta_month  ┆ 109            │
# │ delta_year   ┆ 9              │
# │ avg_units    ┆ 271            │
# │ sum_units    ┆ 10080894       │
# │ launch_date  ┆ 2006-11-11     │
# │ maker_name   ┆ SONY           │
# │ full_name    ┆ PlayStation3   │
# │ quarter      ┆ 2015Q4         │
# ...
