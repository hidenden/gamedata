# %%
# %load_ext autoreload
# %autoreload 2

# %%
### 週販レポート2025年版

# 標準ライブラリ
from datetime import datetime, timedelta

# サードパーティライブラリ
import pandas as pd
from pandas import Timedelta
import matplotlib.pyplot as plt
import japanize_matplotlib
from matplotlib.ticker import ScalarFormatter
from IPython.display import Markdown, display

# プロジェクト内モジュール
from gamedata import hard_sales as hs
from gamedata import plot_hard as ph
from gamedata import hard_info as hi
from gamedata import hard_event as he

# %% [markdown]
# ## load_hard_sales

# %%
base_df = hs.load_hard_sales()
base_df
# Out:
#               weekly_id begin_date   end_date report_date  period_date  \
# 0         1998-10-18_GB 1998-10-12 1998-10-18  1998-10-18            7
# 1        1998-10-18_N64 1998-10-12 1998-10-18  1998-10-18            7
# 2         1998-10-18_PS 1998-10-12 1998-10-18  1998-10-18            7
# 3     1998-10-18_SATURN 1998-10-12 1998-10-18  1998-10-18            7
# 4         1998-10-25_GB 1998-10-19 1998-10-25  1998-10-25            7
# ...                 ...        ...        ...         ...          ...
# 8544     2025-12-21_NS2 2025-12-15 2025-12-21  2025-12-21            7
# 8545     2025-12-21_NSW 2025-12-15 2025-12-21  2025-12-21            7
# 8546     2025-12-21_PS4 2025-12-15 2025-12-21  2025-12-21            7
# 8547     2025-12-21_PS5 2025-12-15 2025-12-21  2025-12-21            7
# 8548     2025-12-21_XSX 2025-12-15 2025-12-21  2025-12-21            7
#
#           hw   units  adjust_units  year  month  ...  week  delta_day  \
# ...

# %% [markdown]
# ## extract_week_reached_units

# %%
ex_df = hs.extract_week_reached_units(base_df, threshold_units=2_000_000)
ex_df
# Out:
#             weekly_id begin_date   end_date report_date  period_date    hw  \
# 4411   2011-10-09_3DS 2011-10-03 2011-10-09  2011-10-09            7   3DS
# 2272    2005-05-01_DS 2005-04-25 2005-05-01  2005-05-01            7    DS
# 154     1999-04-25_GB 1999-04-19 1999-04-25  1999-04-25            7    GB
# 1018   2001-06-17_GBA 2001-06-11 2001-06-17  2001-06-17            7   GBA
# 1627    2003-01-05_GC 2002-12-30 2003-01-05  2003-01-05            7    GC
# 8474   2025-09-14_NS2 2025-09-08 2025-09-14  2025-09-14            7   NS2
# 6509   2017-10-29_NSW 2017-10-23 2017-10-29  2017-10-29            7   NSW
# 325    1999-10-10_PKS 1999-10-04 1999-10-10  1999-10-10            7   PKS
# 277     1999-08-22_PS 1999-08-16 1999-08-22  1999-08-22            7    PS
# 602    2000-06-25_PS2 2000-06-19 2000-06-25  2000-06-25            7   PS2
# 3277   2008-03-30_PS3 2008-03-24 2008-03-30  2008-03-30            7   PS3
# ...

# %% [markdown]
# ## extract_by_date

# %%
za_df = hs.extract_by_date(base_df, target_date=datetime(2025,10,16), hw=["NS2", "PS5"])
za_df
# Out:
#            weekly_id begin_date   end_date report_date  period_date   hw  \
# 8499  2025-10-19_NS2 2025-10-13 2025-10-19  2025-10-19            7  NS2
# 8502  2025-10-19_PS5 2025-10-13 2025-10-19  2025-10-19            7  PS5
#
#        units  adjust_units  year  month  ...  week  delta_day  delta_week  \
# 8499  201684             0  2025     10  ...     3        136          19
# 8502   12085             0  2025     10  ...     3       1802         257
#
#       delta_month  delta_year  avg_units  sum_units  launch_date maker_name  \
# 8499            4           0      28812    2402587   2025-06-05   Nintendo
# 8502           59           5       1726    7111164   2020-11-12       SONY
#
#              full_name
# 8499  Nintendo Switch2
# 8502      PlayStation5
#
# [2 rows x 21 columns]

# %% [markdown]
# ## extract_latest

# %%
latest_df = hs.extract_latest(base_df, 4)
latest_df
# Out:
#            weekly_id begin_date   end_date report_date  period_date   hw  \
# 8529  2025-11-30_NS2 2025-11-24 2025-11-30  2025-11-30            7  NS2
# 8530  2025-11-30_NSW 2025-11-24 2025-11-30  2025-11-30            7  NSW
# 8531  2025-11-30_PS4 2025-11-24 2025-11-30  2025-11-30            7  PS4
# 8532  2025-11-30_PS5 2025-11-24 2025-11-30  2025-11-30            7  PS5
# 8533  2025-11-30_XSX 2025-11-24 2025-11-30  2025-11-30            7  XSX
# 8534  2025-12-07_NS2 2025-12-01 2025-12-07  2025-12-07            7  NS2
# 8535  2025-12-07_NSW 2025-12-01 2025-12-07  2025-12-07            7  NSW
# 8536  2025-12-07_PS4 2025-12-01 2025-12-07  2025-12-07            7  PS4
# 8537  2025-12-07_PS5 2025-12-01 2025-12-07  2025-12-07            7  PS5
# 8538  2025-12-07_XSX 2025-12-01 2025-12-07  2025-12-07            7  XSX
# 8539  2025-12-14_NS2 2025-12-08 2025-12-14  2025-12-14            7  NS2
# 8540  2025-12-14_NSW 2025-12-08 2025-12-14  2025-12-14            7  NSW
# ...

# %% [markdown]
# ## current_report_date

# %%
current_date = hs.current_report_date(base_df)
current_date
# Out:
# Timestamp('2025-12-21 00:00:00')

# %% [markdown]
# ## get_hw

# %%
hw_list = hs.get_hw(latest_df)
hw_list
# Out:
# ['NS2', 'NSW', 'PS4', 'PS5', 'XSX']

# %% [markdown]
# ## get_active_hw

# %%
hw_list = hs.get_active_hw()
hw_list
# Out:
# ['NSW', 'PS4', 'PS5', 'XSX', 'NS2']

# %% [markdown]
# ## weekly_sales

# %%
weekly_df = hs.weekly_sales(base_df, begin=datetime(2025,1,1))
weekly_df
# Out:
#     report_date   hw  weekly_units  sum_units
# 0    2025-01-05  NSW        109729     109729
# 1    2025-01-05  PS4            35         35
# 2    2025-01-05  PS5         46680      46680
# 3    2025-01-05  XSX          1113       1113
# 4    2025-01-12  NSW         57831     167560
# ..          ...  ...           ...        ...
# 228  2025-12-21  NS2        221033    3583810
# 229  2025-12-21  NSW         38184    1487609
# 230  2025-12-21  PS4            12       1072
# 231  2025-12-21  PS5         19307     859972
# 232  2025-12-21  XSX           184      30929
#
# [233 rows x 4 columns]

# %% [markdown]
# ## monthly_sales

# %%
monthly_df = hs.monthly_sales(base_df, begin=datetime(2024,1,1))
monthly_df
# Out:
#      year  month   hw  monthly_units  sum_units
# 0    2024      1  3DS             57         57
# 1    2024      1  NSW         241282     241282
# 2    2024      1  PS4           2574       2574
# 3    2024      1  PS5         185480     185480
# 4    2024      1  XSX           8281       8281
# ..    ...    ...  ...            ...        ...
# 101  2025     12  NS2         615375    3583810
# 102  2025     12  NSW         120844    4596712
# 103  2025     12  PS4             45      14800
# 104  2025     12  PS5          63459    2314121
# 105  2025     12  XSX            598     149150
#
# [106 rows x 5 columns]

# %% [markdown]
# ## yearly_sales

# %%
yearly_df = hs.yearly_sales(base_df, begin=datetime(2020,1,1), maker_mode=True)
yearly_df
# Out:
#     year maker_name  yearly_units  sum_units
# 0   2020  Microsoft         35009      35009
# 1   2020   Nintendo       6019704    6019704
# 2   2020       SONY        797797     797797
# 3   2021  Microsoft         97234     132243
# 4   2021   Nintendo       5607667   11627371
# 5   2021       SONY       1072239    1870036
# 6   2022  Microsoft        269737     401980
# 7   2022   Nintendo       4815210   16442581
# 8   2022       SONY       1176877    3046913
# 9   2023  Microsoft        141712     543692
# 10  2023   Nintendo       4065642   20508223
# 11  2023       SONY       2660760    5707673
# 12  2024  Microsoft        118221     661913
# 13  2024   Nintendo       3109265   23617488
# 14  2024       SONY       1467877    7175550
# 15  2025  Microsoft         30929     692842
# 16  2025   Nintendo       5071419   28688907
# 17  2025       SONY        861044    8036594

# %% [markdown]
# ## yearly_maker_sales

# %%
mk_df = hs.yearly_maker_sales(base_df, begin=datetime(2020,1,1))
mk_df
# Out:
#     year maker_name  yearly_units
# 0   2020  Microsoft         35009
# 1   2020   Nintendo       6019704
# 2   2020       SONY        797797
# 3   2021  Microsoft         97234
# 4   2021   Nintendo       5607667
# 5   2021       SONY       1072239
# 6   2022  Microsoft        269737
# 7   2022   Nintendo       4815210
# 8   2022       SONY       1176877
# 9   2023  Microsoft        141712
# 10  2023   Nintendo       4065642
# 11  2023       SONY       2660760
# 12  2024  Microsoft        118221
# 13  2024   Nintendo       3109265
# 14  2024       SONY       1467877
# 15  2025  Microsoft         30929
# 16  2025   Nintendo       5071419
# 17  2025       SONY        861044

# %% [markdown]
# ## delta_yearly_sales

# %%
dys_df = hs.delta_yearly_sales(base_df)
dys_df
# Out:
#      delta_year   hw  yearly_units  sum_units
# 0             0  3DS       4132038    4132038
# 1             0   DC        270095     270095
# 2             0   DS       1056428    1056428
# 3             0  GBA       4245686    4245686
# 4             0   GC        929832     929832
# ..          ...  ...           ...        ...
# 183          12  PS2         26201   21231208
# 184          13  3DS           162   24388294
# 185          13   GB        109226    6380746
# 186          13  PS2          4689   21235897
# 187          14   GB          8948    6389694
#
# [188 rows x 4 columns]
