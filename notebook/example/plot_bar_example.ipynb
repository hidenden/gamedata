# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline

# %%
# 標準ライブラリ
from datetime import datetime, timedelta

# サードパーティライブラリ
import pandas as pd
import polars as pl
from pandas import Timedelta
import matplotlib.pyplot as plt
import japanize_matplotlib
from matplotlib.ticker import ScalarFormatter
from IPython.display import Markdown, display

# プロジェクト内モジュール
import gamedata as g

# %% [markdown]
# ## plot_monthly_bar_by_year

# %%
(mbyfig, mbydf) = g.plot_monthly_bar_by_year(hw='PS5', begin=datetime(2023,1,1))

# %%
mbydf
# Out:
# ┌───────┬─────────┬─────────┬─────────┬────────┐
# │ month ┆ 2023    ┆ 2024    ┆ 2025    ┆ 2026   │
# ╞═══════╪═════════╪═════════╪═════════╪════════╡
# │ 1     ┆ 234,329 ┆ 185,480 ┆ 81,587  ┆ 66,502 │
# │ 2     ┆ 366,982 ┆ 146,945 ┆ 56,886  ┆ 10,949 │
# │ 3     ┆ 222,656 ┆ 162,281 ┆ 218,300 ┆ 0      │
# │ 4     ┆ 219,646 ┆ 91,981  ┆ 38,983  ┆ 0      │
# │ 5     ┆ 166,660 ┆ 87,218  ┆ 32,001  ┆ 0      │
# │ 6     ┆ 215,521 ┆ 117,592 ┆ 63,516  ┆ 0      │
# │ 7     ┆ 243,383 ┆ 123,087 ┆ 28,959  ┆ 0      │
# │ 8     ┆ 181,361 ┆ 104,178 ┆ 39,004  ┆ 0      │
# │ 9     ┆ 181,056 ┆ 74,523  ┆ 78,693  ┆ 0      │
# │ 10    ┆ 112,186 ┆ 47,615  ┆ 64,732  ┆ 0      │
# │ 11    ┆ 231,317 ┆ 151,370 ┆ 93,852  ┆ 0      │
# │ 12    ┆ 212,371 ┆ 161,879 ┆ 82,691  ┆ 0      │
# └───────┴─────────┴─────────┴─────────┴────────┘

# %% [markdown]
# ## plot_quarterly_bar_by_year

# %%
(qyps5fig, qyps5df) = g.plot_quarterly_bar_by_year(hw='PS5')

# %%
qyps5df
# Out:
# ┌───────┬─────────┬─────────┬─────────┬─────────┬─────────┬─────────┬────────┐
# │ q_num ┆ 2020    ┆ 2021    ┆ 2022    ┆ 2023    ┆ 2024    ┆ 2025    ┆ 2026   │
# ╞═══════╪═════════╪═════════╪═════════╪═════════╪═════════╪═════════╪════════╡
# │ 4     ┆ 255,150 ┆ 151,139 ┆ 422,186 ┆ 555,874 ┆ 360,864 ┆ 241,275 ┆ 0      │
# │ 1     ┆ 0       ┆ 325,061 ┆ 274,182 ┆ 823,967 ┆ 494,706 ┆ 356,773 ┆ 77,451 │
# │ 2     ┆ 0       ┆ 278,372 ┆ 205,667 ┆ 601,827 ┆ 296,791 ┆ 134,500 ┆ 0      │
# │ 3     ┆ 0       ┆ 213,613 ┆ 252,019 ┆ 605,800 ┆ 301,788 ┆ 146,656 ┆ 0      │
# └───────┴─────────┴─────────┴─────────┴─────────┴─────────┴─────────┴────────┘

# %% [markdown]
# ## plot_monthly_bar_by_hard

# %%
(mbhfig, mbhdf) = g.plot_monthly_bar_by_hard(hw=['PS5',  'NSW'], begin=datetime(2024,1,1), ticklabelsize=5)

# %%
mbhdf
# Out:
# ┌────────────┬─────────┬─────────┐
# │ year_month ┆ NSW     ┆ PS5     │
# ╞════════════╪═════════╪═════════╡
# │ 2024-01    ┆ 241,282 ┆ 185,480 │
# │ 2024-02    ┆ 190,786 ┆ 146,945 │
# │ 2024-03    ┆ 289,673 ┆ 162,281 │
# │ 2024-04    ┆ 257,515 ┆ 91,981  │
# │ 2024-05    ┆ 185,821 ┆ 87,218  │
# │ 2024-06    ┆ 225,316 ┆ 117,592 │
# │ 2024-07    ┆ 229,316 ┆ 123,087 │
# │ 2024-08    ┆ 227,913 ┆ 104,178 │
# │ 2024-09    ┆ 308,404 ┆ 74,523  │
# │ 2024-10    ┆ 245,466 ┆ 47,615  │
# │ 2024-11    ┆ 255,401 ┆ 151,370 │
# │ 2024-12    ┆ 452,210 ┆ 161,879 │
# │ 2025-01    ┆ 260,447 ┆ 81,587  │
# │ 2025-02    ┆ 167,188 ┆ 56,886  │
# │ 2025-03    ┆ 171,921 ┆ 218,300 │
# │ 2025-04    ┆ 113,513 ┆ 38,983  │
# │ 2025-05    ┆ 106,506 ┆ 32,001  │
# │ 2025-06    ┆ 78,097  ┆ 63,516  │
# │ 2025-07    ┆ 57,532  ┆ 28,959  │
# │ 2025-08    ┆ 94,517  ┆ 39,004  │
# │ 2025-09    ┆ 82,946  ┆ 78,693  │
# │ 2025-10    ┆ 96,080  ┆ 64,732  │
# │ 2025-11    ┆ 138,018 ┆ 93,852  │
# │ 2025-12    ┆ 153,619 ┆ 82,691  │
# │ 2026-01    ┆ 91,109  ┆ 66,502  │
# │ 2026-02    ┆ 10,678  ┆ 10,949  │
# └────────────┴─────────┴─────────┘

# %%
(qhfig, qhdf) = g.plot_quarterly_bar_by_hard(hw=['PS5', 'NSW', 'NS2'],
                             begin=datetime(2023,1,1), end=datetime(2025,12,31),
                             ticklabelsize=6)

# %%
qhdf
# Out:
# ┌─────────┬───────────┬─────────┬───────────┐
# │ quarter ┆ NSW       ┆ PS5     ┆ NS2       │
# ╞═════════╪═══════════╪═════════╪═══════════╡
# │ 2023Q1  ┆ 879,808   ┆ 823,967 ┆ 0         │
# │ 2023Q2  ┆ 1,062,558 ┆ 601,827 ┆ 0         │
# │ 2023Q3  ┆ 1,048,979 ┆ 605,800 ┆ 0         │
# │ 2023Q4  ┆ 1,071,264 ┆ 555,874 ┆ 0         │
# │ 2024Q1  ┆ 721,741   ┆ 494,706 ┆ 0         │
# │ 2024Q2  ┆ 668,652   ┆ 296,791 ┆ 0         │
# │ 2024Q3  ┆ 765,633   ┆ 301,788 ┆ 0         │
# │ 2024Q4  ┆ 953,077   ┆ 360,864 ┆ 0         │
# │ 2025Q1  ┆ 599,556   ┆ 356,773 ┆ 0         │
# │ 2025Q2  ┆ 298,116   ┆ 134,500 ┆ 1,169,684 │
# │ 2025Q3  ┆ 234,995   ┆ 146,656 ┆ 939,938   │
# │ 2025Q4  ┆ 387,717   ┆ 241,275 ┆ 1,674,445 │
# └─────────┴───────────┴─────────┴───────────┘

# %% [markdown]
# ## plot_monthly_bar_by_hard_year

# %%
(pmhy_fig, pmhy_df) = g.plot_monthly_bar_by_hard_year(hwy=[("NSW", 2017),("NS2", 2025)])

# %%
pmhy_df.sum()
# Out:
# ┌───────┬───────────┬───────────┐
# │ month ┆ NSW_2017  ┆ NS2_2025  │
# ╞═══════╪═══════════╪═══════════╡
# │ 75    ┆ 3,407,158 ┆ 3,784,067 │
# └───────┴───────────┴───────────┘

# %%
pmhy_df
# Out:
# ┌───────┬──────────┬───────────┐
# │ month ┆ NSW_2017 ┆ NS2_2025  │
# ╞═══════╪══════════╪═══════════╡
# │ 3     ┆ 524,371  ┆ 0         │
# │ 4     ┆ 234,817  ┆ 0         │
# │ 5     ┆ 127,314  ┆ 0         │
# │ 6     ┆ 129,971  ┆ 1,169,684 │
# │ 7     ┆ 294,311  ┆ 444,706   │
# │ 8     ┆ 254,489  ┆ 319,690   │
# │ 9     ┆ 168,810  ┆ 175,542   │
# │ 10    ┆ 307,138  ┆ 358,399   │
# │ 11    ┆ 372,619  ┆ 500,414   │
# │ 12    ┆ 993,318  ┆ 815,632   │
# └───────┴──────────┴───────────┘

# %%
(qhyfig, qhydf) = g.plot_quarterly_bar_by_hard_year(hwy=[("PS5", 2023), ("NSW", 2017), ("NS2", 2025)],
                             ticklabelsize=6)

# %%
s_qhydf = g.style_sales(qhydf)
display(s_qhydf)
# Out:
# <style type="text/css">
# #T_047e2_row0_col0, #T_047e2_row0_col1, #T_047e2_row0_col2, #T_047e2_row1_col0, #T_047e2_row1_col1, #T_047e2_row1_col2, #T_047e2_row2_col0, #T_047e2_row2_col1, #T_047e2_row2_col2, #T_047e2_row3_col0, #T_047e2_row3_col1, #T_047e2_row3_col2 {
#   text-align: right;
# }
# </style>
# <table id="T_047e2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_047e2_level0_col0" class="col_heading level0 col0" >PS5_2023</th>
#       <th id="T_047e2_level0_col1" class="col_heading level0 col1" >NSW_2017</th>
#       <th id="T_047e2_level0_col2" class="col_heading level0 col2" >NS2_2025</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >q_num</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_047e2_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_047e2_row0_col0" class="data row0 col0" >823,967</td>
#       <td id="T_047e2_row0_col1" class="data row0 col1" >524,371</td>
#       <td id="T_047e2_row0_col2" class="data row0 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_047e2_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_047e2_row1_col0" class="data row1 col0" >601,827</td>
#       <td id="T_047e2_row1_col1" class="data row1 col1" >492,102</td>
#       <td id="T_047e2_row1_col2" class="data row1 col2" >1,169,684</td>
#     </tr>
#     <tr>
#       <th id="T_047e2_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_047e2_row2_col0" class="data row2 col0" >605,800</td>
#       <td id="T_047e2_row2_col1" class="data row2 col1" >717,610</td>
#       <td id="T_047e2_row2_col2" class="data row2 col2" >939,938</td>
#     </tr>
#     <tr>
#       <th id="T_047e2_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_047e2_row3_col0" class="data row3 col0" >555,874</td>
#       <td id="T_047e2_row3_col1" class="data row3 col1" >1,673,075</td>
#       <td id="T_047e2_row3_col2" class="data row3 col2" >1,674,445</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## plot_yearly_bar_by_hard

# %%
(fig, df) = g.plot_yearly_bar_by_hard(hw=['PS5',  'NSW'], begin=datetime(2020,1,1), ticklabelsize=5)

# %%
df
# Out:
# ┌───────┬───────────┬───────────┐
# │ year  ┆ NSW       ┆ PS5       │
# ╞═══════╪═══════════╪═══════════╡
# │ 2,020 ┆ 5,956,943 ┆ 255,150   │
# │ 2,021 ┆ 5,579,127 ┆ 968,185   │
# │ 2,022 ┆ 4,804,546 ┆ 1,154,054 │
# │ 2,023 ┆ 4,062,609 ┆ 2,587,468 │
# │ 2,024 ┆ 3,109,103 ┆ 1,454,149 │
# │ 2,025 ┆ 1,520,384 ┆ 879,204   │
# │ 2,026 ┆ 101,787   ┆ 77,451    │
# └───────┴───────────┴───────────┘

# %% [markdown]
# ## plot_yearly_bar_by_month

# %%
(fig, df) = g.plot_yearly_bar_by_month(month=1, begin=datetime(2015,1,1))

# %% [markdown]
# ## plot_delta_yearly_bar

# %%
(fig, df) = g.plot_delta_yearly_bar(hw=['PS4', 'PS5', 'NSW'])

# %% [markdown]
# ## plot_maker_share_pie

# %%
(fig, df) = g.plot_maker_share_pie(begin_year=2023, end_year=2025)

# %% [markdown]
# ## plot_maker_share_bar

# %%
(fig, df) = g.plot_maker_share_bar(begin=datetime(2015, 1, 1))

# %%
df
# Out:
# ┌───────┬──────────┬───────┬───────────┐
# │ year  ┆ Nintendo ┆ SONY  ┆ Microsoft │
# ╞═══════╪══════════╪═══════╪═══════════╡
# │ 2,015 ┆ 53.68    ┆ 45.97 ┆ 0.34      │
# │ 2,016 ┆ 45.34    ┆ 54.48 ┆ 0.18      │
# │ 2,017 ┆ 69.14    ┆ 30.67 ┆ 0.19      │
# │ 2,018 ┆ 68.15    ┆ 31.59 ┆ 0.26      │
# │ 2,019 ┆ 79.04    ┆ 20.82 ┆ 0.14      │
# │ 2,020 ┆ 87.85    ┆ 11.64 ┆ 0.51      │
# │ 2,021 ┆ 82.74    ┆ 15.82 ┆ 1.43      │
# │ 2,022 ┆ 76.90    ┆ 18.79 ┆ 4.31      │
# │ 2,023 ┆ 59.20    ┆ 38.74 ┆ 2.06      │
# │ 2,024 ┆ 66.22    ┆ 31.26 ┆ 2.52      │
# │ 2,025 ┆ 85.34    ┆ 14.16 ┆ 0.50      │
# │ 2,026 ┆ 88.74    ┆ 11.01 ┆ 0.26      │
# └───────┴──────────┴───────┴───────────┘
