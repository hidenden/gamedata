# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib widget

# %%
# 標準ライブラリ
from datetime import datetime, timedelta

# サードパーティライブラリ
import pandas as pd
from pandas import Timedelta
import matplotlib.pyplot as plt
import japanize_matplotlib
from matplotlib.ticker import ScalarFormatter
from IPython.display import Markdown, display

# プロジェクト内モジュール
import gamedata as g

# %% [markdown]
# ## plot_monthly_bar_by_year

# %%
(fig, df) = g.plot_monthly_bar_by_year(hw='PS5')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## plot_quarterly_bar_by_year

# %%
(qyps5fig, qyps5df) = g.plot_quarterly_bar_by_year(hw='PS5')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## plot_monthly_bar_by_hard

# %%
(fig, df) = g.plot_monthly_bar_by_hard(hw=['PS5',  'NSW'], begin=datetime(2024,1,1), ticklabelsize=5)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
(qhfig, qhdf) = g.plot_quarterly_bar_by_hard(hw=['PS5', 'NSW', 'NS2'],
                             begin=datetime(2023,1,1), end=datetime(2025,12,31),
                             ticklabelsize=6)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## plot_monthly_bar_by_hard_year

# %%
(pmhy_fig, pmhy_df) = g.plot_monthly_bar_by_hard_year(hwy=[("NSW", 2017),("NS2", 2025)])
pmhy_df.sum()
# Out:
# hw
# NSW_2017    3407158.0
# NS2_2025    3784067.0
# dtype: float64
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pmhy_df
# Out:
# hw     NSW_2017   NS2_2025
# month
# 3        524371        0.0
# 4        234817        0.0
# 5        127314        0.0
# 6        129971  1169684.0
# 7        294311   444706.0
# 8        254489   319690.0
# 9        168810   175542.0
# 10       307138   358399.0
# 11       372619   500414.0
# 12       993318   815632.0

# %%
(qhyfig, qhydf) = g.plot_quarterly_bar_by_hard_year(hwy=[("PS5", 2023), ("NSW", 2017), ("NS2", 2025)],
                             ticklabelsize=6)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
s_qhydf = g.style_sales(qhydf)
display(s_qhydf)
# Out:
# <style type="text/css">
# #T_1c8eb_row0_col0, #T_1c8eb_row0_col1, #T_1c8eb_row0_col2, #T_1c8eb_row1_col0, #T_1c8eb_row1_col1, #T_1c8eb_row1_col2, #T_1c8eb_row2_col0, #T_1c8eb_row2_col1, #T_1c8eb_row2_col2, #T_1c8eb_row3_col0, #T_1c8eb_row3_col1, #T_1c8eb_row3_col2 {
#   text-align: right;
# }
# </style>
# <table id="T_1c8eb">
#   <thead>
#     <tr>
#       <th class="index_name level0" >hw</th>
#       <th id="T_1c8eb_level0_col0" class="col_heading level0 col0" >PS5_2023</th>
#       <th id="T_1c8eb_level0_col1" class="col_heading level0 col1" >NSW_2017</th>
#       <th id="T_1c8eb_level0_col2" class="col_heading level0 col2" >NS2_2025</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >q_num</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1c8eb_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_1c8eb_row0_col0" class="data row0 col0" >823,967</td>
#       <td id="T_1c8eb_row0_col1" class="data row0 col1" >524,371</td>
#       <td id="T_1c8eb_row0_col2" class="data row0 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_1c8eb_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_1c8eb_row1_col0" class="data row1 col0" >601,827</td>
#       <td id="T_1c8eb_row1_col1" class="data row1 col1" >492,102</td>
#       <td id="T_1c8eb_row1_col2" class="data row1 col2" >1,169,684</td>
#     </tr>
#     <tr>
#       <th id="T_1c8eb_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_1c8eb_row2_col0" class="data row2 col0" >605,800</td>
#       <td id="T_1c8eb_row2_col1" class="data row2 col1" >717,610</td>
#       <td id="T_1c8eb_row2_col2" class="data row2 col2" >939,938</td>
#     </tr>
#     <tr>
#       <th id="T_1c8eb_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_1c8eb_row3_col0" class="data row3 col0" >555,874</td>
#       <td id="T_1c8eb_row3_col1" class="data row3 col1" >1,673,075</td>
#       <td id="T_1c8eb_row3_col2" class="data row3 col2" >1,674,445</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## plot_yearly_bar_by_hard

# %%
(fig, df) = g.plot_yearly_bar_by_hard(hw=['PS5',  'NSW'], begin=datetime(2020,1,1), ticklabelsize=5)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## plot_yearly_bar_by_month

# %%
(fig, df) = g.plot_yearly_bar_by_month(month=1, begin=datetime(2015,1,1))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## plot_delta_yearly_bar

# %%
(fig, df) = g.plot_delta_yearly_bar(hw=['PS4', 'PS5', 'NSW'])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## plot_maker_share_pie

# %%
(fig, df) = g.plot_maker_share_pie(begin_year=2023, end_year=2025)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## plot_maker_share_bar

# %%
(fig, df) = g.plot_maker_share_bar(begin=datetime(2005, 1, 1))

share_style = df.style.format("{:.1f}%")  # シェア率をパーセント表示する場合
share_style = share_style.background_gradient(cmap='Blues', axis=0)
display(share_style)
# Out:
# <style type="text/css">
# #T_14921_row0_col0 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_14921_row0_col1 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_14921_row0_col2, #T_14921_row14_col1 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_14921_row1_col0 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_14921_row1_col1 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_14921_row1_col2 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_14921_row2_col0 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_14921_row2_col1, #T_14921_row19_col1 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_14921_row2_col2 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_14921_row3_col0 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_14921_row3_col1 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_14921_row3_col2 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_14921_row4_col0, #T_14921_row6_col2 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_14921_row4_col1 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_14921_row4_col2 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_14921_row5_col0, #T_14921_row16_col1 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_14921_row5_col1 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_14921_row5_col2 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_14921_row6_col0 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_14921_row6_col1 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_14921_row7_col0 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_14921_row7_col1 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_14921_row7_col2 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_14921_row8_col0 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_14921_row8_col1 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_14921_row8_col2 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_14921_row9_col0 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_14921_row9_col1 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_14921_row9_col2 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_14921_row10_col0 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_14921_row10_col1 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_14921_row10_col2 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_14921_row11_col0, #T_14921_row15_col1, #T_14921_row21_col1, #T_14921_row21_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_14921_row11_col1, #T_14921_row17_col2, #T_14921_row21_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_14921_row11_col2 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_14921_row12_col0 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_14921_row12_col1 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_14921_row12_col2 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_14921_row13_col0 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_14921_row13_col1 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_14921_row13_col2 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_14921_row14_col0 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_14921_row14_col2 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_14921_row15_col0 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_14921_row15_col2, #T_14921_row20_col2 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_14921_row16_col0 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_14921_row16_col2, #T_14921_row18_col0 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_14921_row17_col0 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_14921_row17_col1 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_14921_row18_col1 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_14921_row18_col2 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_14921_row19_col0 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_14921_row19_col2 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_14921_row20_col0 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_14921_row20_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# </style>
# <table id="T_14921">
#   <thead>
#     <tr>
#       <th class="index_name level0" >maker_name</th>
#       <th id="T_14921_level0_col0" class="col_heading level0 col0" >Nintendo</th>
#       <th id="T_14921_level0_col1" class="col_heading level0 col1" >SONY</th>
#       <th id="T_14921_level0_col2" class="col_heading level0 col2" >Microsoft</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14921_level0_row0" class="row_heading level0 row0" >2005</th>
#       <td id="T_14921_row0_col0" class="data row0 col0" >55.6%</td>
#       <td id="T_14921_row0_col1" class="data row0 col1" >43.4%</td>
#       <td id="T_14921_row0_col2" class="data row0 col2" >1.0%</td>
#     </tr>
#     <tr>
#       <th id="T_14921_level0_row1" class="row_heading level0 row1" >2006</th>
#       <td id="T_14921_row1_col0" class="data row1 col0" >71.5%</td>
#       <td id="T_14921_row1_col1" class="data row1 col1" >27.1%</td>
#       <td id="T_14921_row1_col2" class="data row1 col2" >1.4%</td>
#     </tr>
#     <tr>
#       <th id="T_14921_level0_row2" class="row_heading level0 row2" >2007</th>
#       <td id="T_14921_row2_col0" class="data row2 col0" >67.3%</td>
#       <td id="T_14921_row2_col1" class="data row2 col1" >31.2%</td>
#       <td id="T_14921_row2_col2" class="data row2 col2" >1.6%</td>
#     </tr>
#     <tr>
#       <th id="T_14921_level0_row3" class="row_heading level0 row3" >2008</th>
#       <td id="T_14921_row3_col0" class="data row3 col0" >56.1%</td>
#       <td id="T_14921_row3_col1" class="data row3 col1" >41.3%</td>
#       <td id="T_14921_row3_col2" class="data row3 col2" >2.6%</td>
#     </tr>
#     <tr>
#       <th id="T_14921_level0_row4" class="row_heading level0 row4" >2009</th>
#       <td id="T_14921_row4_col0" class="data row4 col0" >56.4%</td>
#       <td id="T_14921_row4_col1" class="data row4 col1" >40.5%</td>
#       <td id="T_14921_row4_col2" class="data row4 col2" >3.1%</td>
#     </tr>
#     <tr>
#       <th id="T_14921_level0_row5" class="row_heading level0 row5" >2010</th>
#       <td id="T_14921_row5_col0" class="data row5 col0" >49.7%</td>
#       <td id="T_14921_row5_col1" class="data row5 col1" >48.1%</td>
#       <td id="T_14921_row5_col2" class="data row5 col2" >2.2%</td>
#     </tr>
#     <tr>
#       <th id="T_14921_level0_row6" class="row_heading level0 row6" >2011</th>
#       <td id="T_14921_row6_col0" class="data row6 col0" >59.3%</td>
#       <td id="T_14921_row6_col1" class="data row6 col1" >39.5%</td>
#       <td id="T_14921_row6_col2" class="data row6 col2" >1.2%</td>
#     </tr>
#     <tr>
#       <th id="T_14921_level0_row7" class="row_heading level0 row7" >2012</th>
#       <td id="T_14921_row7_col0" class="data row7 col0" >69.0%</td>
#       <td id="T_14921_row7_col1" class="data row7 col1" >30.3%</td>
#       <td id="T_14921_row7_col2" class="data row7 col2" >0.7%</td>
#     </tr>
#     <tr>
#       <th id="T_14921_level0_row8" class="row_heading level0 row8" >2013</th>
#       <td id="T_14921_row8_col0" class="data row8 col0" >70.5%</td>
#       <td id="T_14921_row8_col1" class="data row8 col1" >29.2%</td>
#       <td id="T_14921_row8_col2" class="data row8 col2" >0.2%</td>
#     </tr>
#     <tr>
#       <th id="T_14921_level0_row9" class="row_heading level0 row9" >2014</th>
#       <td id="T_14921_row9_col0" class="data row9 col0" >58.6%</td>
#       <td id="T_14921_row9_col1" class="data row9 col1" >40.6%</td>
#       <td id="T_14921_row9_col2" class="data row9 col2" >0.8%</td>
#     </tr>
#     <tr>
#       <th id="T_14921_level0_row10" class="row_heading level0 row10" >2015</th>
#       <td id="T_14921_row10_col0" class="data row10 col0" >53.7%</td>
#       <td id="T_14921_row10_col1" class="data row10 col1" >46.0%</td>
#       <td id="T_14921_row10_col2" class="data row10 col2" >0.3%</td>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
