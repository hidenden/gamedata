# %%
# %load_ext autoreload
# %autoreload 2

# %%
# 標準ライブラリ
from datetime import datetime, timedelta

# サードパーティライブラリ
import pandas as pd
from pandas import Timedelta
import matplotlib.pyplot as plt
import japanize_matplotlib
from matplotlib.ticker import ScalarFormatter
from IPython.display import Markdown, display

# プロジェクト内モジュール
from gamedata import hard_sales as hs
from gamedata import plot_hard as ph
from gamedata import hard_info as hi
from gamedata import hard_event as he

# %% [markdown]
# ## plot_monthly_bar_by_year

# %%
(fig, df) = ph.plot_monthly_bar_by_year(hw='PS5')

# %% [markdown]
# ## plot_monthly_bar_by_hard

# %%
(fig, df) = ph.plot_monthly_bar_by_hard(hw=['PS5',  'NSW'], begin=datetime(2024,1,1), ticklabelsize=5)

# %% [markdown]
# ## plot_monthly_bar_by_hard_year

# %%
(pmhy_fig, pmhy_df) = ph.plot_monthly_bar_by_hard_year(hwy=[("NSW", 2017),("NS2", 2025)])
pmhy_df.sum()
# Out:
# hw
# NSW_2017    3407158.0
# NS2_2025    3784067.0
# dtype: float64

# %%
pmhy_df
# Out:
# hw     NSW_2017   NS2_2025
# month
# 3        524371        0.0
# 4        234817        0.0
# 5        127314        0.0
# 6        129971  1169684.0
# 7        294311   444706.0
# 8        254489   319690.0
# 9        168810   175542.0
# 10       307138   358399.0
# 11       372619   500414.0
# 12       993318   815632.0

# %% [markdown]
# ## plot_yearly_bar_by_hard

# %%
(fig, df) = ph.plot_yearly_bar_by_hard(hw=['PS5',  'NSW'], begin=datetime(2020,1,1), ticklabelsize=5)

# %% [markdown]
# ## plot_yearly_bar_by_month

# %%
(fig, df) = ph.plot_yearly_bar_by_month(month=1, begin=datetime(2015,1,1))

# %% [markdown]
# ## plot_delta_yearly_bar

# %%
(fig, df) = ph.plot_delta_yearly_bar(hw=['PS4', 'PS5', 'NSW'])

# %% [markdown]
# ## plot_maker_share_pie

# %%
(fig, df) = ph.plot_maker_share_pie(begin_year=2023, end_year=2025)

# %% [markdown]
# ## plot_maker_share_bar

# %%
(fig, df) = ph.plot_maker_share_bar(begin=datetime(2005, 1, 1))

share_style = df.style.format("{:.1f}%")  # シェア率をパーセント表示する場合
share_style = share_style.background_gradient(cmap='Blues', axis=0)
display(share_style)
# Out:
# <style type="text/css">
# #T_5b9e4_row0_col0 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_5b9e4_row0_col1, #T_5b9e4_row17_col0 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_5b9e4_row0_col2 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_5b9e4_row1_col0 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_5b9e4_row1_col1 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_5b9e4_row1_col2 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_5b9e4_row2_col0 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_5b9e4_row2_col1 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_5b9e4_row2_col2 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_5b9e4_row3_col0 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_5b9e4_row3_col1 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_5b9e4_row3_col2 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# ...
