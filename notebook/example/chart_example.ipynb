# %%
# %load_ext autoreload
# %autoreload 2

# %%
# 標準ライブラリ
from datetime import datetime, timedelta

# サードパーティライブラリ
import pandas as pd
from pandas import Timedelta
import matplotlib.pyplot as plt
import japanize_matplotlib
from matplotlib.ticker import ScalarFormatter
from IPython.display import Markdown, display

# プロジェクト内モジュール
from gamedata import hard_sales as hs
from gamedata import plot_hard as ph
from gamedata import hard_info as hi
from gamedata import hard_event as he
from gamedata import chart_hard as ch

# %%
base_df = hs.load_hard_sales()

# %% [markdown]
# ## chart_units_by_date_hw

# %%
(cudh_df, cudh_style) = ch.chart_units_by_date_hw(base_df, begin=datetime(2020, 1,1), end=datetime(2020,1,31))
cudh_style
# Out:
# <style type="text/css">
# </style>
# <table id="T_33b82">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_33b82_level0_col0" class="col_heading level0 col0" >販売台数</th>
#       <th id="T_33b82_level0_col1" class="col_heading level0 col1" >累計台数</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >集計日</th>
#       <th class="index_name level1" >ハード</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_33b82_level0_row0" class="row_heading level0 row0" rowspan="4">2020-01-05</th>
#       <th id="T_33b82_level1_row0" class="row_heading level1 row0" >Nintendo Switch</th>
#       <td id="T_33b82_row0_col0" class="data row0 col0" >200,564</td>
#       <td id="T_33b82_row0_col1" class="data row0 col1" >11,584,013</td>
#     </tr>
#     <tr>
#       <th id="T_33b82_level1_row1" class="row_heading level1 row1" >PlayStation4</th>
#       <td id="T_33b82_row1_col0" class="data row1 col0" >32,801</td>
#       <td id="T_33b82_row1_col1" class="data row1 col1" >8,766,217</td>
#     </tr>
#     <tr>
#       <th id="T_33b82_level1_row2" class="row_heading level1 row2" >Nintendo 3DS</th>
#       <td id="T_33b82_row2_col0" class="data row2 col0" >2,486</td>
#       <td id="T_33b82_row2_col1" class="data row2 col1" >24,285,620</td>
#     </tr>
#     <tr>
#       <th id="T_33b82_level1_row3" class="row_heading level1 row3" >Xbox One</th>
#       <td id="T_33b82_row3_col0" class="data row3 col0" >122</td>
#       <td id="T_33b82_row3_col1" class="data row3 col1" >110,360</td>
#     </tr>
#     <tr>
#       <th id="T_33b82_level0_row4" class="row_heading level0 row4" rowspan="4">2020-01-12</th>
#       <th id="T_33b82_level1_row4" class="row_heading level1 row4" >Nintendo Switch</th>
#       <td id="T_33b82_row4_col0" class="data row4 col0" >200,564</td>
#       <td id="T_33b82_row4_col1" class="data row4 col1" >11,784,577</td>
#     </tr>
#     <tr>
#       <th id="T_33b82_level1_row5" class="row_heading level1 row5" >PlayStation4</th>
#       <td id="T_33b82_row5_col0" class="data row5 col0" >32,802</td>
#       <td id="T_33b82_row5_col1" class="data row5 col1" >8,799,019</td>
#     </tr>
#     <tr>
#       <th id="T_33b82_level1_row6" class="row_heading level1 row6" >Nintendo 3DS</th>
#       <td id="T_33b82_row6_col0" class="data row6 col0" >2,487</td>
#       <td id="T_33b82_row6_col1" class="data row6 col1" >24,288,107</td>
#     </tr>
#     <tr>
#       <th id="T_33b82_level1_row7" class="row_heading level1 row7" >Xbox One</th>
#       <td id="T_33b82_row7_col0" class="data row7 col0" >123</td>
#       <td id="T_33b82_row7_col1" class="data row7 col1" >110,483</td>
#     </tr>
#     <tr>
#       <th id="T_33b82_level0_row8" class="row_heading level0 row8" rowspan="4">2020-01-19</th>
#       <th id="T_33b82_level1_row8" class="row_heading level1 row8" >Nintendo Switch</th>
#       <td id="T_33b82_row8_col0" class="data row8 col0" >96,458</td>
#       <td id="T_33b82_row8_col1" class="data row8 col1" >11,881,035</td>
#     </tr>
#     <tr>
#       <th id="T_33b82_level1_row9" class="row_heading level1 row9" >PlayStation4</th>
#       <td id="T_33b82_row9_col0" class="data row9 col0" >6,325</td>
#       <td id="T_33b82_row9_col1" class="data row9 col1" >8,805,344</td>
#     </tr>
#     <tr>
#       <th id="T_33b82_level1_row10" class="row_heading level1 row10" >Nintendo 3DS</th>
#       <td id="T_33b82_row10_col0" class="data row10 col0" >766</td>
#       <td id="T_33b82_row10_col1" class="data row10 col1" >24,288,873</td>
#     </tr>
#     <tr>
#       <th id="T_33b82_level1_row11" class="row_heading level1 row11" >Xbox One</th>
#       <td id="T_33b82_row11_col0" class="data row11 col0" >74</td>
#       <td id="T_33b82_row11_col1" class="data row11 col1" >110,557</td>
#     </tr>
#     <tr>
#       <th id="T_33b82_level0_row12" class="row_heading level0 row12" rowspan="4">2020-01-26</th>
#       <th id="T_33b82_level1_row12" class="row_heading level1 row12" >Nintendo Switch</th>
#       <td id="T_33b82_row12_col0" class="data row12 col0" >67,987</td>
#       <td id="T_33b82_row12_col1" class="data row12 col1" >11,949,022</td>
#     </tr>
#     <tr>
#       <th id="T_33b82_level1_row13" class="row_heading level1 row13" >PlayStation4</th>
#       <td id="T_33b82_row13_col0" class="data row13 col0" >6,330</td>
#       <td id="T_33b82_row13_col1" class="data row13 col1" >8,811,674</td>
#     </tr>
#     <tr>
#       <th id="T_33b82_level1_row14" class="row_heading level1 row14" >Nintendo 3DS</th>
#       <td id="T_33b82_row14_col0" class="data row14 col0" >718</td>
#       <td id="T_33b82_row14_col1" class="data row14 col1" >24,289,591</td>
#     </tr>
#     <tr>
#       <th id="T_33b82_level1_row15" class="row_heading level1 row15" >Xbox One</th>
#       <td id="T_33b82_row15_col0" class="data row15 col0" >58</td>
#       <td id="T_33b82_row15_col1" class="data row15 col1" >110,615</td>
#     </tr>
#   </tbody>
# </table>

# %%
cudh_df
# Out:
#                               販売台数      累計台数
# 集計日        ハード
# 2020-01-05 Nintendo Switch  200564  11584013
#            PlayStation4      32801   8766217
#            Nintendo 3DS       2486  24285620
#            Xbox One            122    110360
# 2020-01-12 Nintendo Switch  200564  11784577
#            PlayStation4      32802   8799019
#            Nintendo 3DS       2487  24288107
#            Xbox One            123    110483
# 2020-01-19 Nintendo Switch   96458  11881035
#            PlayStation4       6325   8805344
#            Nintendo 3DS        766  24288873
#            Xbox One             74    110557
# 2020-01-26 Nintendo Switch   67987  11949022
#            PlayStation4       6330   8811674
#            Nintendo 3DS        718  24289591
#            Xbox One             58    110615

# %% [markdown]
# ## chart_weekly_ranking

# %%
cwr_df = ch.chart_weekly_ranking(rank_n=10, begin=datetime(2023,1,1), end=datetime(2023,12,31))
cwr_df
# Out:
#           集計日              ハード  週間販売台数
# 1  2023-01-01  Nintendo Switch  125359
# 2  2023-01-08  Nintendo Switch  125359
# 3  2023-10-08  Nintendo Switch  110241
# 4  2023-05-07  Nintendo Switch  108263
# 5  2023-04-30  Nintendo Switch  108262
# 6  2023-11-12     PlayStation5  107953
# 7  2023-07-02  Nintendo Switch  106214
# 8  2023-06-25  Nintendo Switch  105990
# 9  2023-06-11  Nintendo Switch  104413
# 10 2023-12-17  Nintendo Switch   94643

# %% [markdown]
# ## chart_montly_ranking

# %%
cmr_df = ch.chart_monthly_ranking(rank_n=10, begin=datetime(2015,12,1), end=datetime(2016,11,30))
cmr_df
# Out:
#        年   月               ハード  月間販売台数
# 1   2015  12      Nintendo 3DS  494417
# 2   2016   1      Nintendo 3DS  260203
# 3   2016  11      Nintendo 3DS  241757
# 4   2015  12      PlayStation4  205581
# 5   2016  11      PlayStation4  204015
# 6   2016   1      PlayStation4  193184
# 7   2016   1  PlayStation Vita  189872
# 8   2015  12  PlayStation Vita  179885
# 9   2016  10      PlayStation4  158923
# 10  2015  12             Wii U  154050

# %% [markdown]
# ## chart_yearly_ranking

# %%
cyr_df = ch.chart_yearly_ranking(rank_n=20)
cyr_df
# Out:
#        年                   ハード   年間販売台数
# 1   2006           Nintendo DS  8966021
# 2   2007           Nintendo DS  7202068
# 3   2020       Nintendo Switch  5956943
# 4   2012          Nintendo 3DS  5646213
# 5   2021       Nintendo Switch  5579127
# 6   2013          Nintendo 3DS  4912059
# 7   2022       Nintendo Switch  4804546
# 8   2019       Nintendo Switch  4493903
# 9   2001      GAME BOY ADVANCE  4245686
# 10  2011          Nintendo 3DS  4132038
# 11  2023       Nintendo Switch  4062609
# 12  2009           Nintendo DS  4013845
# 13  2008           Nintendo DS  3963304
# 14  2005           Nintendo DS  3939096
# 15  2002          PlayStation2  3719576
# 16  2007                   Wii  3670002
# 17  2003      GAME BOY ADVANCE  3591601
# 18  2025      Nintendo Switch2  3583810
# 19  2008  PlayStation Portable  3552105
# 20  2018       Nintendo Switch  3482388

# %% [markdown]
# ## chart_delta_week

# %%
cdw_df = ch.chart_delta_week(28)
cdw_df.head(10)
# Out:
#    report_date  delta_week   hw             full_name  sum_units
# 1   2025-12-21          28  NS2      Nintendo Switch2    3583810
# 2   2001-10-07          28  GBA      GAME BOY ADVANCE    3276989
# 3   2000-09-17          28  PS2          PlayStation2    2725751
# 4   2007-06-17          28  Wii                   Wii    2697766
# 5   2005-06-19          28   DS           Nintendo DS    2295713
# 6   2011-09-11          28  3DS          Nintendo 3DS    1787469
# 7   2017-09-17          28  NSW       Nintendo Switch    1683937
# 8   2005-06-26          28  PSP  PlayStation Portable    1477541
# 9   1999-08-08          28  PKS         PocketStation    1337476
# 10  2002-03-31          28   GC     Nintendo GAMECUBE    1289171
