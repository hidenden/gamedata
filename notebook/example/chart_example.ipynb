# %%
# %load_ext autoreload
# %autoreload 2

# %%
# 標準ライブラリ
from datetime import datetime, timedelta

# サードパーティライブラリ
import pandas as pl
import matplotlib.pyplot as plt
import japanize_matplotlib
from matplotlib.ticker import ScalarFormatter
from IPython.display import Markdown, display

# プロジェクト内モジュール
import gamedata as g

# %%
base_df = g.load_hard_sales()

# %% [markdown]
# ## chart_units_by_date_hw

# %%
(cudh_df, cudh_style) = g.chart_units_by_date_hw(base_df, begin=datetime(2020, 1,1), end=datetime(2020,1,31))
cudh_style
# Out:
# <style type="text/css">
# #T_16419_row0_col0, #T_16419_row4_col0 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 100.0%, transparent 100.0%);
# }
# #T_16419_row0_col1, #T_16419_row1_col1, #T_16419_row2_col1, #T_16419_row3_col1, #T_16419_row4_col1, #T_16419_row5_col1, #T_16419_row6_col1, #T_16419_row7_col1, #T_16419_row8_col1, #T_16419_row9_col1, #T_16419_row10_col1, #T_16419_row11_col1, #T_16419_row12_col1, #T_16419_row13_col1, #T_16419_row14_col1, #T_16419_row15_col1 {
#   text-align: right;
# }
# #T_16419_row1_col0, #T_16419_row5_col0 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 16.4%, transparent 16.4%);
# }
# #T_16419_row2_col0, #T_16419_row6_col0 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 1.2%, transparent 1.2%);
# }
# #T_16419_row3_col0, #T_16419_row7_col0 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 0.1%, transparent 0.1%);
# }
# #T_16419_row8_col0 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 48.1%, transparent 48.1%);
# }
# #T_16419_row9_col0, #T_16419_row13_col0 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 3.2%, transparent 3.2%);
# }
# #T_16419_row10_col0, #T_16419_row14_col0 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 0.4%, transparent 0.4%);
# }
# #T_16419_row11_col0, #T_16419_row15_col0 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 0.0%, transparent 0.0%);
# }
# #T_16419_row12_col0 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 33.9%, transparent 33.9%);
# }
# </style>
# <table id="T_16419">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_16419_level0_col0" class="col_heading level0 col0" >販売台数</th>
#       <th id="T_16419_level0_col1" class="col_heading level0 col1" >累計台数</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >集計日</th>
#       <th class="index_name level1" >ハード</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16419_level0_row0" class="row_heading level0 row0" rowspan="4">2020-01-05</th>
#       <th id="T_16419_level1_row0" class="row_heading level1 row0" >Nintendo Switch</th>
#       <td id="T_16419_row0_col0" class="data row0 col0" >200,564</td>
#       <td id="T_16419_row0_col1" class="data row0 col1" >11,584,013</td>
#     </tr>
#     <tr>
#       <th id="T_16419_level1_row1" class="row_heading level1 row1" >PlayStation4</th>
#       <td id="T_16419_row1_col0" class="data row1 col0" >32,801</td>
#       <td id="T_16419_row1_col1" class="data row1 col1" >8,766,217</td>
#     </tr>
#     <tr>
#       <th id="T_16419_level1_row2" class="row_heading level1 row2" >Nintendo 3DS</th>
#       <td id="T_16419_row2_col0" class="data row2 col0" >2,486</td>
#       <td id="T_16419_row2_col1" class="data row2 col1" >24,285,620</td>
#     </tr>
#     <tr>
#       <th id="T_16419_level1_row3" class="row_heading level1 row3" >Xbox One</th>
#       <td id="T_16419_row3_col0" class="data row3 col0" >122</td>
#       <td id="T_16419_row3_col1" class="data row3 col1" >110,360</td>
#     </tr>
#     <tr>
#       <th id="T_16419_level0_row4" class="row_heading level0 row4" rowspan="4">2020-01-12</th>
#       <th id="T_16419_level1_row4" class="row_heading level1 row4" >Nintendo Switch</th>
#       <td id="T_16419_row4_col0" class="data row4 col0" >200,564</td>
#       <td id="T_16419_row4_col1" class="data row4 col1" >11,784,577</td>
#     </tr>
#     <tr>
#       <th id="T_16419_level1_row5" class="row_heading level1 row5" >PlayStation4</th>
#       <td id="T_16419_row5_col0" class="data row5 col0" >32,802</td>
#       <td id="T_16419_row5_col1" class="data row5 col1" >8,799,019</td>
#     </tr>
#     <tr>
#       <th id="T_16419_level1_row6" class="row_heading level1 row6" >Nintendo 3DS</th>
#       <td id="T_16419_row6_col0" class="data row6 col0" >2,487</td>
#       <td id="T_16419_row6_col1" class="data row6 col1" >24,288,107</td>
#     </tr>
#     <tr>
#       <th id="T_16419_level1_row7" class="row_heading level1 row7" >Xbox One</th>
#       <td id="T_16419_row7_col0" class="data row7 col0" >123</td>
#       <td id="T_16419_row7_col1" class="data row7 col1" >110,483</td>
#     </tr>
#     <tr>
#       <th id="T_16419_level0_row8" class="row_heading level0 row8" rowspan="4">2020-01-19</th>
#       <th id="T_16419_level1_row8" class="row_heading level1 row8" >Nintendo Switch</th>
#       <td id="T_16419_row8_col0" class="data row8 col0" >96,458</td>
#       <td id="T_16419_row8_col1" class="data row8 col1" >11,881,035</td>
#     </tr>
#     <tr>
#       <th id="T_16419_level1_row9" class="row_heading level1 row9" >PlayStation4</th>
#       <td id="T_16419_row9_col0" class="data row9 col0" >6,325</td>
#       <td id="T_16419_row9_col1" class="data row9 col1" >8,805,344</td>
#     </tr>
#     <tr>
#       <th id="T_16419_level1_row10" class="row_heading level1 row10" >Nintendo 3DS</th>
#       <td id="T_16419_row10_col0" class="data row10 col0" >766</td>
#       <td id="T_16419_row10_col1" class="data row10 col1" >24,288,873</td>
#     </tr>
#     <tr>
#       <th id="T_16419_level1_row11" class="row_heading level1 row11" >Xbox One</th>
#       <td id="T_16419_row11_col0" class="data row11 col0" >74</td>
#       <td id="T_16419_row11_col1" class="data row11 col1" >110,557</td>
#     </tr>
#     <tr>
#       <th id="T_16419_level0_row12" class="row_heading level0 row12" rowspan="4">2020-01-26</th>
#       <th id="T_16419_level1_row12" class="row_heading level1 row12" >Nintendo Switch</th>
#       <td id="T_16419_row12_col0" class="data row12 col0" >67,987</td>
#       <td id="T_16419_row12_col1" class="data row12 col1" >11,949,022</td>
#     </tr>
#     <tr>
#       <th id="T_16419_level1_row13" class="row_heading level1 row13" >PlayStation4</th>
#       <td id="T_16419_row13_col0" class="data row13 col0" >6,330</td>
#       <td id="T_16419_row13_col1" class="data row13 col1" >8,811,674</td>
#     </tr>
#     <tr>
#       <th id="T_16419_level1_row14" class="row_heading level1 row14" >Nintendo 3DS</th>
#       <td id="T_16419_row14_col0" class="data row14 col0" >718</td>
#       <td id="T_16419_row14_col1" class="data row14 col1" >24,289,591</td>
#     </tr>
#     <tr>
#       <th id="T_16419_level1_row15" class="row_heading level1 row15" >Xbox One</th>
#       <td id="T_16419_row15_col0" class="data row15 col0" >58</td>
#       <td id="T_16419_row15_col1" class="data row15 col1" >110,615</td>
#     </tr>
#   </tbody>
# </table>

# %%
s1 = g.style_sales(cudh_df, columns=['販売台数', '累計台数'], datetime_index=True)
display(s1)
# Out:
# <style type="text/css">
# #T_5e822_row0_col0, #T_5e822_row0_col1, #T_5e822_row1_col0, #T_5e822_row1_col1, #T_5e822_row2_col0, #T_5e822_row2_col1, #T_5e822_row3_col0, #T_5e822_row3_col1, #T_5e822_row4_col0, #T_5e822_row4_col1, #T_5e822_row5_col0, #T_5e822_row5_col1, #T_5e822_row6_col0, #T_5e822_row6_col1, #T_5e822_row7_col0, #T_5e822_row7_col1, #T_5e822_row8_col0, #T_5e822_row8_col1, #T_5e822_row9_col0, #T_5e822_row9_col1, #T_5e822_row10_col0, #T_5e822_row10_col1, #T_5e822_row11_col0, #T_5e822_row11_col1, #T_5e822_row12_col0, #T_5e822_row12_col1, #T_5e822_row13_col0, #T_5e822_row13_col1, #T_5e822_row14_col0, #T_5e822_row14_col1, #T_5e822_row15_col0, #T_5e822_row15_col1 {
#   text-align: right;
# }
# </style>
# <table id="T_5e822">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5e822_level0_col0" class="col_heading level0 col0" >販売台数</th>
#       <th id="T_5e822_level0_col1" class="col_heading level0 col1" >累計台数</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >集計日</th>
#       <th class="index_name level1" >ハード</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e822_level0_row0" class="row_heading level0 row0" rowspan="4">2020-01-05</th>
#       <th id="T_5e822_level1_row0" class="row_heading level1 row0" >Nintendo Switch</th>
#       <td id="T_5e822_row0_col0" class="data row0 col0" >200,564</td>
#       <td id="T_5e822_row0_col1" class="data row0 col1" >11,584,013</td>
#     </tr>
#     <tr>
#       <th id="T_5e822_level1_row1" class="row_heading level1 row1" >PlayStation4</th>
#       <td id="T_5e822_row1_col0" class="data row1 col0" >32,801</td>
#       <td id="T_5e822_row1_col1" class="data row1 col1" >8,766,217</td>
#     </tr>
#     <tr>
#       <th id="T_5e822_level1_row2" class="row_heading level1 row2" >Nintendo 3DS</th>
#       <td id="T_5e822_row2_col0" class="data row2 col0" >2,486</td>
#       <td id="T_5e822_row2_col1" class="data row2 col1" >24,285,620</td>
#     </tr>
#     <tr>
#       <th id="T_5e822_level1_row3" class="row_heading level1 row3" >Xbox One</th>
#       <td id="T_5e822_row3_col0" class="data row3 col0" >122</td>
#       <td id="T_5e822_row3_col1" class="data row3 col1" >110,360</td>
#     </tr>
#     <tr>
#       <th id="T_5e822_level0_row4" class="row_heading level0 row4" rowspan="4">2020-01-12</th>
#       <th id="T_5e822_level1_row4" class="row_heading level1 row4" >Nintendo Switch</th>
#       <td id="T_5e822_row4_col0" class="data row4 col0" >200,564</td>
#       <td id="T_5e822_row4_col1" class="data row4 col1" >11,784,577</td>
#     </tr>
#     <tr>
#       <th id="T_5e822_level1_row5" class="row_heading level1 row5" >PlayStation4</th>
#       <td id="T_5e822_row5_col0" class="data row5 col0" >32,802</td>
#       <td id="T_5e822_row5_col1" class="data row5 col1" >8,799,019</td>
#     </tr>
#     <tr>
#       <th id="T_5e822_level1_row6" class="row_heading level1 row6" >Nintendo 3DS</th>
#       <td id="T_5e822_row6_col0" class="data row6 col0" >2,487</td>
#       <td id="T_5e822_row6_col1" class="data row6 col1" >24,288,107</td>
#     </tr>
#     <tr>
#       <th id="T_5e822_level1_row7" class="row_heading level1 row7" >Xbox One</th>
#       <td id="T_5e822_row7_col0" class="data row7 col0" >123</td>
#       <td id="T_5e822_row7_col1" class="data row7 col1" >110,483</td>
#     </tr>
#     <tr>
#       <th id="T_5e822_level0_row8" class="row_heading level0 row8" rowspan="4">2020-01-19</th>
#       <th id="T_5e822_level1_row8" class="row_heading level1 row8" >Nintendo Switch</th>
#       <td id="T_5e822_row8_col0" class="data row8 col0" >96,458</td>
#       <td id="T_5e822_row8_col1" class="data row8 col1" >11,881,035</td>
#     </tr>
#     <tr>
#       <th id="T_5e822_level1_row9" class="row_heading level1 row9" >PlayStation4</th>
#       <td id="T_5e822_row9_col0" class="data row9 col0" >6,325</td>
#       <td id="T_5e822_row9_col1" class="data row9 col1" >8,805,344</td>
#     </tr>
#     <tr>
#       <th id="T_5e822_level1_row10" class="row_heading level1 row10" >Nintendo 3DS</th>
#       <td id="T_5e822_row10_col0" class="data row10 col0" >766</td>
#       <td id="T_5e822_row10_col1" class="data row10 col1" >24,288,873</td>
#     </tr>
#     <tr>
#       <th id="T_5e822_level1_row11" class="row_heading level1 row11" >Xbox One</th>
#       <td id="T_5e822_row11_col0" class="data row11 col0" >74</td>
#       <td id="T_5e822_row11_col1" class="data row11 col1" >110,557</td>
#     </tr>
#     <tr>
#       <th id="T_5e822_level0_row12" class="row_heading level0 row12" rowspan="4">2020-01-26</th>
#       <th id="T_5e822_level1_row12" class="row_heading level1 row12" >Nintendo Switch</th>
#       <td id="T_5e822_row12_col0" class="data row12 col0" >67,987</td>
#       <td id="T_5e822_row12_col1" class="data row12 col1" >11,949,022</td>
#     </tr>
#     <tr>
#       <th id="T_5e822_level1_row13" class="row_heading level1 row13" >PlayStation4</th>
#       <td id="T_5e822_row13_col0" class="data row13 col0" >6,330</td>
#       <td id="T_5e822_row13_col1" class="data row13 col1" >8,811,674</td>
#     </tr>
#     <tr>
#       <th id="T_5e822_level1_row14" class="row_heading level1 row14" >Nintendo 3DS</th>
#       <td id="T_5e822_row14_col0" class="data row14 col0" >718</td>
#       <td id="T_5e822_row14_col1" class="data row14 col1" >24,289,591</td>
#     </tr>
#     <tr>
#       <th id="T_5e822_level1_row15" class="row_heading level1 row15" >Xbox One</th>
#       <td id="T_5e822_row15_col0" class="data row15 col0" >58</td>
#       <td id="T_5e822_row15_col1" class="data row15 col1" >110,615</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## chart_weekly_ranking

# %%
cwr_df = g.chart_weekly_ranking(rank_n=10, begin=datetime(2023,1,1), end=datetime(2023,12,31))
s2 = g.style_sales(cwr_df, columns=['週間販売台数'], date_columns=['集計日'],highlights=['週間販売台数'])
display(s2)
# Out:
# <style type="text/css">
# #T_f205d_row0_col0, #T_f205d_row1_col0, #T_f205d_row2_col0, #T_f205d_row3_col0, #T_f205d_row4_col0, #T_f205d_row5_col0, #T_f205d_row6_col0, #T_f205d_row7_col0, #T_f205d_row8_col0, #T_f205d_row9_col0 {
#   text-align: left;
# }
# #T_f205d_row0_col2, #T_f205d_row1_col2 {
#   text-align: right;
#   background-color: #b31d15;
# }
# #T_f205d_row2_col2, #T_f205d_row3_col2, #T_f205d_row4_col2, #T_f205d_row5_col2, #T_f205d_row6_col2, #T_f205d_row7_col2, #T_f205d_row8_col2, #T_f205d_row9_col2 {
#   text-align: right;
# }
# </style>
# <table id="T_f205d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f205d_level0_col0" class="col_heading level0 col0" >集計日</th>
#       <th id="T_f205d_level0_col1" class="col_heading level0 col1" >ハード</th>
#       <th id="T_f205d_level0_col2" class="col_heading level0 col2" >週間販売台数</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f205d_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_f205d_row0_col0" class="data row0 col0" >2023-01-01</td>
#       <td id="T_f205d_row0_col1" class="data row0 col1" >Nintendo Switch</td>
#       <td id="T_f205d_row0_col2" class="data row0 col2" >125,359</td>
#     </tr>
#     <tr>
#       <th id="T_f205d_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_f205d_row1_col0" class="data row1 col0" >2023-01-08</td>
#       <td id="T_f205d_row1_col1" class="data row1 col1" >Nintendo Switch</td>
#       <td id="T_f205d_row1_col2" class="data row1 col2" >125,359</td>
#     </tr>
#     <tr>
#       <th id="T_f205d_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_f205d_row2_col0" class="data row2 col0" >2023-10-08</td>
#       <td id="T_f205d_row2_col1" class="data row2 col1" >Nintendo Switch</td>
#       <td id="T_f205d_row2_col2" class="data row2 col2" >110,241</td>
#     </tr>
#     <tr>
#       <th id="T_f205d_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_f205d_row3_col0" class="data row3 col0" >2023-05-07</td>
#       <td id="T_f205d_row3_col1" class="data row3 col1" >Nintendo Switch</td>
#       <td id="T_f205d_row3_col2" class="data row3 col2" >108,263</td>
#     </tr>
#     <tr>
#       <th id="T_f205d_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_f205d_row4_col0" class="data row4 col0" >2023-04-30</td>
#       <td id="T_f205d_row4_col1" class="data row4 col1" >Nintendo Switch</td>
#       <td id="T_f205d_row4_col2" class="data row4 col2" >108,262</td>
#     </tr>
#     <tr>
#       <th id="T_f205d_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_f205d_row5_col0" class="data row5 col0" >2023-11-12</td>
#       <td id="T_f205d_row5_col1" class="data row5 col1" >PlayStation5</td>
#       <td id="T_f205d_row5_col2" class="data row5 col2" >107,953</td>
#     </tr>
#     <tr>
#       <th id="T_f205d_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_f205d_row6_col0" class="data row6 col0" >2023-07-02</td>
#       <td id="T_f205d_row6_col1" class="data row6 col1" >Nintendo Switch</td>
#       <td id="T_f205d_row6_col2" class="data row6 col2" >106,214</td>
#     </tr>
#     <tr>
#       <th id="T_f205d_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_f205d_row7_col0" class="data row7 col0" >2023-06-25</td>
#       <td id="T_f205d_row7_col1" class="data row7 col1" >Nintendo Switch</td>
#       <td id="T_f205d_row7_col2" class="data row7 col2" >105,990</td>
#     </tr>
#     <tr>
#       <th id="T_f205d_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_f205d_row8_col0" class="data row8 col0" >2023-06-11</td>
#       <td id="T_f205d_row8_col1" class="data row8 col1" >Nintendo Switch</td>
#       <td id="T_f205d_row8_col2" class="data row8 col2" >104,413</td>
#     </tr>
#     <tr>
#       <th id="T_f205d_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_f205d_row9_col0" class="data row9 col0" >2023-12-17</td>
#       <td id="T_f205d_row9_col1" class="data row9 col1" >Nintendo Switch</td>
#       <td id="T_f205d_row9_col2" class="data row9 col2" >94,643</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## chart_montly_ranking

# %%
cmr_df = g.chart_monthly_ranking(rank_n=10, begin=datetime(2015,12,1), end=datetime(2016,11,30))
s3 = g.style_sales(cmr_df, columns=['月間販売台数'], bars=['月間販売台数'])
display(s3)
# Out:
# <style type="text/css">
# #T_10242_row0_col3 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06dd 100.0%, transparent 100.0%);
# }
# #T_10242_row1_col3 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06dd 52.6%, transparent 52.6%);
# }
# #T_10242_row2_col3 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06dd 48.9%, transparent 48.9%);
# }
# #T_10242_row3_col3 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06dd 41.6%, transparent 41.6%);
# }
# #T_10242_row4_col3 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06dd 41.3%, transparent 41.3%);
# }
# #T_10242_row5_col3 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06dd 39.1%, transparent 39.1%);
# }
# #T_10242_row6_col3 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06dd 38.4%, transparent 38.4%);
# }
# #T_10242_row7_col3 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06dd 36.4%, transparent 36.4%);
# }
# #T_10242_row8_col3 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06dd 32.1%, transparent 32.1%);
# }
# #T_10242_row9_col3 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06dd 31.2%, transparent 31.2%);
# }
# </style>
# <table id="T_10242">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_10242_level0_col0" class="col_heading level0 col0" >年</th>
#       <th id="T_10242_level0_col1" class="col_heading level0 col1" >月</th>
#       <th id="T_10242_level0_col2" class="col_heading level0 col2" >ハード</th>
#       <th id="T_10242_level0_col3" class="col_heading level0 col3" >月間販売台数</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_10242_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_10242_row0_col0" class="data row0 col0" >2015</td>
#       <td id="T_10242_row0_col1" class="data row0 col1" >12</td>
#       <td id="T_10242_row0_col2" class="data row0 col2" >Nintendo 3DS</td>
#       <td id="T_10242_row0_col3" class="data row0 col3" >494,417</td>
#     </tr>
#     <tr>
#       <th id="T_10242_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_10242_row1_col0" class="data row1 col0" >2016</td>
#       <td id="T_10242_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_10242_row1_col2" class="data row1 col2" >Nintendo 3DS</td>
#       <td id="T_10242_row1_col3" class="data row1 col3" >260,203</td>
#     </tr>
#     <tr>
#       <th id="T_10242_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_10242_row2_col0" class="data row2 col0" >2016</td>
#       <td id="T_10242_row2_col1" class="data row2 col1" >11</td>
#       <td id="T_10242_row2_col2" class="data row2 col2" >Nintendo 3DS</td>
#       <td id="T_10242_row2_col3" class="data row2 col3" >241,757</td>
#     </tr>
#     <tr>
#       <th id="T_10242_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_10242_row3_col0" class="data row3 col0" >2015</td>
#       <td id="T_10242_row3_col1" class="data row3 col1" >12</td>
#       <td id="T_10242_row3_col2" class="data row3 col2" >PlayStation4</td>
#       <td id="T_10242_row3_col3" class="data row3 col3" >205,581</td>
#     </tr>
#     <tr>
#       <th id="T_10242_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_10242_row4_col0" class="data row4 col0" >2016</td>
#       <td id="T_10242_row4_col1" class="data row4 col1" >11</td>
#       <td id="T_10242_row4_col2" class="data row4 col2" >PlayStation4</td>
#       <td id="T_10242_row4_col3" class="data row4 col3" >204,015</td>
#     </tr>
#     <tr>
#       <th id="T_10242_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_10242_row5_col0" class="data row5 col0" >2016</td>
#       <td id="T_10242_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_10242_row5_col2" class="data row5 col2" >PlayStation4</td>
#       <td id="T_10242_row5_col3" class="data row5 col3" >193,184</td>
#     </tr>
#     <tr>
#       <th id="T_10242_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_10242_row6_col0" class="data row6 col0" >2016</td>
#       <td id="T_10242_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_10242_row6_col2" class="data row6 col2" >PlayStation Vita</td>
#       <td id="T_10242_row6_col3" class="data row6 col3" >189,872</td>
#     </tr>
#     <tr>
#       <th id="T_10242_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_10242_row7_col0" class="data row7 col0" >2015</td>
#       <td id="T_10242_row7_col1" class="data row7 col1" >12</td>
#       <td id="T_10242_row7_col2" class="data row7 col2" >PlayStation Vita</td>
#       <td id="T_10242_row7_col3" class="data row7 col3" >179,885</td>
#     </tr>
#     <tr>
#       <th id="T_10242_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_10242_row8_col0" class="data row8 col0" >2016</td>
#       <td id="T_10242_row8_col1" class="data row8 col1" >10</td>
#       <td id="T_10242_row8_col2" class="data row8 col2" >PlayStation4</td>
#       <td id="T_10242_row8_col3" class="data row8 col3" >158,923</td>
#     </tr>
#     <tr>
#       <th id="T_10242_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_10242_row9_col0" class="data row9 col0" >2015</td>
#       <td id="T_10242_row9_col1" class="data row9 col1" >12</td>
#       <td id="T_10242_row9_col2" class="data row9 col2" >Wii U</td>
#       <td id="T_10242_row9_col3" class="data row9 col3" >154,050</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## chart_yearly_ranking

# %%
cyr_df = g.chart_yearly_ranking(rank_n=20)

s4 = g.style_sales(cyr_df, columns=['年間販売台数'], gradients=['年間販売台数'])
display(s4)
# Out:
# <style type="text/css">
# #T_8a9ed_row0_col2 {
#   text-align: right;
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_8a9ed_row1_col2 {
#   text-align: right;
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_8a9ed_row2_col2 {
#   text-align: right;
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_8a9ed_row3_col2 {
#   text-align: right;
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_8a9ed_row4_col2 {
#   text-align: right;
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_8a9ed_row5_col2 {
#   text-align: right;
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_8a9ed_row6_col2 {
#   text-align: right;
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_8a9ed_row7_col2 {
#   text-align: right;
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_8a9ed_row8_col2 {
#   text-align: right;
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_8a9ed_row9_col2 {
#   text-align: right;
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_8a9ed_row10_col2 {
#   text-align: right;
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_8a9ed_row11_col2 {
#   text-align: right;
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_8a9ed_row12_col2 {
#   text-align: right;
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_8a9ed_row13_col2 {
#   text-align: right;
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_8a9ed_row14_col2 {
#   text-align: right;
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_8a9ed_row15_col2 {
#   text-align: right;
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_8a9ed_row16_col2 {
#   text-align: right;
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_8a9ed_row17_col2 {
#   text-align: right;
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_8a9ed_row18_col2 {
#   text-align: right;
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_8a9ed_row19_col2 {
#   text-align: right;
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_8a9ed">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a9ed_level0_col0" class="col_heading level0 col0" >年</th>
#       <th id="T_8a9ed_level0_col1" class="col_heading level0 col1" >ハード</th>
#       <th id="T_8a9ed_level0_col2" class="col_heading level0 col2" >年間販売台数</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a9ed_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_8a9ed_row0_col0" class="data row0 col0" >2006</td>
#       <td id="T_8a9ed_row0_col1" class="data row0 col1" >Nintendo DS</td>
#       <td id="T_8a9ed_row0_col2" class="data row0 col2" >8,966,021</td>
#     </tr>
#     <tr>
#       <th id="T_8a9ed_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_8a9ed_row1_col0" class="data row1 col0" >2007</td>
#       <td id="T_8a9ed_row1_col1" class="data row1 col1" >Nintendo DS</td>
#       <td id="T_8a9ed_row1_col2" class="data row1 col2" >7,202,068</td>
#     </tr>
#     <tr>
#       <th id="T_8a9ed_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_8a9ed_row2_col0" class="data row2 col0" >2020</td>
#       <td id="T_8a9ed_row2_col1" class="data row2 col1" >Nintendo Switch</td>
#       <td id="T_8a9ed_row2_col2" class="data row2 col2" >5,956,943</td>
#     </tr>
#     <tr>
#       <th id="T_8a9ed_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_8a9ed_row3_col0" class="data row3 col0" >2012</td>
#       <td id="T_8a9ed_row3_col1" class="data row3 col1" >Nintendo 3DS</td>
#       <td id="T_8a9ed_row3_col2" class="data row3 col2" >5,646,213</td>
#     </tr>
#     <tr>
#       <th id="T_8a9ed_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_8a9ed_row4_col0" class="data row4 col0" >2021</td>
#       <td id="T_8a9ed_row4_col1" class="data row4 col1" >Nintendo Switch</td>
#       <td id="T_8a9ed_row4_col2" class="data row4 col2" >5,579,127</td>
#     </tr>
#     <tr>
#       <th id="T_8a9ed_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_8a9ed_row5_col0" class="data row5 col0" >2013</td>
#       <td id="T_8a9ed_row5_col1" class="data row5 col1" >Nintendo 3DS</td>
#       <td id="T_8a9ed_row5_col2" class="data row5 col2" >4,912,059</td>
#     </tr>
#     <tr>
#       <th id="T_8a9ed_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_8a9ed_row6_col0" class="data row6 col0" >2022</td>
#       <td id="T_8a9ed_row6_col1" class="data row6 col1" >Nintendo Switch</td>
#       <td id="T_8a9ed_row6_col2" class="data row6 col2" >4,804,546</td>
#     </tr>
#     <tr>
#       <th id="T_8a9ed_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_8a9ed_row7_col0" class="data row7 col0" >2019</td>
#       <td id="T_8a9ed_row7_col1" class="data row7 col1" >Nintendo Switch</td>
#       <td id="T_8a9ed_row7_col2" class="data row7 col2" >4,493,903</td>
#     </tr>
#     <tr>
#       <th id="T_8a9ed_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_8a9ed_row8_col0" class="data row8 col0" >2001</td>
#       <td id="T_8a9ed_row8_col1" class="data row8 col1" >GAME BOY ADVANCE</td>
#       <td id="T_8a9ed_row8_col2" class="data row8 col2" >4,245,686</td>
#     </tr>
#     <tr>
#       <th id="T_8a9ed_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_8a9ed_row9_col0" class="data row9 col0" >2011</td>
#       <td id="T_8a9ed_row9_col1" class="data row9 col1" >Nintendo 3DS</td>
#       <td id="T_8a9ed_row9_col2" class="data row9 col2" >4,132,038</td>
#     </tr>
#     <tr>
#       <th id="T_8a9ed_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_8a9ed_row10_col0" class="data row10 col0" >2023</td>
#       <td id="T_8a9ed_row10_col1" class="data row10 col1" >Nintendo Switch</td>
#       <td id="T_8a9ed_row10_col2" class="data row10 col2" >4,062,609</td>
#     </tr>
#     <tr>
#       <th id="T_8a9ed_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_8a9ed_row11_col0" class="data row11 col0" >2009</td>
#       <td id="T_8a9ed_row11_col1" class="data row11 col1" >Nintendo DS</td>
#       <td id="T_8a9ed_row11_col2" class="data row11 col2" >4,013,845</td>
#     </tr>
#     <tr>
#       <th id="T_8a9ed_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_8a9ed_row12_col0" class="data row12 col0" >2008</td>
#       <td id="T_8a9ed_row12_col1" class="data row12 col1" >Nintendo DS</td>
#       <td id="T_8a9ed_row12_col2" class="data row12 col2" >3,963,304</td>
#     </tr>
#     <tr>
#       <th id="T_8a9ed_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_8a9ed_row13_col0" class="data row13 col0" >2005</td>
#       <td id="T_8a9ed_row13_col1" class="data row13 col1" >Nintendo DS</td>
#       <td id="T_8a9ed_row13_col2" class="data row13 col2" >3,939,096</td>
#     </tr>
#     <tr>
#       <th id="T_8a9ed_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_8a9ed_row14_col0" class="data row14 col0" >2025</td>
#       <td id="T_8a9ed_row14_col1" class="data row14 col1" >Nintendo Switch2</td>
#       <td id="T_8a9ed_row14_col2" class="data row14 col2" >3,784,067</td>
#     </tr>
#     <tr>
#       <th id="T_8a9ed_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_8a9ed_row15_col0" class="data row15 col0" >2002</td>
#       <td id="T_8a9ed_row15_col1" class="data row15 col1" >PlayStation2</td>
#       <td id="T_8a9ed_row15_col2" class="data row15 col2" >3,719,576</td>
#     </tr>
#     <tr>
#       <th id="T_8a9ed_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_8a9ed_row16_col0" class="data row16 col0" >2007</td>
#       <td id="T_8a9ed_row16_col1" class="data row16 col1" >Wii</td>
#       <td id="T_8a9ed_row16_col2" class="data row16 col2" >3,670,002</td>
#     </tr>
#     <tr>
#       <th id="T_8a9ed_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_8a9ed_row17_col0" class="data row17 col0" >2003</td>
#       <td id="T_8a9ed_row17_col1" class="data row17 col1" >GAME BOY ADVANCE</td>
#       <td id="T_8a9ed_row17_col2" class="data row17 col2" >3,591,601</td>
#     </tr>
#     <tr>
#       <th id="T_8a9ed_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_8a9ed_row18_col0" class="data row18 col0" >2008</td>

# %% [markdown]
# ## chart_delta_week_ranking

# %%
cdw_df = g.chart_delta_week_ranking(28)
cdw_df10 = cdw_df.head(10)
s5 = g.style_sales(cdw_df10, columns=['sum_units'], date_columns=['report_date'], bars=['sum_units'])
display(s5)
# Out:
# <style type="text/css">
# #T_b8afc_row0_col0, #T_b8afc_row1_col0, #T_b8afc_row2_col0, #T_b8afc_row3_col0, #T_b8afc_row4_col0, #T_b8afc_row5_col0, #T_b8afc_row6_col0, #T_b8afc_row7_col0, #T_b8afc_row8_col0, #T_b8afc_row9_col0 {
#   text-align: left;
# }
# #T_b8afc_row0_col4 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06dd 100.0%, transparent 100.0%);
# }
# #T_b8afc_row1_col4 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06dd 91.4%, transparent 91.4%);
# }
# #T_b8afc_row2_col4 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06dd 76.1%, transparent 76.1%);
# }
# #T_b8afc_row3_col4 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06dd 75.3%, transparent 75.3%);
# }
# #T_b8afc_row4_col4 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06dd 64.1%, transparent 64.1%);
# }
# #T_b8afc_row5_col4 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06dd 49.9%, transparent 49.9%);
# }
# #T_b8afc_row6_col4 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06dd 47.0%, transparent 47.0%);
# }
# #T_b8afc_row7_col4 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06dd 41.2%, transparent 41.2%);
# }
# #T_b8afc_row8_col4 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06dd 37.3%, transparent 37.3%);
# }
# #T_b8afc_row9_col4 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06dd 36.0%, transparent 36.0%);
# }
# </style>
# <table id="T_b8afc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b8afc_level0_col0" class="col_heading level0 col0" >report_date</th>
#       <th id="T_b8afc_level0_col1" class="col_heading level0 col1" >delta_week</th>
#       <th id="T_b8afc_level0_col2" class="col_heading level0 col2" >hw</th>
#       <th id="T_b8afc_level0_col3" class="col_heading level0 col3" >full_name</th>
#       <th id="T_b8afc_level0_col4" class="col_heading level0 col4" >sum_units</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b8afc_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_b8afc_row0_col0" class="data row0 col0" >2025-12-21</td>
#       <td id="T_b8afc_row0_col1" class="data row0 col1" >28</td>
#       <td id="T_b8afc_row0_col2" class="data row0 col2" >NS2</td>
#       <td id="T_b8afc_row0_col3" class="data row0 col3" >Nintendo Switch2</td>
#       <td id="T_b8afc_row0_col4" class="data row0 col4" >3,583,810</td>
#     </tr>
#     <tr>
#       <th id="T_b8afc_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_b8afc_row1_col0" class="data row1 col0" >2001-10-07</td>
#       <td id="T_b8afc_row1_col1" class="data row1 col1" >28</td>
#       <td id="T_b8afc_row1_col2" class="data row1 col2" >GBA</td>
#       <td id="T_b8afc_row1_col3" class="data row1 col3" >GAME BOY ADVANCE</td>
#       <td id="T_b8afc_row1_col4" class="data row1 col4" >3,276,989</td>
#     </tr>
#     <tr>
#       <th id="T_b8afc_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_b8afc_row2_col0" class="data row2 col0" >2000-09-17</td>
#       <td id="T_b8afc_row2_col1" class="data row2 col1" >28</td>
#       <td id="T_b8afc_row2_col2" class="data row2 col2" >PS2</td>
#       <td id="T_b8afc_row2_col3" class="data row2 col3" >PlayStation2</td>
#       <td id="T_b8afc_row2_col4" class="data row2 col4" >2,725,751</td>
#     </tr>
#     <tr>
#       <th id="T_b8afc_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_b8afc_row3_col0" class="data row3 col0" >2007-06-17</td>
#       <td id="T_b8afc_row3_col1" class="data row3 col1" >28</td>
#       <td id="T_b8afc_row3_col2" class="data row3 col2" >Wii</td>
#       <td id="T_b8afc_row3_col3" class="data row3 col3" >Wii</td>
#       <td id="T_b8afc_row3_col4" class="data row3 col4" >2,697,766</td>
#     </tr>
#     <tr>
#       <th id="T_b8afc_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_b8afc_row4_col0" class="data row4 col0" >2005-06-19</td>
#       <td id="T_b8afc_row4_col1" class="data row4 col1" >28</td>
#       <td id="T_b8afc_row4_col2" class="data row4 col2" >DS</td>
#       <td id="T_b8afc_row4_col3" class="data row4 col3" >Nintendo DS</td>
#       <td id="T_b8afc_row4_col4" class="data row4 col4" >2,295,713</td>
#     </tr>
#     <tr>
#       <th id="T_b8afc_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_b8afc_row5_col0" class="data row5 col0" >2011-09-11</td>
#       <td id="T_b8afc_row5_col1" class="data row5 col1" >28</td>
#       <td id="T_b8afc_row5_col2" class="data row5 col2" >3DS</td>
#       <td id="T_b8afc_row5_col3" class="data row5 col3" >Nintendo 3DS</td>
#       <td id="T_b8afc_row5_col4" class="data row5 col4" >1,787,469</td>
#     </tr>
#     <tr>
#       <th id="T_b8afc_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_b8afc_row6_col0" class="data row6 col0" >2017-09-17</td>
#       <td id="T_b8afc_row6_col1" class="data row6 col1" >28</td>
#       <td id="T_b8afc_row6_col2" class="data row6 col2" >NSW</td>
#       <td id="T_b8afc_row6_col3" class="data row6 col3" >Nintendo Switch</td>
#       <td id="T_b8afc_row6_col4" class="data row6 col4" >1,683,937</td>
#     </tr>
#     <tr>
#       <th id="T_b8afc_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_b8afc_row7_col0" class="data row7 col0" >2005-06-26</td>
#       <td id="T_b8afc_row7_col1" class="data row7 col1" >28</td>
#       <td id="T_b8afc_row7_col2" class="data row7 col2" >PSP</td>
#       <td id="T_b8afc_row7_col3" class="data row7 col3" >PlayStation Portable</td>
#       <td id="T_b8afc_row7_col4" class="data row7 col4" >1,477,541</td>
#     </tr>
#     <tr>
#       <th id="T_b8afc_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_b8afc_row8_col0" class="data row8 col0" >1999-08-08</td>
#       <td id="T_b8afc_row8_col1" class="data row8 col1" >28</td>
#       <td id="T_b8afc_row8_col2" class="data row8 col2" >PKS</td>
#       <td id="T_b8afc_row8_col3" class="data row8 col3" >PocketStation</td>
#       <td id="T_b8afc_row8_col4" class="data row8 col4" >1,337,476</td>
#     </tr>
#     <tr>
#       <th id="T_b8afc_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_b8afc_row9_col0" class="data row9 col0" >2002-03-31</td>
#       <td id="T_b8afc_row9_col1" class="data row9 col1" >28</td>
#       <td id="T_b8afc_row9_col2" class="data row9 col2" >GC</td>
#       <td id="T_b8afc_row9_col3" class="data row9 col3" >Nintendo GAMECUBE</td>
#       <td id="T_b8afc_row9_col4" class="data row9 col4" >1,289,171</td>
#     </tr>
#   </tbody>
# </table>
