# %%
# %load_ext autoreload
# %autoreload 2

# %%
# 標準ライブラリ
from datetime import datetime, timedelta

# サードパーティライブラリ
import pandas as pd
from pandas import Timedelta
import matplotlib.pyplot as plt
import japanize_matplotlib
from matplotlib.ticker import ScalarFormatter
from IPython.display import Markdown, display

# プロジェクト内モジュール
from gamedata import hard_sales as hs
from gamedata import plot_hard as ph
from gamedata import hard_info as hi
from gamedata import hard_event as he
from gamedata import chart_hard as ch

# %%
base_df = hs.load_hard_sales()

# %% [markdown]
# ## chart_units_by_date_hw

# %%
(cudh_df, cudh_style) = ch.chart_units_by_date_hw(base_df, begin=datetime(2020, 1,1), end=datetime(2020,1,31))
cudh_style
# Out:
# <style type="text/css">
# </style>
# <table id="T_ba517">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba517_level0_col0" class="col_heading level0 col0" >販売台数</th>
#       <th id="T_ba517_level0_col1" class="col_heading level0 col1" >累計台数</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >集計日</th>
#       <th class="index_name level1" >ハード</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba517_level0_row0" class="row_heading level0 row0" rowspan="4">2020-01-05</th>
#       <th id="T_ba517_level1_row0" class="row_heading level1 row0" >Nintendo Switch</th>
#       <td id="T_ba517_row0_col0" class="data row0 col0" >200,564</td>
#       <td id="T_ba517_row0_col1" class="data row0 col1" >11,584,013</td>
#     </tr>
#     <tr>
# ...

# %%
s1 = ch.style_sales(cudh_df, columns=['販売台数', '累計台数'], datetime_index=True)
display(s1)
# Out:
# <style type="text/css">
# </style>
# <table id="T_2874f">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2874f_level0_col0" class="col_heading level0 col0" >販売台数</th>
#       <th id="T_2874f_level0_col1" class="col_heading level0 col1" >累計台数</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >集計日</th>
#       <th class="index_name level1" >ハード</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2874f_level0_row0" class="row_heading level0 row0" rowspan="4">2020-01-05</th>
#       <th id="T_2874f_level1_row0" class="row_heading level1 row0" >Nintendo Switch</th>
#       <td id="T_2874f_row0_col0" class="data row0 col0" >200,564</td>
#       <td id="T_2874f_row0_col1" class="data row0 col1" >11,584,013</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ## chart_weekly_ranking

# %%
cwr_df = ch.chart_weekly_ranking(rank_n=10, begin=datetime(2023,1,1), end=datetime(2023,12,31))
s2 = ch.style_sales(cwr_df, columns=['週間販売台数'], date_column='集計日',highlight='週間販売台数')
display(s2)
# Out:
# <style type="text/css">
# #T_0b955_row0_col2, #T_0b955_row1_col2 {
#   background-color: #b31d15;
# }
# </style>
# <table id="T_0b955">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0b955_level0_col0" class="col_heading level0 col0" >集計日</th>
#       <th id="T_0b955_level0_col1" class="col_heading level0 col1" >ハード</th>
#       <th id="T_0b955_level0_col2" class="col_heading level0 col2" >週間販売台数</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0b955_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_0b955_row0_col0" class="data row0 col0" >2023-01-01</td>
#       <td id="T_0b955_row0_col1" class="data row0 col1" >Nintendo Switch</td>
#       <td id="T_0b955_row0_col2" class="data row0 col2" >125,359</td>
#     </tr>
#     <tr>
#       <th id="T_0b955_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_0b955_row1_col0" class="data row1 col0" >2023-01-08</td>
# ...

# %% [markdown]
# ## chart_montly_ranking

# %%
cmr_df = ch.chart_monthly_ranking(rank_n=10, begin=datetime(2015,12,1), end=datetime(2016,11,30))
s3 = ch.style_sales(cmr_df, columns=['月間販売台数'], bar='月間販売台数')
display(s3)
# Out:
# <style type="text/css">
# #T_d1127_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 100.0%, transparent 100.0%);
# }
# #T_d1127_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 52.6%, transparent 52.6%);
# }
# #T_d1127_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 48.9%, transparent 48.9%);
# }
# #T_d1127_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 41.6%, transparent 41.6%);
# }
# #T_d1127_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 41.3%, transparent 41.3%);
# }
# #T_d1127_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 39.1%, transparent 39.1%);
# }
# #T_d1127_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 38.4%, transparent 38.4%);
# }
# #T_d1127_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 36.4%, transparent 36.4%);
# }
# #T_d1127_row8_col3 {
# ...

# %% [markdown]
# ## chart_yearly_ranking

# %%
cyr_df = ch.chart_yearly_ranking(rank_n=20)

s4 = ch.style_sales(cyr_df, columns=['年間販売台数'], gradient='年間販売台数')
display(s4)
# Out:
# <style type="text/css">
# #T_71705_row0_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_71705_row1_col2 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_71705_row2_col2 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_71705_row3_col2 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_71705_row4_col2 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_71705_row5_col2 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_71705_row6_col2 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_71705_row7_col2 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_71705_row8_col2 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_71705_row9_col2 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_71705_row10_col2 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_71705_row11_col2 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_71705_row12_col2 {
# ...

# %% [markdown]
# ## chart_delta_week

# %%
cdw_df = ch.chart_delta_week(28)
cdw_df10 = cdw_df.head(10)
s5 = ch.style_sales(cdw_df10, columns=['sum_units'], date_column='report_date', bar='sum_units')
display(s5)
# Out:
# <style type="text/css">
# #T_8a7ff_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 100.0%, transparent 100.0%);
# }
# #T_8a7ff_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 91.4%, transparent 91.4%);
# }
# #T_8a7ff_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 76.1%, transparent 76.1%);
# }
# #T_8a7ff_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 75.3%, transparent 75.3%);
# }
# #T_8a7ff_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 64.1%, transparent 64.1%);
# }
# #T_8a7ff_row5_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 49.9%, transparent 49.9%);
# }
# #T_8a7ff_row6_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 47.0%, transparent 47.0%);
# }
# #T_8a7ff_row7_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 41.2%, transparent 41.2%);
# }
# #T_8a7ff_row8_col4 {
# ...
