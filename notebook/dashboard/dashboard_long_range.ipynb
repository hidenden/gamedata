# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline

### 累計レポート
# 標準ライブラリ
import os
import sys
from pathlib import Path
from datetime import datetime, timedelta
from typing import List, Dict, Tuple, Optional, Callable

# サードパーティライブラリ
import pandas as pd
from pandas import Timedelta
import matplotlib.pyplot as plt
import japanize_matplotlib
from matplotlib.ticker import ScalarFormatter
from IPython.display import Markdown, display

# プロジェクト内モジュール
import gamedata as g

# %% [markdown]
# ## PlayStation年間販売履歴

# %%
(fig, df) = g.plot_yearly_bar_by_hard(hw=['PS5', 'PS4', 'PS3', 'PS2', "PS", "PSP", "Vita"], 
                                       begin=datetime(2005,1,1), end=datetime(2025,12,31), 
                                       stacked=True, 
                                       ticklabelsize=8)

# %% [markdown]
# ## 任天堂年間販売履歴

# %%
	
(fig, df) = g.plot_yearly_bar_by_hard(hw=['N64', 'GC', 'Wii', 'WiiU', "NSW", "NS2", "GBA", "DS", "3DS"], 
                                       ymax=11500000, begin=datetime(2005,1,1), 
                                       end=datetime(2025,12,31), stacked=True,
                                       ticklabelsize=8)

# %% [markdown]
# ## 全ハードエリアグラフ

# %%
(fig, df) = g.plot_sales(mode='year', begin=datetime(2005,1,1), area=True)

# %% [markdown]
# ## メーカーシェア

# %%
(fig, df) = g.plot_maker_share_pie(begin_year=2005, end_year=2008)

# %%
(fig, df) = g.plot_maker_share_pie(begin_year=2009, end_year=2012)

# %%
(fig, df) = g.plot_maker_share_pie(begin_year=2013, end_year=2016)

# %%
(fig, df) = g.plot_maker_share_pie(begin_year=2017, end_year=2020)

# %%
(fig, df) = g.plot_maker_share_pie(begin_year=2021, end_year=2023)

# %%
(fig, df) = g.plot_maker_share_pie(begin_year=2024, end_year=2025)

# %% [markdown]
# ## PlayStation機種別年間販売

# %% [markdown]
# ### PS5

# %%
(fig, df) = g.plot_yearly_bar_by_hard(hw=['PS5'], 
                                       begin=datetime(2005,1,1),
                                       stacked=True, 
                                       ticklabelsize=8)

# %% [markdown]
# ### PS4

# %%
(fig, df) = g.plot_yearly_bar_by_hard(hw=['PS4'], 
                                       begin=datetime(2005,1,1),
                                       stacked=True, 
                                       ticklabelsize=8)

# %% [markdown]
# ### PS3

# %%
(fig, df) = g.plot_yearly_bar_by_hard(hw=['PS3'], 
                                       begin=datetime(2005,1,1),
                                       stacked=True, 
                                       ticklabelsize=8)

# %%
(fig, df) = g.plot_yearly_bar_by_hard(hw=['PS3', 'PS4', 'PS5'], 
                                       begin=datetime(2005,1,1),
                                       stacked=True, 
                                       ticklabelsize=8)

# %% [markdown]
# ### PS Vita

# %%
(fig, df) = g.plot_yearly_bar_by_hard(hw=['Vita'], 
                                       begin=datetime(2005,1,1),
                                       stacked=True, 
                                       ticklabelsize=8)

# %% [markdown]
# ### PSP

# %%
(fig, df) = g.plot_yearly_bar_by_hard(hw=['PSP'], 
                                       begin=datetime(2005,1,1),
                                       stacked=True, 
                                       ticklabelsize=8)

# %% [markdown]
# ## 任天堂機種別年間販売状況

# %% [markdown]
# ### Nintendo Switch2

# %%
(fig, df) = g.plot_yearly_bar_by_hard(hw=['NS2'], 
                                       begin=datetime(2005,1,1),
                                       stacked=True, 
                                       ticklabelsize=8)

# %% [markdown]
# ### Nintendo Switch

# %%
(fig, df) = g.plot_yearly_bar_by_hard(hw=['NSW'], 
                                       begin=datetime(2005,1,1),
                                       stacked=True, 
                                       ticklabelsize=8)

# %% [markdown]
# ### Nintendo 3DS

# %%
(fig, df) = g.plot_yearly_bar_by_hard(hw=['3DS'], 
                                       begin=datetime(2005,1,1),
                                       stacked=True, 
                                       ticklabelsize=8)

# %% [markdown]
# ### WiiU

# %%
(fig, df) = g.plot_yearly_bar_by_hard(hw=['WiiU'], 
                                       begin=datetime(2005,1,1),
                                       stacked=True, 
                                       ticklabelsize=8)

# %% [markdown]
# ### Wii

# %%
(fig, df) = g.plot_yearly_bar_by_hard(hw=['Wii'], 
                                       begin=datetime(2005,1,1),
                                       stacked=True, 
                                       ticklabelsize=8)

# %% [markdown]
# ### Nintendo DS

# %%
(fig, df) = g.plot_yearly_bar_by_hard(hw=['DS'], 
                                       begin=datetime(2001,1,1),
                                       stacked=True, 
                                       ticklabelsize=8)

# %%
(fig, df) = g.plot_yearly_bar_by_hard(hw=['NSW', 'PS5', 'NS2'], 
                                       begin=datetime(2005,1,1),
                                       stacked=False, 
                                       ticklabelsize=8)

# %%
(fig, df) = g.plot_yearly_bar_by_hard(hw=['DC','Xbox', 'XB360', 'XBOne', 'XSX'], 
                                       begin=datetime(1999,1,1),
                                       stacked=True, 
                                       ticklabelsize=8)
