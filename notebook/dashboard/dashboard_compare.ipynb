# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline

### 累計レポート
# 標準ライブラリ
import os
from datetime import datetime, timedelta
from typing import List, Dict, Tuple, Optional, Callable

# サードパーティライブラリ
import polars as pl
import matplotlib.pyplot as plt
import japanize_matplotlib
from matplotlib.ticker import ScalarFormatter
from IPython.display import Markdown, display

# プロジェクト内モジュール
import gamedata as g

# %%
(fig4, d4) = g.plot_cumsum_diffs(cmplist = [('NS2', 'PS5'), ('NSW', 'PS4')], xgrid=10)

# %%
d4 = d4.filter((pl.col("weeks") >= 30) & (pl.col("weeks") <= 40))
g.style(d4)
# Out:
# <style type="text/css">
# #T_cd189_row0_col0, #T_cd189_row0_col1, #T_cd189_row1_col0, #T_cd189_row1_col1, #T_cd189_row2_col0, #T_cd189_row2_col1, #T_cd189_row3_col0, #T_cd189_row3_col1, #T_cd189_row4_col0, #T_cd189_row4_col1, #T_cd189_row5_col0, #T_cd189_row5_col1, #T_cd189_row6_col0, #T_cd189_row6_col1, #T_cd189_row7_col0, #T_cd189_row7_col1, #T_cd189_row8_col0, #T_cd189_row8_col1, #T_cd189_row9_col0, #T_cd189_row9_col1, #T_cd189_row10_col0, #T_cd189_row10_col1 {
#   text-align: right;
# }
# </style>
# <table id="T_cd189">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cd189_level0_col0" class="col_heading level0 col0" >PS5_NS2差</th>
#       <th id="T_cd189_level0_col1" class="col_heading level0 col1" >PS4_NSW差</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >weeks</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd189_level0_row0" class="row_heading level0 row0" >30</th>
#       <td id="T_cd189_row0_col0" class="data row0 col0" >3,514,143</td>
#       <td id="T_cd189_row0_col1" class="data row0 col1" >3,529,438</td>
#     </tr>
#     <tr>
#       <th id="T_cd189_level0_row1" class="row_heading level0 row1" >31</th>
#       <td id="T_cd189_row1_col0" class="data row1 col0" >3,380,600</td>
#       <td id="T_cd189_row1_col1" class="data row1 col1" >3,489,502</td>
#     </tr>
#     <tr>
#       <th id="T_cd189_level0_row2" class="row_heading level0 row2" >32</th>
#       <td id="T_cd189_row2_col0" class="data row2 col0" >3,247,058</td>
#       <td id="T_cd189_row2_col1" class="data row2 col1" >3,476,475</td>
#     </tr>
#     <tr>
#       <th id="T_cd189_level0_row3" class="row_heading level0 row3" >33</th>
#       <td id="T_cd189_row3_col0" class="data row3 col0" >3,189,532</td>
#       <td id="T_cd189_row3_col1" class="data row3 col1" >3,465,734</td>
#     </tr>
#     <tr>
#       <th id="T_cd189_level0_row4" class="row_heading level0 row4" >34</th>
#       <td id="T_cd189_row4_col0" class="data row4 col0" >3,127,212</td>
#       <td id="T_cd189_row4_col1" class="data row4 col1" >3,473,849</td>
#     </tr>
#     <tr>
#       <th id="T_cd189_level0_row5" class="row_heading level0 row5" >35</th>
#       <td id="T_cd189_row5_col0" class="data row5 col0" >3,068,575</td>
#       <td id="T_cd189_row5_col1" class="data row5 col1" >3,366,878</td>
#     </tr>
#     <tr>
#       <th id="T_cd189_level0_row6" class="row_heading level0 row6" >36</th>
#       <td id="T_cd189_row6_col0" class="data row6 col0" >3,013,898</td>
#       <td id="T_cd189_row6_col1" class="data row6 col1" >3,334,864</td>
#     </tr>
#     <tr>
#       <th id="T_cd189_level0_row7" class="row_heading level0 row7" >37</th>
#       <td id="T_cd189_row7_col0" class="data row7 col0" >2,967,707</td>
#       <td id="T_cd189_row7_col1" class="data row7 col1" >3,279,912</td>
#     </tr>
#     <tr>
#       <th id="T_cd189_level0_row8" class="row_heading level0 row8" >38</th>
#       <td id="T_cd189_row8_col0" class="data row8 col0" >2,914,737</td>
#       <td id="T_cd189_row8_col1" class="data row8 col1" >3,221,471</td>
#     </tr>
#     <tr>
#       <th id="T_cd189_level0_row9" class="row_heading level0 row9" >39</th>
#       <td id="T_cd189_row9_col0" class="data row9 col0" >2,843,955</td>
#       <td id="T_cd189_row9_col1" class="data row9 col1" >3,115,531</td>
#     </tr>
#     <tr>
#       <th id="T_cd189_level0_row10" class="row_heading level0 row10" >40</th>
#       <td id="T_cd189_row10_col0" class="data row10 col0" >2,733,266</td>
#       <td id="T_cd189_row10_col1" class="data row10 col1" >2,996,466</td>
#     </tr>
#   </tbody>
# </table>
