# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline

### 累計レポート
# 標準ライブラリ
import os
from datetime import datetime, timedelta
from typing import List, Dict, Tuple, Optional, Callable

# サードパーティライブラリ
import polars as pl
import matplotlib.pyplot as plt
import japanize_matplotlib
from matplotlib.ticker import ScalarFormatter
from IPython.display import Markdown, display

# プロジェクト内モジュール
import gamedata as g

# %%
(fig4, d4) = g.plot_cumsum_diffs(cmplist = [('NS2', 'PS5'), ('NSW', 'PS4')], xgrid=10)

# %%
d4.head(30)
# Out:
# ┌───────┬───────────┬───────────┐
# │ weeks ┆ PS5_NS2差 ┆ PS4_NSW差 │
# ╞═══════╪═══════════╪═══════════╡
# │ 0     ┆ 6,862,029 ┆ 4,359,277 │
# │ 1     ┆ 6,167,379 ┆ 4,065,277 │
# │ 2     ┆ 6,028,303 ┆ 4,036,422 │
# │ 3     ┆ 5,894,283 ┆ 4,018,033 │
# │ 4     ┆ 5,740,595 ┆ 3,969,019 │
# │ 5     ┆ 5,620,581 ┆ 3,965,065 │
# │ 6     ┆ 5,555,958 ┆ 3,941,870 │
# │ 7     ┆ 5,409,941 ┆ 3,921,237 │
# │ 8     ┆ 5,324,848 ┆ 3,899,716 │
# │ 9     ┆ 5,269,256 ┆ 3,850,255 │
# │ 10    ┆ 5,188,001 ┆ 3,831,400 │
# │ 11    ┆ 5,106,746 ┆ 3,823,430 │
# │ 12    ┆ 5,077,815 ┆ 3,813,200 │
# │ 13    ┆ 5,044,162 ┆ 3,805,507 │
# │ 14    ┆ 5,029,454 ┆ 3,801,519 │
# │ 15    ┆ 5,006,879 ┆ 3,793,093 │
# │ 16    ┆ 4,974,552 ┆ 3,768,770 │
# │ 17    ┆ 4,947,313 ┆ 3,767,946 │
# │ 18    ┆ 4,930,218 ┆ 3,771,852 │
# │ 19    ┆ 4,898,176 ┆ 3,764,123 │
# │ 20    ┆ 4,708,577 ┆ 3,767,762 │
# │ 21    ┆ 4,653,646 ┆ 3,692,711 │
# │ 22    ┆ 4,577,358 ┆ 3,680,968 │
# │ 23    ┆ 4,494,639 ┆ 3,664,101 │
# │ 24    ┆ 4,398,945 ┆ 3,624,970 │
# │ 25    ┆ 4,308,975 ┆ 3,642,786 │
# │ 26    ┆ 4,247,084 ┆ 3,583,618 │
# │ 27    ┆ 4,068,926 ┆ 3,580,497 │
# │ 28    ┆ 3,896,894 ┆ 3,564,291 │
# │ 29    ┆ 3,695,168 ┆ 3,553,765 │
# └───────┴───────────┴───────────┘
