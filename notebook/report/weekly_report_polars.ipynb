# %%
# %load_ext autoreload
# %autoreload 2

# %%
VERBOSE = True
PUBLISH = True
if not PUBLISH:
    # %matplotlib widget
else:
    # %matplotlib inline

# %%
### 週販レポート
# 標準ライブラリ
import os
import sys
from pathlib import Path
from datetime import datetime, timedelta

# サードパーティライブラリ
import polars as pl
import matplotlib.pyplot as plt
from matplotlib.figure import Figure

import japanize_matplotlib
from matplotlib.ticker import ScalarFormatter
from IPython.display import Markdown, display

# プロジェクト内モジュール
import gamedata as g

# %%
# 出力関数登録
def outfunc(fig: Figure) -> None:
    if PUBLISH:
        display(fig)
    else:
        plt.show()
g.set_dispfunc(outfunc)

# %%
# レポート日付
from report_config import get_config

config = get_config()
report_date = config["date"]
report_event_mask = g.EventMasks(hard=1.5, price=3, sale=2, soft=1.5, event=1)

def show_title(d:datetime) -> None:
    last_updated_str = d.strftime("%Y-%m-%d")
    mode = "[[LAB MODE]]" if not PUBLISH else ""
    display(Markdown(f"# 国内ゲームハード週販レポート ({last_updated_str}) {mode}"))

if PUBLISH and not VERBOSE:
    g.set_transparent_mode(True)
else:
    g.set_transparent_mode(False)

# %%
show_title(report_date)
# Out:
# # 国内ゲームハード週販レポート (2026-02-01)

# %% [markdown]
# * ハードウェアの販売データはファミ通の調査結果を基にしています。
# * 2026/1/11は2週合算だったため､データは処理上の都合､週次値に変換するため1/4と1/11に等分しています｡
# * [過去の週販レポート](../index.html)

# %% [markdown]
# ## 直近4週間のハード売り上げ／累計推移

# %%
df1 = g.load_hard_sales()
style1 = g.chart_units_by_date_hw(df1, begin=g.weeks_before(report_date, 3), end=report_date)
display(style1)
# Out:
# <style type="text/css">
# #T_6fd44_row0_col0 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 100.0%, transparent 100.0%);
# }
# #T_6fd44_row0_col1, #T_6fd44_row1_col1, #T_6fd44_row2_col1, #T_6fd44_row3_col1, #T_6fd44_row4_col1, #T_6fd44_row5_col1, #T_6fd44_row6_col1, #T_6fd44_row7_col1, #T_6fd44_row8_col1, #T_6fd44_row9_col1, #T_6fd44_row10_col1, #T_6fd44_row11_col1, #T_6fd44_row12_col1, #T_6fd44_row13_col1, #T_6fd44_row14_col1, #T_6fd44_row15_col1, #T_6fd44_row16_col1, #T_6fd44_row17_col1, #T_6fd44_row18_col1, #T_6fd44_row19_col1 {
#   text-align: right;
# }
# #T_6fd44_row1_col0 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 14.9%, transparent 14.9%);
# }
# #T_6fd44_row2_col0 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 14.8%, transparent 14.8%);
# }
# #T_6fd44_row3_col0 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 0.1%, transparent 0.1%);
# }
# #T_6fd44_row4_col0, #T_6fd44_row9_col0, #T_6fd44_row14_col0, #T_6fd44_row19_col0 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 0.0%, transparent 0.0%);
# }
# #T_6fd44_row5_col0 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 43.0%, transparent 43.0%);
# }
# #T_6fd44_row6_col0 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 17.4%, transparent 17.4%);
# }
# #T_6fd44_row7_col0 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 6.4%, transparent 6.4%);
# }
# #T_6fd44_row8_col0 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 0.2%, transparent 0.2%);
# }
# #T_6fd44_row10_col0 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 45.9%, transparent 45.9%);
# }
# #T_6fd44_row11_col0 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 11.2%, transparent 11.2%);
# }
# #T_6fd44_row12_col0 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 6.2%, transparent 6.2%);
# }
# #T_6fd44_row13_col0 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 0.4%, transparent 0.4%);
# }
# #T_6fd44_row15_col0 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 44.3%, transparent 44.3%);
# }
# #T_6fd44_row16_col0 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 7.0%, transparent 7.0%);
# }
# #T_6fd44_row17_col0 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 6.8%, transparent 6.8%);
# }
# #T_6fd44_row18_col0 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06 0.3%, transparent 0.3%);
# }
# </style>
# <table id="T_6fd44">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6fd44_level0_col0" class="col_heading level0 col0" >販売台数</th>
#       <th id="T_6fd44_level0_col1" class="col_heading level0 col1" >累計台数</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >集計日</th>
#       <th class="index_name level1" >ハード</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6fd44_level0_row0" class="row_heading level0 row0" rowspan="5">2026-01-11</th>
#       <th id="T_6fd44_level1_row0" class="row_heading level1 row0" >Nintendo Switch2</th>
#       <td id="T_6fd44_row0_col0" class="data row0 col0" >156,919</td>
#       <td id="T_6fd44_row0_col1" class="data row0 col1" >4,097,905</td>
#     </tr>
#     <tr>
#       <th id="T_6fd44_level1_row1" class="row_heading level1 row1" >PlayStation5</th>
#       <td id="T_6fd44_row1_col0" class="data row1 col0" >23,377</td>
#       <td id="T_6fd44_row1_col1" class="data row1 col1" >7,344,963</td>
#     </tr>
#     <tr>
#       <th id="T_6fd44_level1_row2" class="row_heading level1 row2" >Nintendo Switch</th>
#       <td id="T_6fd44_row2_col0" class="data row2 col0" >23,180</td>
#       <td id="T_6fd44_row2_col1" class="data row2 col1" >36,462,521</td>
#     </tr>
#     <tr>
#       <th id="T_6fd44_level1_row3" class="row_heading level1 row3" >Xbox Series X|S</th>
#       <td id="T_6fd44_row3_col0" class="data row3 col0" >141</td>
#       <td id="T_6fd44_row3_col1" class="data row3 col1" >689,835</td>
#     </tr>
#     <tr>
#       <th id="T_6fd44_level1_row4" class="row_heading level1 row4" >PlayStation4</th>
#       <td id="T_6fd44_row4_col0" class="data row4 col0" >13</td>
#       <td id="T_6fd44_row4_col1" class="data row4 col1" >9,491,072</td>
#     </tr>
#     <tr>
#       <th id="T_6fd44_level0_row5" class="row_heading level0 row5" rowspan="5">2026-01-18</th>
#       <th id="T_6fd44_level1_row5" class="row_heading level1 row5" >Nintendo Switch2</th>
#       <td id="T_6fd44_row5_col0" class="data row5 col0" >67,509</td>
#       <td id="T_6fd44_row5_col1" class="data row5 col1" >4,165,414</td>
#     </tr>
#     <tr>
#       <th id="T_6fd44_level1_row6" class="row_heading level1 row6" >Nintendo Switch</th>
#       <td id="T_6fd44_row6_col0" class="data row6 col0" >27,234</td>
#       <td id="T_6fd44_row6_col1" class="data row6 col1" >36,489,755</td>
#     </tr>
#     <tr>
#       <th id="T_6fd44_level1_row7" class="row_heading level1 row7" >PlayStation5</th>
#       <td id="T_6fd44_row7_col0" class="data row7 col0" >9,983</td>
#       <td id="T_6fd44_row7_col1" class="data row7 col1" >7,354,946</td>
#     </tr>
#     <tr>
#       <th id="T_6fd44_level1_row8" class="row_heading level1 row8" >Xbox Series X|S</th>
#       <td id="T_6fd44_row8_col0" class="data row8 col0" >303</td>
#       <td id="T_6fd44_row8_col1" class="data row8 col1" >690,138</td>
#     </tr>
#     <tr>
#       <th id="T_6fd44_level1_row9" class="row_heading level1 row9" >PlayStation4</th>
#       <td id="T_6fd44_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_6fd44_row9_col1" class="data row9 col1" >9,491,082</td>
#     </tr>
#     <tr>
#       <th id="T_6fd44_level0_row10" class="row_heading level0 row10" rowspan="5">2026-01-25</th>
#       <th id="T_6fd44_level1_row10" class="row_heading level1 row10" >Nintendo Switch2</th>
#       <td id="T_6fd44_row10_col0" class="data row10 col0" >72,086</td>
#       <td id="T_6fd44_row10_col1" class="data row10 col1" >4,237,500</td>
#     </tr>
#     <tr>
#       <th id="T_6fd44_level1_row11" class="row_heading level1 row11" >Nintendo Switch</th>
#       <td id="T_6fd44_row11_col0" class="data row11 col0" >17,515</td>
#       <td id="T_6fd44_row11_col1" class="data row11 col1" >36,507,270</td>
#     </tr>
#     <tr>
#       <th id="T_6fd44_level1_row12" class="row_heading level1 row12" >PlayStation5</th>
#       <td id="T_6fd44_row12_col0" class="data row12 col0" >9,766</td>
#       <td id="T_6fd44_row12_col1" class="data row12 col1" >7,364,712</td>
#     </tr>
#     <tr>
#       <th id="T_6fd44_level1_row13" class="row_heading level1 row13" >Xbox Series X|S</th>
#       <td id="T_6fd44_row13_col0" class="data row13 col0" >693</td>
#       <td id="T_6fd44_row13_col1" class="data row13 col1" >690,831</td>
#     </tr>
#     <tr>
#       <th id="T_6fd44_level1_row14" class="row_heading level1 row14" >PlayStation4</th>
#       <td id="T_6fd44_row14_col0" class="data row14 col0" >18</td>
#       <td id="T_6fd44_row14_col1" class="data row14 col1" >9,491,100</td>
#     </tr>
#     <tr>
#       <th id="T_6fd44_level0_row15" class="row_heading level0 row15" rowspan="5">2026-02-01</th>
#       <th id="T_6fd44_level1_row15" class="row_heading level1 row15" >Nintendo Switch2</th>
#       <td id="T_6fd44_row15_col0" class="data row15 col0" >69,586</td>
#       <td id="T_6fd44_row15_col1" class="data row15 col1" >4,307,086</td>
#     </tr>
#     <tr>
#       <th id="T_6fd44_level1_row16" class="row_heading level1 row16" >PlayStation5</th>
#       <td id="T_6fd44_row16_col0" class="data row16 col0" >10,949</td>
#       <td id="T_6fd44_row16_col1" class="data row16 col1" >7,375,661</td>
#     </tr>
#     <tr>
#       <th id="T_6fd44_level1_row17" class="row_heading level1 row17" >Nintendo Switch</th>
#       <td id="T_6fd44_row17_col0

# %% [markdown]
# 2月6日から[マイニンテンドーストアで先着販売](https://store-jp.nintendo.com/switch2)が始まります｡
# プレイ時間や購入台数制限はありますが､
# 任天堂は需要と供給がバランスしたと判断したようです｡
#
# そんな今週のSwitch2は微増の7万台でした｡
# 今後､7万前後で推移するとすると､商戦期以外としては非常に高い水準です｡
#
# PS5は2週連続で1万台を割り込みました｡
# セール期以外は売れない商品になってます｡
#
# Switchが減り始めました｡今週も主力はLiteで8577台で､約半分を占めています｡
# 将来､Switch2 Liteが出るまではこの傾向が続くのでしょうか｡

# %% [markdown]
# ## 週販推移

# %%
(weekly_fig, weekly_df) = g.plot_sales(begin=g.report_begin(report_date), end=report_date, event_mask=g.EVENT_MASK_MIDDLE)

# %% [markdown]
# ### 週販推移(拡大）

# %%
(weekly_big_fig, weekly_big_df) = g.plot_sales(begin=g.report_begin(report_date), end=report_date, ymax=230000, event_mask=g.EVENT_MASK_MIDDLE)

# %% [markdown]
# ### SwitchとSwitch2:初年の年末商戦後の推移比較

# %%
(pso_ns2_fig, pso_ns2_df) = g.plot_sales_with_offset(
                              hw_periods=[
                              {'hw': 'NSW', 'begin': datetime(2017,12,20)},
                              {'hw': 'NS2', 'begin': datetime(2025,12,20)},
                              ],
                          end = 15)

# %% [markdown]
# ホリデーシーズン後のSwitchとSwitch2の推移を比較するために､
# Nintendo Switchの2017/12/20以降とNintendo Switch2の2025/12/20以降の週販のグラフを示します｡
#
# 商戦後に落ち込むのはSwitchもSwitch2も同じですが､
# Switchは5万台未満で推移するのに比べ､Switch2は7万台前後の推移になっています｡
# その差は2万台/週｡Switch2の高い需要が継続しています｡

# %% [markdown]
# ### PS5の直近3年間の年末商戦後の推移比較

# %%
(psps5_fig, psps5_df) = g.plot_sales_with_offset(
                              hw_periods=[
                              {'hw': 'PS5', 'begin': datetime(2023,12,20)},
                              {'hw': 'PS5', 'begin': datetime(2024,12,20)},
                              {'hw': 'PS5', 'begin': datetime(2025,12,20)},
                              ],
                          end = 15)

# %% [markdown]
# PS5DE日本語版の値下げ効果がホリデーシーズン後も継続しているか確認するために､
# PS5の2023/12/20, 2024/12/20, 2025/12/20以降の週販のグラフを示します｡
#
# 2025年は12月中の年末商戦の段階で2023年､2024年を下回っています｡
# ホリデー後も昨年を下回る水準が継続しており､値下げは販売台数を増加させる事は出来ていません｡

# %% [markdown]
# ## 月間販売推移

# %%
(mbh_fig, mbh_df) = g.plot_monthly_bar_by_hard(hw=["NS2", "PS5", "NSW", "XSX"], 
                                        begin=g.report_begin(report_date), end=report_date,
                                        stacked=False)

# %%
month_style = g.style_sales(mbh_df.tail(1))
display(month_style)
# Out:
# <style type="text/css">
# #T_f15a3_row0_col0, #T_f15a3_row0_col1, #T_f15a3_row0_col2, #T_f15a3_row0_col3 {
#   text-align: right;
# }
# </style>
# <table id="T_f15a3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f15a3_level0_col0" class="col_heading level0 col0" >NSW</th>
#       <th id="T_f15a3_level0_col1" class="col_heading level0 col1" >PS5</th>
#       <th id="T_f15a3_level0_col2" class="col_heading level0 col2" >XSX</th>
#       <th id="T_f15a3_level0_col3" class="col_heading level0 col3" >NS2</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >year_month</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f15a3_level0_row0" class="row_heading level0 row0" >2026-02</th>
#       <td id="T_f15a3_row0_col0" class="data row0 col0" >10,678</td>
#       <td id="T_f15a3_row0_col1" class="data row0 col1" >10,949</td>
#       <td id="T_f15a3_row0_col2" class="data row0 col2" >525</td>
#       <td id="T_f15a3_row0_col3" class="data row0 col3" >69,586</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Nintendo Switchの月間販売台数： 前々年､前年との比較

# %%
(my_ns_fig, my_ns_df) = g.plot_monthly_bar_by_year(hw="NSW", ymax=480000, begin=g.years_ago(report_date), end=report_date)

# %%
if True:
    this_year = report_date.year
    my_ns_df2 = my_ns_df.drop(str(this_year - 2))
    my_ns_df2 = my_ns_df2.with_columns(
        (pl.col(str(this_year)) / pl.col(str(this_year - 1))).alias("YoY")
    )
    my_ns_style = g.style_sales(my_ns_df2, percent_columns=["YoY"], columns= [str(this_year), str(this_year -1)])
    display(my_ns_style)
# Out:
# <style type="text/css">
# #T_bd67d_row0_col0, #T_bd67d_row0_col1, #T_bd67d_row0_col2, #T_bd67d_row1_col0, #T_bd67d_row1_col1, #T_bd67d_row1_col2, #T_bd67d_row2_col0, #T_bd67d_row2_col1, #T_bd67d_row2_col2, #T_bd67d_row3_col0, #T_bd67d_row3_col1, #T_bd67d_row3_col2, #T_bd67d_row4_col0, #T_bd67d_row4_col1, #T_bd67d_row4_col2, #T_bd67d_row5_col0, #T_bd67d_row5_col1, #T_bd67d_row5_col2, #T_bd67d_row6_col0, #T_bd67d_row6_col1, #T_bd67d_row6_col2, #T_bd67d_row7_col0, #T_bd67d_row7_col1, #T_bd67d_row7_col2, #T_bd67d_row8_col0, #T_bd67d_row8_col1, #T_bd67d_row8_col2, #T_bd67d_row9_col0, #T_bd67d_row9_col1, #T_bd67d_row9_col2, #T_bd67d_row10_col0, #T_bd67d_row10_col1, #T_bd67d_row10_col2, #T_bd67d_row11_col0, #T_bd67d_row11_col1, #T_bd67d_row11_col2 {
#   text-align: right;
# }
# </style>
# <table id="T_bd67d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bd67d_level0_col0" class="col_heading level0 col0" >2025</th>
#       <th id="T_bd67d_level0_col1" class="col_heading level0 col1" >2026</th>
#       <th id="T_bd67d_level0_col2" class="col_heading level0 col2" >YoY</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >month</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bd67d_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_bd67d_row0_col0" class="data row0 col0" >260,447</td>
#       <td id="T_bd67d_row0_col1" class="data row0 col1" >91,109</td>
#       <td id="T_bd67d_row0_col2" class="data row0 col2" >35.0%</td>
#     </tr>
#     <tr>
#       <th id="T_bd67d_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_bd67d_row1_col0" class="data row1 col0" >167,188</td>
#       <td id="T_bd67d_row1_col1" class="data row1 col1" >10,678</td>
#       <td id="T_bd67d_row1_col2" class="data row1 col2" >6.4%</td>
#     </tr>
#     <tr>
#       <th id="T_bd67d_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_bd67d_row2_col0" class="data row2 col0" >171,921</td>
#       <td id="T_bd67d_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_bd67d_row2_col2" class="data row2 col2" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_bd67d_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_bd67d_row3_col0" class="data row3 col0" >113,513</td>
#       <td id="T_bd67d_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_bd67d_row3_col2" class="data row3 col2" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_bd67d_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_bd67d_row4_col0" class="data row4 col0" >106,506</td>
#       <td id="T_bd67d_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_bd67d_row4_col2" class="data row4 col2" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_bd67d_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_bd67d_row5_col0" class="data row5 col0" >78,097</td>
#       <td id="T_bd67d_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_bd67d_row5_col2" class="data row5 col2" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_bd67d_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_bd67d_row6_col0" class="data row6 col0" >57,532</td>
#       <td id="T_bd67d_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_bd67d_row6_col2" class="data row6 col2" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_bd67d_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_bd67d_row7_col0" class="data row7 col0" >94,517</td>
#       <td id="T_bd67d_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_bd67d_row7_col2" class="data row7 col2" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_bd67d_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_bd67d_row8_col0" class="data row8 col0" >82,946</td>
#       <td id="T_bd67d_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_bd67d_row8_col2" class="data row8 col2" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_bd67d_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_bd67d_row9_col0" class="data row9 col0" >96,080</td>
#       <td id="T_bd67d_row9_col1" class="data row9 col1" >0</td>
#       <td id="T_bd67d_row9_col2" class="data row9 col2" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_bd67d_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_bd67d_row10_col0" class="data row10 col0" >138,018</td>
#       <td id="T_bd67d_row10_col1" class="data row10 col1" >0</td>
#       <td id="T_bd67d_row10_col2" class="data row10 col2" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_bd67d_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_bd67d_row11_col0" class="data row11 col0" >153,619</td>
#       <td id="T_bd67d_row11_col1" class="data row11 col1" >0</td>
#       <td id="T_bd67d_row11_col2" class="data row11 col2" >0.0%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# 2026年1月のSwitchは10万台に届きませんでした｡前年比は35%｡大きな落ち込みです｡
#
# ただ､昨年の4月以降にはSwitch2の影響で顕著に販売台数が低下していたので､
# 大きな落ち込みを示す前年比は､3月までだと思います｡

# %% [markdown]
# ### PlayStation 5の月間販売台数： 前々年､前年との比較

# %%
(my_ps5_fig, my_ps5_df) = g.plot_monthly_bar_by_year(hw="PS5", ymax=480000, 
                                        begin=g.years_ago(report_date), end=report_date)

# %%
if True:
    this_year = report_date.year
    my_ps5_df = my_ps5_df.drop(str(this_year - 2))
    my_ps5_df = my_ps5_df.with_columns(
        (pl.col(str(this_year)) / pl.col(str(this_year - 1))).alias("YoY")
    )
    ps5_monthly_style = g.style_sales(my_ps5_df, percent_columns=["YoY"], columns=[str(this_year), str(this_year - 1)])
    display(ps5_monthly_style)
# Out:
# <style type="text/css">
# #T_792fb_row0_col0, #T_792fb_row0_col1, #T_792fb_row0_col2, #T_792fb_row1_col0, #T_792fb_row1_col1, #T_792fb_row1_col2, #T_792fb_row2_col0, #T_792fb_row2_col1, #T_792fb_row2_col2, #T_792fb_row3_col0, #T_792fb_row3_col1, #T_792fb_row3_col2, #T_792fb_row4_col0, #T_792fb_row4_col1, #T_792fb_row4_col2, #T_792fb_row5_col0, #T_792fb_row5_col1, #T_792fb_row5_col2, #T_792fb_row6_col0, #T_792fb_row6_col1, #T_792fb_row6_col2, #T_792fb_row7_col0, #T_792fb_row7_col1, #T_792fb_row7_col2, #T_792fb_row8_col0, #T_792fb_row8_col1, #T_792fb_row8_col2, #T_792fb_row9_col0, #T_792fb_row9_col1, #T_792fb_row9_col2, #T_792fb_row10_col0, #T_792fb_row10_col1, #T_792fb_row10_col2, #T_792fb_row11_col0, #T_792fb_row11_col1, #T_792fb_row11_col2 {
#   text-align: right;
# }
# </style>
# <table id="T_792fb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_792fb_level0_col0" class="col_heading level0 col0" >2025</th>
#       <th id="T_792fb_level0_col1" class="col_heading level0 col1" >2026</th>
#       <th id="T_792fb_level0_col2" class="col_heading level0 col2" >YoY</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >month</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_792fb_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_792fb_row0_col0" class="data row0 col0" >81,587</td>
#       <td id="T_792fb_row0_col1" class="data row0 col1" >66,502</td>
#       <td id="T_792fb_row0_col2" class="data row0 col2" >81.5%</td>
#     </tr>
#     <tr>
#       <th id="T_792fb_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_792fb_row1_col0" class="data row1 col0" >56,886</td>
#       <td id="T_792fb_row1_col1" class="data row1 col1" >10,949</td>
#       <td id="T_792fb_row1_col2" class="data row1 col2" >19.2%</td>
#     </tr>
#     <tr>
#       <th id="T_792fb_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_792fb_row2_col0" class="data row2 col0" >218,300</td>
#       <td id="T_792fb_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_792fb_row2_col2" class="data row2 col2" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_792fb_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_792fb_row3_col0" class="data row3 col0" >38,983</td>
#       <td id="T_792fb_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_792fb_row3_col2" class="data row3 col2" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_792fb_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_792fb_row4_col0" class="data row4 col0" >32,001</td>
#       <td id="T_792fb_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_792fb_row4_col2" class="data row4 col2" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_792fb_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_792fb_row5_col0" class="data row5 col0" >63,516</td>
#       <td id="T_792fb_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_792fb_row5_col2" class="data row5 col2" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_792fb_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_792fb_row6_col0" class="data row6 col0" >28,959</td>
#       <td id="T_792fb_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_792fb_row6_col2" class="data row6 col2" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_792fb_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_792fb_row7_col0" class="data row7 col0" >39,004</td>
#       <td id="T_792fb_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_792fb_row7_col2" class="data row7 col2" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_792fb_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_792fb_row8_col0" class="data row8 col0" >78,693</td>
#       <td id="T_792fb_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_792fb_row8_col2" class="data row8 col2" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_792fb_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_792fb_row9_col0" class="data row9 col0" >64,732</td>
#       <td id="T_792fb_row9_col1" class="data row9 col1" >0</td>
#       <td id="T_792fb_row9_col2" class="data row9 col2" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_792fb_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_792fb_row10_col0" class="data row10 col0" >93,852</td>
#       <td id="T_792fb_row10_col1" class="data row10 col1" >0</td>
#       <td id="T_792fb_row10_col2" class="data row10 col2" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_792fb_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_792fb_row11_col0" class="data row11 col0" >82,691</td>
#       <td id="T_792fb_row11_col1" class="data row11 col1" >0</td>
#       <td id="T_792fb_row11_col2" class="data row11 col2" >0.0%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# PS5の2026年1月は前年比81.5%でした｡
# 値下げの効果が完全に失われています｡
# 早急に次のテコ入れが必要です｡

# %% [markdown]
# ## 累計販売推移

# %%
long_range_event_mask = g.EventMasks(hard=0.5, soft=0, event=0, price=0, sale=0)
(cumulative_sales_fig, cumulative_sales_df) = g.plot_cumulative_sales(hw=['PS4', 'NS2', 'PS5', 'NSW', 'XSX'], begin=datetime(2017,3,1), event_mask = g.EVENT_MASK_LONG)

# %%
cs_style = g.style_sales(cumulative_sales_df.tail(1), datetime_index=True)
display(cs_style) if VERBOSE else None
# Out:
# <style type="text/css">
# #T_1ba5e_row0_col0, #T_1ba5e_row0_col1, #T_1ba5e_row0_col2, #T_1ba5e_row0_col3, #T_1ba5e_row0_col4 {
#   text-align: right;
# }
# </style>
# <table id="T_1ba5e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1ba5e_level0_col0" class="col_heading level0 col0" >NSW</th>
#       <th id="T_1ba5e_level0_col1" class="col_heading level0 col1" >PS4</th>
#       <th id="T_1ba5e_level0_col2" class="col_heading level0 col2" >PS5</th>
#       <th id="T_1ba5e_level0_col3" class="col_heading level0 col3" >XSX</th>
#       <th id="T_1ba5e_level0_col4" class="col_heading level0 col4" >NS2</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >report_date</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1ba5e_level0_row0" class="row_heading level0 row0" >2026-02-01</th>
#       <td id="T_1ba5e_row0_col0" class="data row0 col0" >36,517,948</td>
#       <td id="T_1ba5e_row0_col1" class="data row0 col1" >9,491,113</td>
#       <td id="T_1ba5e_row0_col2" class="data row0 col2" >7,375,661</td>
#       <td id="T_1ba5e_row0_col3" class="data row0 col3" >691,356</td>
#       <td id="T_1ba5e_row0_col4" class="data row0 col4" >4,307,086</td>
#     </tr>
#   </tbody>
# </table>

# %%
(csd_fig, csd_df) = g.plot_cumulative_sales_by_delta(hw=['PS4', 'NS2', 'PS5', 'NSW', 'XSX'], end=50, event_mask= g.EVENT_MASK_SHORT)

# %% [markdown]
# Switch2は同時期のSwitchの2.2倍の普及速度を継続しています｡

# %%
(csd2_fig, csd2_df) = g.plot_cumulative_sales_by_delta(hw=['NS2', 'PS5'], end=280, event_mask=g.EVENT_MASK_MIDDLE)

# %% [markdown]
# 勢いの差を見やすくするために､Nintendo Switch2とPlayStation5だけの累計推移グラフを示します｡
# Switch2はPS5に比べると垂直立ち上げと呼べるような立ち上がりをしていることが分かると思います｡

# %% [markdown]
# ## Switch2初動状況

# %%
(csd_ns2_fig, csd_ns2_df) = g.plot_cumulative_sales_by_delta(hw=["GBA", "NS2", "DS", "PS2", "Wii", "3DS", "NSW", "PS5"], 
                                        mode="week", xgrid=2, end=45,
                                        event_mask=g.EVENT_MASK_MIDDLE)

# %%
df12 = csd_ns2_df.filter(pl.col("delta_week") == 33).drop("delta_week")
df12_unpivot = df12.unpivot(
    index=None,
    variable_name="ハード",
    value_name="販売数"
).sort("販売数", descending=True)

styled_df12_unpivot = g.style_sales(df12_unpivot, columns=['販売数'], bars=['販売数'])
display(styled_df12_unpivot)
# Out:
# <style type="text/css">
# #T_70f46_row0_col0 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06dd 100.0%, transparent 100.0%);
# }
# #T_70f46_row1_col0 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06dd 81.8%, transparent 81.8%);
# }
# #T_70f46_row2_col0 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06dd 72.9%, transparent 72.9%);
# }
# #T_70f46_row3_col0 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06dd 67.4%, transparent 67.4%);
# }
# #T_70f46_row4_col0 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06dd 58.9%, transparent 58.9%);
# }
# #T_70f46_row5_col0 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06dd 49.1%, transparent 49.1%);
# }
# #T_70f46_row6_col0 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06dd 45.0%, transparent 45.0%);
# }
# #T_70f46_row7_col0 {
#   text-align: right;
#   width: 10em;
#   background: linear-gradient(90deg, #18ba06dd 20.6%, transparent 20.6%);
# }
# </style>
# <table id="T_70f46">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_70f46_level0_col0" class="col_heading level0 col0" >販売数</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ハード</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_70f46_level0_row0" class="row_heading level0 row0" >NS2</th>
#       <td id="T_70f46_row0_col0" class="data row0 col0" >4,237,500</td>
#     </tr>
#     <tr>
#       <th id="T_70f46_level0_row1" class="row_heading level0 row1" >GBA</th>
#       <td id="T_70f46_row1_col0" class="data row1 col0" >3,467,042</td>
#     </tr>
#     <tr>
#       <th id="T_70f46_level0_row2" class="row_heading level0 row2" >Wii</th>
#       <td id="T_70f46_row2_col0" class="data row2 col0" >3,090,509</td>
#     </tr>
#     <tr>
#       <th id="T_70f46_level0_row3" class="row_heading level0 row3" >PS2</th>
#       <td id="T_70f46_row3_col0" class="data row3 col0" >2,855,375</td>
#     </tr>
#     <tr>
#       <th id="T_70f46_level0_row4" class="row_heading level0 row4" >DS</th>
#       <td id="T_70f46_row4_col0" class="data row4 col0" >2,497,605</td>
#     </tr>
#     <tr>
#       <th id="T_70f46_level0_row5" class="row_heading level0 row5" >3DS</th>
#       <td id="T_70f46_row5_col0" class="data row5 col0" >2,079,329</td>
#     </tr>
#     <tr>
#       <th id="T_70f46_level0_row6" class="row_heading level0 row6" >NSW</th>
#       <td id="T_70f46_row6_col0" class="data row6 col0" >1,908,127</td>
#     </tr>
#     <tr>
#       <th id="T_70f46_level0_row7" class="row_heading level0 row7" >PS5</th>
#       <td id="T_70f46_row7_col0" class="data row7 col0" >874,937</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Switch2が週7万のペースを維持できるなら､
# 第40週を超えても歴代一位を維持できる可能性が高いです｡

# %% [markdown]
# ## 年単位の状況

# %%
(yb_fig, yb_df) = g.plot_yearly_bar_by_hard(hw=['3DS', 'WiiU','NSW', 'NS2',  'PS4', 'PS5', 'Vita', 'XSX', 'XBOne'], 
                                       begin=g.years_ago(report_date, 10),
                                       end=report_date, stacked=True)

# %%
yb_df = yb_df.with_columns(
    pl.sum_horizontal(pl.exclude("year")).alias("合計")
)
yearly_style = g.style_sales(yb_df)
display(yearly_style)
# Out:
# <style type="text/css">
# #T_8d446_row0_col0, #T_8d446_row0_col1, #T_8d446_row0_col2, #T_8d446_row0_col3, #T_8d446_row0_col4, #T_8d446_row0_col5, #T_8d446_row0_col6, #T_8d446_row0_col7, #T_8d446_row0_col8, #T_8d446_row0_col9, #T_8d446_row1_col0, #T_8d446_row1_col1, #T_8d446_row1_col2, #T_8d446_row1_col3, #T_8d446_row1_col4, #T_8d446_row1_col5, #T_8d446_row1_col6, #T_8d446_row1_col7, #T_8d446_row1_col8, #T_8d446_row1_col9, #T_8d446_row2_col0, #T_8d446_row2_col1, #T_8d446_row2_col2, #T_8d446_row2_col3, #T_8d446_row2_col4, #T_8d446_row2_col5, #T_8d446_row2_col6, #T_8d446_row2_col7, #T_8d446_row2_col8, #T_8d446_row2_col9, #T_8d446_row3_col0, #T_8d446_row3_col1, #T_8d446_row3_col2, #T_8d446_row3_col3, #T_8d446_row3_col4, #T_8d446_row3_col5, #T_8d446_row3_col6, #T_8d446_row3_col7, #T_8d446_row3_col8, #T_8d446_row3_col9, #T_8d446_row4_col0, #T_8d446_row4_col1, #T_8d446_row4_col2, #T_8d446_row4_col3, #T_8d446_row4_col4, #T_8d446_row4_col5, #T_8d446_row4_col6, #T_8d446_row4_col7, #T_8d446_row4_col8, #T_8d446_row4_col9, #T_8d446_row5_col0, #T_8d446_row5_col1, #T_8d446_row5_col2, #T_8d446_row5_col3, #T_8d446_row5_col4, #T_8d446_row5_col5, #T_8d446_row5_col6, #T_8d446_row5_col7, #T_8d446_row5_col8, #T_8d446_row5_col9, #T_8d446_row6_col0, #T_8d446_row6_col1, #T_8d446_row6_col2, #T_8d446_row6_col3, #T_8d446_row6_col4, #T_8d446_row6_col5, #T_8d446_row6_col6, #T_8d446_row6_col7, #T_8d446_row6_col8, #T_8d446_row6_col9, #T_8d446_row7_col0, #T_8d446_row7_col1, #T_8d446_row7_col2, #T_8d446_row7_col3, #T_8d446_row7_col4, #T_8d446_row7_col5, #T_8d446_row7_col6, #T_8d446_row7_col7, #T_8d446_row7_col8, #T_8d446_row7_col9, #T_8d446_row8_col0, #T_8d446_row8_col1, #T_8d446_row8_col2, #T_8d446_row8_col3, #T_8d446_row8_col4, #T_8d446_row8_col5, #T_8d446_row8_col6, #T_8d446_row8_col7, #T_8d446_row8_col8, #T_8d446_row8_col9, #T_8d446_row9_col0, #T_8d446_row9_col1, #T_8d446_row9_col2, #T_8d446_row9_col3, #T_8d446_row9_col4, #T_8d446_row9_col5, #T_8d446_row9_col6, #T_8d446_row9_col7, #T_8d446_row9_col8, #T_8d446_row9_col9, #T_8d446_row10_col0, #T_8d446_row10_col1, #T_8d446_row10_col2, #T_8d446_row10_col3, #T_8d446_row10_col4, #T_8d446_row10_col5, #T_8d446_row10_col6, #T_8d446_row10_col7, #T_8d446_row10_col8, #T_8d446_row10_col9 {
#   text-align: right;
# }
# </style>
# <table id="T_8d446">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8d446_level0_col0" class="col_heading level0 col0" >3DS</th>
#       <th id="T_8d446_level0_col1" class="col_heading level0 col1" >WiiU</th>
#       <th id="T_8d446_level0_col2" class="col_heading level0 col2" >NSW</th>
#       <th id="T_8d446_level0_col3" class="col_heading level0 col3" >NS2</th>
#       <th id="T_8d446_level0_col4" class="col_heading level0 col4" >PS4</th>
#       <th id="T_8d446_level0_col5" class="col_heading level0 col5" >PS5</th>
#       <th id="T_8d446_level0_col6" class="col_heading level0 col6" >Vita</th>
#       <th id="T_8d446_level0_col7" class="col_heading level0 col7" >XSX</th>
#       <th id="T_8d446_level0_col8" class="col_heading level0 col8" >XBOne</th>
#       <th id="T_8d446_level0_col9" class="col_heading level0 col9" >合計</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8d446_level0_row0" class="row_heading level0 row0" >2016</th>
#       <td id="T_8d446_row0_col0" class="data row0 col0" >1,874,457</td>
#       <td id="T_8d446_row0_col1" class="data row0 col1" >336,151</td>
#       <td id="T_8d446_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_8d446_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_8d446_row0_col4" class="data row0 col4" >1,790,883</td>
#       <td id="T_8d446_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_8d446_row0_col6" class="data row0 col6" >865,002</td>
#       <td id="T_8d446_row0_col7" class="data row0 col7" >nan</td>
#       <td id="T_8d446_row0_col8" class="data row0 col8" >8,897</td>
#       <td id="T_8d446_row0_col9" class="data row0 col9" >4,875,390</td>
#     </tr>
#     <tr>
#       <th id="T_8d446_level0_row1" class="row_heading level0 row1" >2017</th>
#       <td id="T_8d446_row1_col0" class="data row1 col0" >1,827,131</td>
#       <td id="T_8d446_row1_col1" class="data row1 col1" >21,817</td>
#       <td id="T_8d446_row1_col2" class="data row1 col2" >3,407,158</td>
#       <td id="T_8d446_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_8d446_row1_col4" class="data row1 col4" >1,935,247</td>
#       <td id="T_8d446_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_8d446_row1_col6" class="data row1 col6" >396,207</td>
#       <td id="T_8d446_row1_col7" class="data row1 col7" >nan</td>
#       <td id="T_8d446_row1_col8" class="data row1 col8" >14,664</td>
#       <td id="T_8d446_row1_col9" class="data row1 col9" >7,602,224</td>
#     </tr>
#     <tr>
#       <th id="T_8d446_level0_row2" class="row_heading level0 row2" >2018</th>
#       <td id="T_8d446_row2_col0" class="data row2 col0" >566,420</td>
#       <td id="T_8d446_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_8d446_row2_col2" class="data row2 col2" >3,482,388</td>
#       <td id="T_8d446_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_8d446_row2_col4" class="data row2 col4" >1,695,227</td>
#       <td id="T_8d446_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_8d446_row2_col6" class="data row2 col6" >181,728</td>
#       <td id="T_8d446_row2_col7" class="data row2 col7" >nan</td>
#       <td id="T_8d446_row2_col8" class="data row2 col8" >15,339</td>
#       <td id="T_8d446_row2_col9" class="data row2 col9" >5,941,102</td>
#     </tr>
#     <tr>
#       <th id="T_8d446_level0_row3" class="row_heading level0 row3" >2019</th>
#       <td id="T_8d446_row3_col0" class="data row3 col0" >191,173</td>
#       <td id="T_8d446_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_8d446_row3_col2" class="data row3 col2" >4,493,903</td>
#       <td id="T_8d446_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_8d446_row3_col4" class="data row3 col4" >1,196,153</td>
#       <td id="T_8d446_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_8d446_row3_col6" class="data row3 col6" >37,668</td>
#       <td id="T_8d446_row3_col7" class="data row3 col7" >nan</td>
#       <td id="T_8d446_row3_col8" class="data row3 col8" >8,315</td>
#       <td id="T_8d446_row3_col9" class="data row3 col9" >5,927,212</td>
#     </tr>
#     <tr>
#       <th id="T_8d446_level0_row4" class="row_heading level0 row4" >2020</th>
#       <td id="T_8d446_row4_col0" class="data row4 col0" >62,761</td>
#       <td id="T_8d446_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_8d446_row4_col2" class="data row4 col2" >5,956,943</td>
#       <td id="T_8d446_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_8d446_row4_col4" class="data row4 col4" >542,647</td>
#       <td id="T_8d446_row4_col5" class="data row4 col5" >255,150</td>
#       <td id="T_8d446_row4_col6" class="data row4 col6" >nan</td>
#       <td id="T_8d446_row4_col7" class="data row4 col7" >31,424</td>
#       <td id="T_8d446_row4_col8" class="data row4 col8" >3,585</td>
#       <td id="T_8d446_row4_col9" class="data row4 col9" >6,852,510</td>
#     </tr>
#     <tr>
#       <th id="T_8d446_level0_row5" class="row_heading level0 row5" >2021</th>
#       <td id="T_8d446_row5_col0" class="data row5 col0" >28,540</td>
#       <td id="T_8d446_row5_col1" class="data row5 col1" >nan</td>
#       <td id="T_8d446_row5_col2" class="data row5 col2" >5,579,127</td>
#       <td id="T_8d446_row5_col3" class="data row5 col3" >nan</td>
#       <td id="T_8d446_row5_col4" class="data row5 col4" >104,054</td

# %% [markdown]
# ### 年単位のメーカーシェア

# %%
(msb_fig, msb_df) = g.plot_maker_share_bar(begin=datetime(2017, 1, 1))

# %% [markdown]
# 今週も､PS5が四桁だった影響で任天堂のシェアはさらに上昇し､先週の88.8%から88.9%になりました｡

# %%
if VERBOSE:
    # msb_dfのyear以外のカラムの全ての値を100で割る
    msb_df = msb_df.with_columns(
        [ (pl.col(col) / 100).alias(col) for col in msb_df.columns if col != "year" ]
    )
    share_style = g.style_sales(msb_df, percent_columns=msb_df.columns[1:])
    share_style = share_style.background_gradient(cmap='Blues', axis=0)
    display(share_style)
# Out:
# <style type="text/css">
# #T_46bbc_row0_col0 {
#   text-align: right;
#   text-align: right;
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_46bbc_row0_col1 {
#   text-align: right;
#   text-align: right;
#   background-color: #2c7cba;
#   color: #f1f1f1;
# }
# #T_46bbc_row0_col2 {
#   text-align: right;
#   text-align: right;
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_46bbc_row1_col0 {
#   text-align: right;
#   text-align: right;
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_46bbc_row1_col1 {
#   text-align: right;
#   text-align: right;
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_46bbc_row1_col2, #T_46bbc_row9_col2 {
#   text-align: right;
#   text-align: right;
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_46bbc_row2_col0 {
#   text-align: right;
#   text-align: right;
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_46bbc_row2_col1 {
#   text-align: right;
#   text-align: right;
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_46bbc_row2_col2, #T_46bbc_row6_col0, #T_46bbc_row9_col1 {
#   text-align: right;
#   text-align: right;
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_46bbc_row3_col0 {
#   text-align: right;
#   text-align: right;
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_46bbc_row3_col1 {
#   text-align: right;
#   text-align: right;
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_46bbc_row3_col2, #T_46bbc_row8_col2 {
#   text-align: right;
#   text-align: right;
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_46bbc_row4_col0 {
#   text-align: right;
#   text-align: right;
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_46bbc_row4_col1 {
#   text-align: right;
#   text-align: right;
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_46bbc_row4_col2 {
#   text-align: right;
#   text-align: right;
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_46bbc_row5_col0 {
#   text-align: right;
#   text-align: right;
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_46bbc_row5_col1 {
#   text-align: right;
#   text-align: right;
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_46bbc_row5_col2, #T_46bbc_row6_col1, #T_46bbc_row9_col0 {
#   text-align: right;
#   text-align: right;
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_46bbc_row6_col2 {
#   text-align: right;
#   text-align: right;
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_46bbc_row7_col0 {
#   text-align: right;
#   text-align: right;
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_46bbc_row7_col1 {
#   text-align: right;
#   text-align: right;
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_46bbc_row7_col2 {
#   text-align: right;
#   text-align: right;
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_46bbc_row8_col0 {
#   text-align: right;
#   text-align: right;
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_46bbc_row8_col1 {
#   text-align: right;
#   text-align: right;
#   background-color: #e0ecf8;
#   color: #000000;
# }
# </style>
# <table id="T_46bbc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_46bbc_level0_col0" class="col_heading level0 col0" >Nintendo</th>
#       <th id="T_46bbc_level0_col1" class="col_heading level0 col1" >SONY</th>
#       <th id="T_46bbc_level0_col2" class="col_heading level0 col2" >Microsoft</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46bbc_level0_row0" class="row_heading level0 row0" >2017</th>
#       <td id="T_46bbc_row0_col0" class="data row0 col0" >69.1%</td>
#       <td id="T_46bbc_row0_col1" class="data row0 col1" >30.7%</td>
#       <td id="T_46bbc_row0_col2" class="data row0 col2" >0.2%</td>
#     </tr>
#     <tr>
#       <th id="T_46bbc_level0_row1" class="row_heading level0 row1" >2018</th>
#       <td id="T_46bbc_row1_col0" class="data row1 col0" >68.1%</td>
#       <td id="T_46bbc_row1_col1" class="data row1 col1" >31.6%</td>
#       <td id="T_46bbc_row1_col2" class="data row1 col2" >0.3%</td>
#     </tr>
#     <tr>
#       <th id="T_46bbc_level0_row2" class="row_heading level0 row2" >2019</th>
#       <td id="T_46bbc_row2_col0" class="data row2 col0" >79.0%</td>
#       <td id="T_46bbc_row2_col1" class="data row2 col1" >20.8%</td>
#       <td id="T_46bbc_row2_col2" class="data row2 col2" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_46bbc_level0_row3" class="row_heading level0 row3" >2020</th>
#       <td id="T_46bbc_row3_col0" class="data row3 col0" >87.8%</td>
#       <td id="T_46bbc_row3_col1" class="data row3 col1" >11.6%</td>
#       <td id="T_46bbc_row3_col2" class="data row3 col2" >0.5%</td>
#     </tr>
#     <tr>
#       <th id="T_46bbc_level0_row4" class="row_heading level0 row4" >2021</th>
#       <td id="T_46bbc_row4_col0" class="data row4 col0" >82.7%</td>
#       <td id="T_46bbc_row4_col1" class="data row4 col1" >15.8%</td>
#       <td id="T_46bbc_row4_col2" class="data row4 col2" >1.4%</td>
#     </tr>
#     <tr>
#       <th id="T_46bbc_level0_row5" class="row_heading level0 row5" >2022</th>
#       <td id="T_46bbc_row5_col0" class="data row5 col0" >76.9%</td>
#       <td id="T_46bbc_row5_col1" class="data row5 col1" >18.8%</td>
#       <td id="T_46bbc_row5_col2" class="data row5 col2" >4.3%</td>
#     </tr>
#     <tr>
#       <th id="T_46bbc_level0_row6" class="row_heading level0 row6" >2023</th>
#       <td id="T_46bbc_row6_col0" class="data row6 col0" >59.2%</td>
#       <td id="T_46bbc_row6_col1" class="data row6 col1" >38.7%</td>
#       <td id="T_46bbc_row6_col2" class="data row6 col2" >2.1%</td>
#     </tr>
#     <tr>
#       <th id="T_46bbc_level0_row7" class="row_heading level0 row7" >2024</th>
#       <td id="T_46bbc_row7_col0" class="data row7 col0" >66.2%</td>
#       <td id="T_46bbc_row7_col1" class="data row7 col1" >31.3%</td>
#       <td id="T_46bbc_row7_col2" class="data row7 col2" >2.5%</td>
#     </tr>
#     <tr>
#       <th id="T_46bbc_level0_row8" class="row_heading level0 row8" >2025</th>
#       <td id="T_46bbc_row8_col0" class="data row8 col0" >85.3%</td>
#       <td id="T_46bbc_row8_col1" class="data row8 col1" >14.2%</td>
#       <td id="T_46bbc_row8_col2" class="data row8 col2" >0.5%</td>
#     </tr>
#     <tr>
#       <th id="T_46bbc_level0_row9" class="row_heading level0 row9" >2026</th>
#       <td id="T_46bbc_row9_col0" class="data row9 col0" >88.7%</td>
#       <td id="T_46bbc_row9_col1" class="data row9 col1" >11.0%</td>
#       <td id="T_46bbc_row9_col2" class="data row9 col2" >0.3%</td>
#     </tr>
#   </tbody>
# </table>

# %%
if VERBOSE:
    (fig, df) = g.plot_maker_share_pie(begin_year=report_date.year, end_year=report_date.year)
