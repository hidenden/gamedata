# %%
# 標準ライブラリ
from datetime import datetime, timedelta

# サードパーティライブラリ
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter

# プロジェクト内モジュール
from gamedata import hard_sales as hs
from gamedata import plot_hard as ph

import re
import japanize_matplotlib
from matplotlib.animation import FuncAnimation, PillowWriter
import math

# %%
hard_sales_df = hs.load_hard_sales(normalize7=True)
pv_sales_by_hw = hs.pivot_sales(hard_sales_df)

# %% [markdown]
# ## 年単位の集計
#
# 年単位集計を行うために､'Y' でリサンプリング。
# なお､1998年のデータは年末だけなので､1999年以後でフィルタする｡

# %%
pv_sales_by_year = pv_sales_by_hw.resample('Y').sum()
pv_sales_after_1999 = pv_sales_by_year[pv_sales_by_year.index.year >= 1999]

# %%
hw_year = hard_yearly_pivot.toPandas().set_index("year")
# Out:
# 23/03/24 22:14:38 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.

# %% [markdown]
# ## グラフ化
#
# 面グラフを作成する

# %%
pv_sales_after_1999.plot(figsize=(20, 10), grid=True, kind="area", ylim=[0,17000000], title="ハード別年単位売上", ylabel="売上 (百万)", xlabel="年")
# Out:
# <Axes: title={'center': 'ハード別年単位売上'}, xlabel='年', ylabel='売上 (百万)'>
