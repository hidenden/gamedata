# %%
# 標準ライブラリ
from datetime import datetime, timedelta

# サードパーティライブラリ
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter

# プロジェクト内モジュール
from gamedata import hard_sales as hs
from gamedata import plot_hard as ph

# %%
hard_sales_df = hs.load_hard_sales(normalize7=True)
hard_list = hs.get_hw_names(hard_sales_df)

# %%
pivot_df = hs.pivot_cumulative_sales_by_delta(hard_sales_df)
pivot_df[['NS2', 'NSW', 'PS4', 'PS5']]
pivot_df.reset_index(inplace=True)

# %%
fig = ph.plot_cumulative_sales_by_delta(hard_sales_df, hw=["NS2", "NSW", "PS5", "PS4", "WiiU"], limit=40, mode="week")
fig.show()
# Out:
# /var/folders/p4/348jfj6522l78r8xkkk0csb40000gn/T/ipykernel_52408/3836053655.py:2: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
reached_df = hs.extract_week_reached_units(hard_sales_df, 1800000)
reached_df.sort_values(by="delta_week", inplace=True)
reached_df
# Out:
#             weekly_id begin_date   end_date report_date  period_date    hw  \
# 8439   2025-07-27_NS2 2025-07-21 2025-07-27  2025-07-27            7   NS2
# 985    2001-05-20_GBA 2001-05-14 2001-05-20  2001-05-20            7   GBA
# 586    2000-06-11_PS2 2000-06-05 2000-06-11  2000-06-11            7   PS2
# 2888   2007-03-11_Wii 2007-03-05 2007-03-11  2007-03-11            7   Wii
# 2242    2005-03-27_DS 2005-03-21 2005-03-27  2005-03-27            7    DS
# 4394   2011-09-18_3DS 2011-09-12 2011-09-18  2011-09-18            7   3DS
# 6488   2017-10-01_NSW 2017-09-25 2017-10-01  2017-10-01            7   NSW
# 303    1999-09-19_PKS 1999-09-13 1999-09-19  1999-09-19            7   PKS
# 2403   2005-09-25_PSP 2005-09-19 2005-09-25  2005-09-25            7   PSP
# 3207   2008-01-20_PS3 2008-01-14 2008-01-20  2008-01-20            7   PS3
# 1605    2002-12-15_GC 2002-12-09 2002-12-15  2002-12-15            7    GC
# ...

# %%
fig = ph.plot_cumulative_sales(hard_sales_df, mode="month")
fig.show()
# Out:
# /var/folders/p4/348jfj6522l78r8xkkk0csb40000gn/T/ipykernel_52408/2351386997.py:2: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig = ph.plot_cumulative_sales(hard_sales_df, mode="year")
fig.show()
# Out:
# /var/folders/p4/348jfj6522l78r8xkkk0csb40000gn/T/ipykernel_52408/1221981254.py:2: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig = ph.plot_cumulative_sales(hard_sales_df, hw=["NSW", "NS2", "PS5"])
fig.show()
# Out:
# /var/folders/p4/348jfj6522l78r8xkkk0csb40000gn/T/ipykernel_52408/2139445086.py:2: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
