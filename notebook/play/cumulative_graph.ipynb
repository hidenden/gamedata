# %%
# 標準ライブラリ
from datetime import datetime, timedelta

# サードパーティライブラリ
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter

# プロジェクト内モジュール
from gamedata import hard_sales as hs
from gamedata import plot_hard as ph

# %%
hard_sales_df = hs.load_hard_sales()
hard_list = hs.get_hw_names(hard_sales_df)

# %%
pivot_df = hs.pivot_cumulative_sales_by_delta(hard_sales_df)
pivot_df[['NS2', 'NSW', 'PS4', 'PS5']]
pivot_df.reset_index(inplace=True)

# %%
fig = ph.plot_cumulative_sales_by_delta(hard_sales_df, hw=["NS2", "NSW", "PS5", "PS4"], limit=15, mode="week")
fig.show()
# Out:
# /var/folders/p4/348jfj6522l78r8xkkk0csb40000gn/T/ipykernel_18559/3419342618.py:2: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig = ph.plot_cumulative_sales_by_delta(hard_sales_df, hw=["GBA", "NS2", "DS", "PS2", "Wii", "3DS"], limit=15, mode="week")
fig.show()
# Out:
# /var/folders/p4/348jfj6522l78r8xkkk0csb40000gn/T/ipykernel_18559/4073675651.py:2: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
reached_df = hs.extract_week_reached_units(hard_sales_df, 1800000)
reached_df.sort_values(by="delta_week", inplace=True)
reached_df
# Out:
#             weekly_id begin_date   end_date report_date  period_date    hw  \
# 982    2001-05-20_GBA 2001-05-14 2001-05-20  2001-05-20            7   GBA
# 8454   2025-08-17_NS2 2025-08-11 2025-08-17  2025-08-17            7   NS2
# 586    2000-06-11_PS2 2000-06-05 2000-06-11  2000-06-11            7   PS2
# 2891   2007-03-11_Wii 2007-03-05 2007-03-11  2007-03-11            7   Wii
# 2242    2005-03-27_DS 2005-03-21 2005-03-27  2005-03-27            7    DS
# 4390   2011-09-18_3DS 2011-09-12 2011-09-18  2011-09-18            7   3DS
# 6485   2017-10-01_NSW 2017-09-25 2017-10-01  2017-10-01            7   NSW
# 304    1999-09-19_PKS 1999-09-13 1999-09-19  1999-09-19            7   PKS
# 2402   2005-09-25_PSP 2005-09-19 2005-09-25  2005-09-25            7   PSP
# 3207   2008-01-20_PS3 2008-01-14 2008-01-20  2008-01-20            7   PS3
# 1606    2002-12-15_GC 2002-12-09 2002-12-15  2002-12-15            7    GC
# 5489  2014-06-22_WiiU 2014-06-16 2014-06-22  2014-06-22            7  WiiU
# 5955   2015-11-08_PS4 2015-11-02 2015-11-08  2015-11-08            7   PS4
# 7723   2022-07-31_PS5 2022-07-25 2022-07-31  2022-07-31            7   PS5
# 5217  2013-10-13_Vita 2013-10-07 2013-10-13  2013-10-13            7  Vita
# 944     2001-04-22_DC 2001-04-16 2001-04-22  2001-04-22            7    DC
# 242     1999-07-18_PS 1999-07-12 1999-07-18  1999-07-18            7    PS
# 112     1999-03-14_GB 1999-03-08 1999-03-14  1999-03-14            7    GB
#
#       units  year  month  mday  week  delta_day  delta_week  delta_month  \
# 982   70875  2001      5    20     3         60           8            2
# 8454  89821  2025      8    17     3         73          10            2
# 586   79393  2000      6    11     2         99          14            3
# 2891  49750  2007      3    11     2         99          14            3
# 2242  60507  2005      3    27     4        115          16            3
# 4390  62245  2011      9    18     3        204          29            7
# 6485  74500  2017     10     1     1        212          30            7
# 304   74235  1999      9    19     3        239          34            8
# 2402  41827  2005      9    25     4        287          41            9
# 3207  32264  2008      1    20     3        435          62           14
# 1606  44902  2002     12    15     3        457          65           15
# 5489   8373  2014      6    22     4        561          80           18
# 5955  32593  2015     11     8     2        624          89           21
# 7723  39336  2022      7    31     5        626          89           20
# 5217  58682  2013     10    13     2        666          95           22
# 944    5056  2001      4    22     4        877         125           29
# 242   33633  1999      7    18     3       1688         241           55
# 112   36610  1999      3    14     2       3614         516          119
#
#       delta_year  avg_units  sum_units launch_date maker_name  \
# 982            0      10125    1809362  2001-03-21   Nintendo
# 8454           0      12831    1856764  2025-06-05   Nintendo
# 586            0      11341    1873108  2000-03-04       SONY
# 2891           1       7107    1801988  2006-12-02   Nintendo
# 2242           1       8643    1809306  2004-12-02   Nintendo
# 4390           0       8892    1849714  2011-02-26   Nintendo
# 6485           0      10642    1808583  2017-03-03   Nintendo
# 304            0      10605    1833921  1999-01-23       SONY
# 2402           1       5975    1821819  2004-12-12       SONY
# 3207           2       4609    1809314  2006-11-11       SONY
# 1606           1       6414    1833710  2001-09-14   Nintendo
# 5489           2       1196    1801022  2012-12-08   Nintendo
# 5955           1       4656    1832187  2014-02-22       SONY
# 7723           2       5619    1803981  2020-11-12       SONY
# 5217           2       8383    1836062  2011-12-17       SONY
# 944            3        722    1804559  1998-11-27       SEGA
# 242            5       4804    1827460  1994-12-03       SONY
# 112           10       5230    1804482  1989-04-21   Nintendo
#
#                  full_name
# 982       GAME BOY ADVANCE
# 8454      Nintendo Switch2
# 586           PlayStation2
# 2891                   Wii
# 2242           Nintendo DS
# 4390          Nintendo 3DS
# 6485       Nintendo Switch
# 304          PocketStation
# 2402  PlayStation Portable
# 3207          PlayStation3
# 1606     Nintendo GAMECUBE
# 5489                  WiiU
# 5955          PlayStation4
# 7723          PlayStation5
# 5217      PlayStation Vita
# 944              DreamCast
# 242            PlayStation
# 112               GAME BOY

# %%
fig = ph.plot_cumulative_sales(hard_sales_df, mode="month")
fig.show()
# Out:
# /var/folders/p4/348jfj6522l78r8xkkk0csb40000gn/T/ipykernel_18559/2351386997.py:2: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig = ph.plot_cumulative_sales(hard_sales_df, mode="year")
fig.show()
# Out:
# /var/folders/p4/348jfj6522l78r8xkkk0csb40000gn/T/ipykernel_18559/1221981254.py:2: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig = ph.plot_cumulative_sales(hard_sales_df, hw=["NSW", "NS2", "PS5"])
fig.show()
# Out:
# /var/folders/p4/348jfj6522l78r8xkkk0csb40000gn/T/ipykernel_18559/2139445086.py:2: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig = ph.plot_cumulative_sales(hard_sales_df, hw=["NS2", "PS5"])
fig.show()
# Out:
# /var/folders/p4/348jfj6522l78r8xkkk0csb40000gn/T/ipykernel_18559/2334433784.py:2: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
