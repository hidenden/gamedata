# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline

### 累計レポート
# 標準ライブラリ
import os
from datetime import datetime, timedelta
from typing import List, Dict, Tuple, Optional, Callable

# サードパーティライブラリ
import pandas as pd
from pandas import Timedelta
import matplotlib.pyplot as plt
import japanize_matplotlib
from matplotlib.ticker import ScalarFormatter
from IPython.display import Markdown, display

# プロジェクト内モジュール
from gamedata import hard_sales as hs
from gamedata import plot_hard as ph
from gamedata import hard_info as hi
from gamedata import hard_event as he
from gamedata import chart_hard as ch

# %%
def sales_by_year(year:int, hw=['NS2', 'NSW', 'PS5']) -> None:
    begin = datetime(year, 1, 1)
    end = datetime(year + 1, 1, 1)
    
    subtitle = f"## {year}年のハード販売状況"
    display(Markdown(subtitle))
    report_event_mask = he.EventMasks(hard=1.5, price=3, sale=2, soft=3, event=2)
    ph.plot_sales(begin=begin, end=end, event_mask=report_event_mask)
    ph.plot_monthly_bar_by_hard(hw=hw, begin=begin, end=end, stacked=False)

# %%
sales_by_year(2025, hw=['NS2', 'NSW', 'PS5'])
# Out:
# ## 2025年のハード販売状況

# %%
sales_by_year(2024, hw=['NSW', 'PS5', 'XSX'])
# Out:
# ## 2024年のハード販売状況

# %%
sales_by_year(2023, hw=['NSW', 'PS5', 'XSX'])
# Out:
# ## 2023年のハード販売状況

# %%
sales_by_year(2022, hw=['NSW', 'PS5', 'XSX'])
# Out:
# ## 2022年のハード販売状況

# %%
sales_by_year(2021, hw=['NSW', 'PS5', 'XSX'])
# Out:
# ## 2021年のハード販売状況

# %%
sales_by_year(2020, hw=['NSW', 'PS4', 'PS5', 'XSX'])
# Out:
# ## 2020年のハード販売状況

# %%
sales_by_year(2019, hw=['NSW', 'PS4'])
# Out:
# ## 2019年のハード販売状況

# %%
sales_by_year(2018, hw=['NSW', '3DS', 'PS4'])
# Out:
# ## 2018年のハード販売状況

# %%
sales_by_year(2017, hw=['NSW', '3DS', 'PS4', 'Vita'])
# Out:
# ## 2017年のハード販売状況

# %%
sales_by_year(2016, hw=['3DS', 'WiiU', 'PS4', 'Vita'])
# Out:
# ## 2016年のハード販売状況

# %%
sales_by_year(2015, hw=['3DS', 'WiiU', 'PS4', 'Vita'])
# Out:
# ## 2015年のハード販売状況

# %%
sales_by_year(2014, hw=['3DS', 'WiiU', 'PS3', 'PS4', 'Vita'])
# Out:
# ## 2014年のハード販売状況

# %%
sales_by_year(2013, hw=['3DS', 'WiiU', 'PS3', 'Vita'])
# Out:
# ## 2013年のハード販売状況

# %%
sales_by_year(2012, hw=['3DS', 'Wii', 'WiiU', 'PS3', 'PSP', 'Vita'])
# Out:
# ## 2012年のハード販売状況

# %%
sales_by_year(2011, hw=['DS', '3DS', 'Wii', 'PS3', 'PSP', 'Vita'])
# Out:
# ## 2011年のハード販売状況

# %%
sales_by_year(2010, hw=['DS', 'Wii', 'PS3', 'PSP'])
# Out:
# ## 2010年のハード販売状況
