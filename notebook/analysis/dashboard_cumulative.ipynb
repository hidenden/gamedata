# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline

### 累計レポート
# 標準ライブラリ
import os
from datetime import datetime, timedelta
from typing import List, Dict, Tuple, Optional, Callable

# サードパーティライブラリ
import pandas as pd
from pandas import Timedelta
import matplotlib.pyplot as plt
import japanize_matplotlib
from matplotlib.ticker import ScalarFormatter
from IPython.display import Markdown, display

# プロジェクト内モジュール
from gamedata import hard_sales as hs
from gamedata import plot_hard as ph
from gamedata import hard_info as hi
from gamedata import hard_event as he
from gamedata import chart_hard as ch

long_range_event_mask = he.EventMasks(hard=0.5, soft=1, event=0, price=0, sale=0)
report_event_mask = he.EventMasks(hard=1.5, price=3, sale=2, soft=1.5, event=1)

# %%
long_range_event_mask = he.EventMasks(hard=0.5, soft=1, event=0, price=0, sale=0)
(fig, df) = ph.plot_cumulative_sales(hw=['PS4', 'PS5', 'NSW', 'XSX', 'NS2'], begin=datetime(2017,3,1), event_mask = long_range_event_mask)

# %%
(fig, df) = ph.plot_cumulative_sales(hw=['PS5', 'NS2'], begin=datetime(2017,3,1), event_mask = long_range_event_mask)

# %%
(fig, df) = ph.plot_cumulative_sales_by_delta(hw=['PS5', 'NS2'], end=50, event_mask = long_range_event_mask)

# %%
(fig, df) = ph.plot_cumulative_sales(hw=['PS4', 'NSW'], begin=datetime(2014,1,1), event_mask = long_range_event_mask)

# %%
(fig, df) = ph.plot_cumulative_sales_by_delta(hw=['PS4', 'NSW'], end=450,event_mask = long_range_event_mask)

# %%
(fig, df) = ph.plot_cumulative_sales_by_delta(hw=['PS4', 'NS2', 'PS5', 'NSW', 'XSX'], end=50, event_mask=report_event_mask)

# %%
(fig, df) = ph.plot_cumulative_sales_by_delta(hw=["GBA", "NS2", "DS", "PS2", "Wii", "3DS", "NSW", "PS5"], 
                                        mode="week", xgrid=2, end=30,
                                        event_mask=report_event_mask)

# %%
(fig, df) = ph.plot_cumulative_sales_by_delta(hw=["GBA", "NS2", "DS", "3DS", "NSW", "PSP", "Vita"], 
                                        mode="week", xgrid=2, end=48,
                                        event_mask=report_event_mask)

# %%
(fig, df) = ph.plot_cumulative_sales_by_delta(hw=["PS2", "PS3", "PS4", "PS5", "PSP", "Vita"], 
                                        mode="week", xgrid=2, end=80,
                                        event_mask=report_event_mask)

# %%
(fig, df) = ph.plot_cumulative_sales_by_delta(hw=["NS2", "NSW"], 
                                        mode="week", xgrid=2, end=50,
                                        event_mask=report_event_mask)

# %%
long_range_event_mask = he.EventMasks(hard=2, soft=0.7, event=3, price=2, sale=1)
(fig, df) = ph.plot_cumulative_sales(hw=['Vita', '3DS', 'NSW'], end=datetime(2017,12,31), event_mask = long_range_event_mask)
