# %%
from pyspark.sql import functions as F
from pyspark.sql import SparkSession
import matplotlib.pyplot as plt
from plot_utils import *
from data_utils import *
from pyspark.sql import Row

hard_sales = load_hard_sales()
# Out:
# 23/08/18 17:18:49 WARN Utils: Your hostname, apricot.local resolves to a loopback address: 127.0.0.1; using 192.168.0.41 instead (on interface en0)
# 23/08/18 17:18:49 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/08/18 17:18:49 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 23/08/18 17:18:50 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 23/08/18 17:18:50 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# 23/08/18 17:18:50 WARN Utils: Service 'SparkUI' could not bind on port 4042. Attempting port 4043.

# %%
ff15_hw = extract_by_date(hard_sales, "2016-11-29")
ff15_hw.show()
ff15_before_hw = extract_by_date(hard_sales, "2016-11-25")
ff15_before_hw.show()
# Out:
# +-----+----------+----------+------+----+-----+----------+---------+----------------+-----------+---------+----------+----------+---------+----+
# |   hw|begin_date|  end_date| units|year|month|launch_day|    maker|       full_name|launch_year|delta_day|delta_week|delta_year|sum_units|week|
# +-----+----------+----------+------+----+-----+----------+---------+----------------+-----------+---------+----------+----------+---------+----+
# |  3DS|2016-11-28|2016-12-04| 62267|2016|   12|2011-02-26| Nintendo|    Nintendo 3DS|       2011|     2108|       301|         5| 21268377|  48|
# |  PS4|2016-11-28|2016-12-04|116593|2016|   12|2014-02-22|     SONY|    PlayStation4|       2014|     1016|       145|         2|  3625775|  48|
# | Vita|2016-11-28|2016-12-04| 14853|2016|   12|2011-12-17|     SONY|PlayStation Vita|       2011|     1814|       259|         5|  5104403|  48|
# ...

# %%
ff13_hw = extract_by_date(hard_sales, "2009-12-17")
ff13_hw.show()

ff13_before_hw = extract_by_date(hard_sales, "2009-12-12")
ff13_before_hw.show()
# Out:
# +-----+----------+----------+------+----+-----+----------+---------+--------------------+-----------+---------+----------+----------+---------+----+
# |   hw|begin_date|  end_date| units|year|month|launch_day|    maker|           full_name|launch_year|delta_day|delta_week|delta_year|sum_units|week|
# +-----+----------+----------+------+----+-----+----------+---------+--------------------+-----------+---------+----------+----------+---------+----+
# |   DS|2009-12-14|2009-12-20|198372|2009|   12|2004-12-02| Nintendo|         Nintendo DS|       2004|     1844|       263|         5| 28896882|  51|
# |  PS2|2009-12-14|2009-12-20|  3405|2009|   12|2000-03-04|     SONY|        PlayStation2|       2000|     3578|       511|         9| 21054074|  51|
# |  PS3|2009-12-14|2009-12-20|245406|2009|   12|2006-11-11|     SONY|        PlayStation3|       2006|     1135|       162|         3|  4265964|  51|
# ...

# %%
ff16_before_hw = extract_by_date(hard_sales, "2023-06-18")
ff16_before_hw.show()
# Out:
# +------+----------+----------+-----+----+-----+----------+---------+---------------+-----------+---------+----------+----------+---------+----+
# |    hw|begin_date|  end_date|units|year|month|launch_day|    maker|      full_name|launch_year|delta_day|delta_week|delta_year|sum_units|week|
# +------+----------+----------+-----+----+-----+----------+---------+---------------+-----------+---------+----------+----------+---------+----+
# |   3DS|2023-06-12|2023-06-18|   47|2023|    6|2011-02-26| Nintendo|   Nintendo 3DS|       2011|     4495|       642|        12| 24387161|  24|
# |   PS4|2023-06-12|2023-06-18| 1340|2023|    6|2014-02-22|     SONY|   PlayStation4|       2014|     3403|       486|         9|  9437839|  24|
# |   PS5|2023-06-12|2023-06-18|51251|2023|    6|2020-11-12|     SONY|   PlayStation5|       2020|      948|       135|         3|  3717798|  24|
# ...

# %%
print(ff15_ps4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(ff15_ps4)
#
# NameError: name 'ff15_ps4' is not defined
# 23/08/19 23:00:00 WARN HeartbeatReceiver: Removing executor driver with no recent heartbeats: 758460 ms exceeds timeout 120000 ms
# 23/08/19 23:00:00 WARN SparkContext: Killing executors is not supported by current scheduler.
# 23/08/19 23:00:01 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:301)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# ...

# %%
extract_latest(hard_sales).show()
# Out:
# +------+----------+----------+------+----+-----+----------+---------+---------------+-----------+---------+----------+----------+---------+----+
# |    hw|begin_date|  end_date| units|year|month|launch_day|    maker|      full_name|launch_year|delta_day|delta_week|delta_year|sum_units|week|
# +------+----------+----------+------+----+-----+----------+---------+---------------+-----------+---------+----------+----------+---------+----+
# |   3DS|2023-06-05|2023-06-11|    36|2023|    6|2011-02-26| Nintendo|   Nintendo 3DS|       2011|     4488|       641|        12| 24387114|  23|
# |   PS4|2023-06-05|2023-06-11|  1852|2023|    6|2014-02-22|     SONY|   PlayStation4|       2014|     3396|       485|         9|  9436499|  23|
# |   PS5|2023-06-05|2023-06-11| 43609|2023|    6|2020-11-12|     SONY|   PlayStation5|       2020|      941|       134|         3|  3666547|  23|
# ...

# %%
ff16_ps5 = extract_by_date(hard_sales, "2023-06-11", ["PS5"]).first()['sum_units']
print(ff16_ps5)
# Out:
# 3666547

# %%
ff16_ps5 = extract_by_date(hard_sales, "2023-06-04", ["PS5"]).first()['sum_units']
print(ff16_ps5)
# Out:
# 3622938

# %%
ff15_hw.show()
# Out:
# +---+----------+----------+-----+----+-----+----------+-----+------------+-----------+---------+----------+----------+---------+----+
# | hw|begin_date|  end_date|units|year|month|launch_day|maker|   full_name|launch_year|delta_day|delta_week|delta_year|sum_units|week|
# +---+----------+----------+-----+----+-----+----------+-----+------------+-----------+---------+----------+----------+---------+----+
# |PS4|2016-11-21|2016-11-27|40636|2016|   11|2014-02-22| SONY|PlayStation4|       2014|     1009|       144|         2|  3509182|  47|
# +---+----------+----------+-----+----+-----+----------+-----+------------+-----------+---------+----------+----------+---------+----+
